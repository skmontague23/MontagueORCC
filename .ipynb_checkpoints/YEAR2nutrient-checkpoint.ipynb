# %% [markdown]
# # YEAR 2 Nutrient Analysis

# %%
Samples taken one year after experiment

# %%
library(lme4) #for linear mixed effects model
library(readr) #to read in data
library(emmeans) #for post hocs
library(esquisse) #interface for building plots
library(dplyr) #for data wrangling
library(nlme) #for linear mixed effects model
library(car) #for the Levene test
library(ggplot2) #for graphs
library(plotrix) #for standard error
library(performance) #model testing
library(lmtest) #another option than levene test for variance

# %%
setwd("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC")
getwd()
# Out:
# [1] "/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC"

# %% [markdown]
# ## 0. Data Formatting

# %%
year2 <- read_csv("Year_2_Data/Nutrients/Nutrient_YEAR2_working.csv")
Phase1_info <- read_csv("Oyster_Weight_Data/growth_phase2.1_weightsSKM.csv")
# Out:
# New names:
# • `` -> `...16`
# Rows: 374 Columns: 16
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (11): Sample_Name_Nutrients, Phase_2_treat, Phase_2_rep, Phase_2_rep_R, Tissue_type, Tag, Tag_color, N_Notes, C_...
# dbl  (5): Tag_num, Linear corr d15N, wt_percent_n, Linear corr d13C, wt_percent_c
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1152 Columns: 37
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (20): Sample_Name, Date_MMDDYYYY_pre, Phase_1_treat, Phase_1_rep, Phase_2_treat, Phase_2_rep, Tag_color, Notes_p...
# dbl (17): Order_pre, Year, Tag_num, Submerged_weight_pre, Dry_weight_pre, Order_post, Date_MMDDYYYY_post, Submerged_...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
colnames(Phase1_info)
# Out:
#  [1] "Sample_Name"               "Order_pre"                 "Date_MMDDYYYY_pre"         "Year"
#  [5] "Phase_1_treat"             "Phase_1_rep"               "Phase_2_treat"             "Phase_2_rep"
#  [9] "Tag_color"                 "Tag_num"                   "Submerged_weight_pre"      "Dry_weight_pre"
# [13] "Notes_pre"                 "Order_post"                "Date_MMDDYYYY_post"        "Submerged_weight_post"
# [17] "Dry_weight_post"           "double_single_dead"        "Notes_post"                "Actual_shell_pre_mg"
# [21] "Actual_shell_post_mg"      "Actual_shell_growth_mg"    "Actual_tissue_pre_mg"      "Actual_tissue_post_mg"
# [25] "Actual_tissue_growth_mg"   "Ratio_tissue_shell_mg"     "Phase_1_temp"              "Phase_1_DO"
# [29] "Phase_2.1_temp"            "Phase_2.1_DO"              "Phase1_Phase2_treat"       "Phase_1_rep_R"
# [33] "Phase_2_rep_R"             "Ratio_tissue_shell_pre_mg" "Phase1_Phase2_rep"         "Exclude_all"
# [37] "Exclude_pre_analysis"

# %%
#Add in treatment groups etc.
nutrient_df <- year2 %>%
  inner_join(
    Phase1_info %>%
      select(
        Phase_2_rep_R, Sample_Name, Phase_1_treat, Phase_1_rep, Phase_1_rep_R,
        Tag_color, Tag_num, Notes_pre, Notes_post,
        Actual_shell_pre_mg, Actual_shell_post_mg, Actual_shell_growth_mg,
        Actual_tissue_pre_mg, Actual_tissue_post_mg, Actual_tissue_growth_mg,
        Phase_1_temp, Phase_1_DO, Phase_2.1_temp, Phase_2.1_DO,
        Exclude_all), 
      by = c("Phase_2_rep_R", "Tag_color", "Tag_num"))

# %%
colnames(nutrient_df)
# Out:
#  [1] "Sample_Name_Nutrients"   "Phase_2_treat"           "Phase_2_rep"             "Phase_2_rep_R"
#  [5] "Tissue_type"             "Tag"                     "Tag_color"               "Tag_num"
#  [9] "Linear corr d15N"        "wt_percent_n"            "N_Notes"                 "Linear corr d13C"
# [13] "wt_percent_c"            "C_Notes"                 "N_Exclude"               "...16"
# [17] "Sample_Name"             "Phase_1_treat"           "Phase_1_rep"             "Phase_1_rep_R"
# [21] "Notes_pre"               "Notes_post"              "Actual_shell_pre_mg"     "Actual_shell_post_mg"
# [25] "Actual_shell_growth_mg"  "Actual_tissue_pre_mg"    "Actual_tissue_post_mg"   "Actual_tissue_growth_mg"
# [29] "Phase_1_temp"            "Phase_1_DO"              "Phase_2.1_temp"          "Phase_2.1_DO"
# [33] "Exclude_all"

# %%
View(nutrient_df)
# Out:
#     Sample_Name_Nutrients Phase_2_treat Phase_2_rep Phase_2_rep_R Tissue_type Tag Tag_color Tag_num Linear corr d15N
# 1   Cont01 B12 T          Cont          01          Cont01        T           B12 B         12      12.8
# 2   Cont02 G23 T          Cont          02          Cont02        T           G23 G         23      13.3
# 3   Cont02 W22 T          Cont          02          Cont02        T           W22 W         22      13.3
# 4   Cont02 O22 T          Cont          02          Cont02        T           O22 O         22      12.7
# 5   Cont02 O18 T          Cont          02          Cont02        T           O18 O         18      12.5
# 6   Cont02 G13 T          Cont          02          Cont02        T           G13 G         13      13.2
# 7   Cont02 G17 T          Cont          02          Cont02        T           G17 G         17      12.6
# 8   Cont02 W23 T          Cont          02          Cont02        T           W23 W         23      13.0
# 9   Cont02 B19 T          Cont          02          Cont02        T           B19 B         19      13.0
# 10  Cont02 B15 T          Cont          02          Cont02        T           B15 B         15      13.2
# 11  Cont03 B29 T          Cont          03          Cont03        T           B29 B         29      13.0
# 12  Cont03 W31 T          Cont          03          Cont03        T           W31 W         31      13.0
# 13  Cont03 W28 T          Cont          03          Cont03        T           W28 W         28      13.7
# 14  Cont03 W29 T          Cont          03          Cont03        T           W29 W         29      13.3
# 15  Cont03 G27 T          Cont          03          Cont03        T           G27 G         27      12.9
# 16  Cont03 G34 T          Cont          03          Cont03        T           G34 G         34      13.0
# 17  Cont03 O36 T          Cont          03          Cont03        T           O36 O         36      12.7
# 18  Cont03 O34 T          Cont          03          Cont03        T           O34 O         34      11.8
# 19  Cont03 B34 T          Cont          03          Cont03        T           B34 B         34      12.5
# 20  Cont03 B25 T          Cont          03          Cont03        T           B25 B         25      13.3
# 21  Cont03 G26 T          Cont          03          Cont03        T           G26 G         26      12.9
# 22  Cont04 W39 T          Cont          04          Cont04        T           W39 W         39      12.7
# 23  Cont04 O42 T          Cont          04          Cont04        T           O42 O         42      12.3
# 24  Cont04 O44 T          Cont          04          Cont04        T           O44 O         44      12.4
# 25  Cont04 G39 T          Cont          04          Cont04        T           G39 G         39      13.7
# 26  Cont04 B43 T          Cont          04          Cont04        T           B43 B         43      13.2
# 27  Cont04 G43 T          Cont          04          Cont04        T           G43 G         43      12.5
# 28  Cont04 B39 T          Cont          04          Cont04        T           B39 B         39      13.2
# 29  Cont04  W47 T         Cont          04          Cont04        T           W47 W         47      12.3
# 30  Cont05 W56 T          Cont          05          Cont05        T           W56 W         56      13.2
# ⋮   ⋮                     ⋮             ⋮           ⋮             ⋮           ⋮   ⋮         ⋮       ⋮
# 345 Warm06 O61 S          Warm          06          Warm06        S           O61 O         61      16.4
# 346 Warm06 O64 S          Warm          06          Warm06        S           O64 O         64      13.3
# 347 Warm06 B70 S          Warm          06          Warm06        S           B70 B         70      12.4
# 348 Warm06 B62 S          Warm          06          Warm06        S           B62 B         62      13.1
# 349 Warm06 G65 S          Warm          06          Warm06        S           G65 G         65      12.5
# 350 Warm06 G67 S          Warm          06          Warm06        S           G67 G         67      11.5
# 351 Warm06 W65 S          Warm          06          Warm06        S           W65 W         65      12.9
# 352 Warm06 W69 S          Warm          06          Warm06        S           W69 W         69      12.1
# 353 Hyp01 G1 S            Hyp           01          Hyp01         S           G1  G          1      12.6
# 354 Hyp01 W8 S            Hyp           01          Hyp01         S           W8  W          8      13.5
# 355 Hyp01 O5 S            Hyp           01          Hyp01         S           O5  O          5      12.6
# 356 Hyp01 W9 S            Hyp           01          Hyp01         S           W9  W          9      12.8
# 357 Hyp01 B5 S            Hyp           01          Hyp01         S           B5  B          5      10.0
# 358 Both04 G43 S          Both          04          Both04        S           G43 G         43      16.4
# 359 Both04 B44 S          Both          04          Both04        S           B44 B         44      13.5
# 360 Both05 B57 S          Both          05          Both05        S           B57 B         57      13.2
# 361 Both05 G59 S          Both          05          Both05        S           G59 G         59      12.7
# 362 Both05 O53 S          Both          05          Both05        S           O53 O         53       9.1
# 363 Both05 O55 S          Both          05          Both05        S           O55 O         55       8.5
# 364 Both05 W53 S          Both          05          Both05        S           W53 W         53      11.8
# 365 Both05 G51 S          Both          05          Both05        S           G51 G         51      13.2
# 366 Both05 W57 S          Both          05          Both05        S           W57 W         57      12.5
# 367 Both06 B65 S          Both          06          Both06        S           B65 B         65      11.6
# 368 Both06 G69 S          Both          06          Both06        S           G69 G         69      12.1
# 369 Both06 W63 S          Both          06          Both06        S           W63 W         63      11.6
# 370 Both06 B69 S          Both          06          Both06        S           B69 B         69      11.3
# 371 Both06 O72 S          Both          06          Both06        S           O72 O         72      15.0
# 372 Both06 G66 S          Both          06          Both06        S           G66 G         66       9.0
# 373 Both06 O63 S          Both          06          Both06        S           O63 O         63      13.0
# 374 Both06 W67 S          Both          06          Both06        S           W67 W         67      12.1
#     wt_percent_n ⋯ Actual_shell_post_mg Actual_shell_growth_mg Actual_tissue_pre_mg Actual_tissue_post_mg
# 1   8.0          ⋯  724.2940            267.5946               255.80064            357.6060
# 2   7.7          ⋯ 1244.9159            731.2141               307.99824            560.6841
# 3   8.7          ⋯ 1167.8043            489.4289               492.22464            616.9957
# 4   7.4          ⋯  643.3822            259.8359               285.15372            346.0178
# 5   5.3          ⋯ 1739.0950            818.7761               585.68112            762.8050
# 365 0.2          ⋯  675.8419            309.07968              253.33776             374.3581
# 366 0.2          ⋯  570.7042            174.33234              182.42818             291.4958
# 367 0.2          ⋯ 1375.2297            663.91962              572.98992            1191.4703
# 368 0.1          ⋯  505.4681            192.38310              140.31502             207.0319
# 369 0.2          ⋯  414.8976            150.73968              181.94208             219.2024
# 370 0.2          ⋯  266.3747             76.79490              105.22022             157.2253
# 371 0.2          ⋯ 1149.1202            406.61712              499.29694             804.4798
# 372 0.2          ⋯  394.6301            182.24934              133.91926             239.0699
# 373 0.1          ⋯  315.6184             96.74574              124.22732             173.9816
# 374 0.1          ⋯  211.9057             90.25380               91.84808             126.7943
#     Actual_tissue_growth_mg Phase_1_temp Phase_1_DO Phase_2.1_temp Phase_2.1_DO Exclude_all
# 1   101.80540               Ambient      Hyp        Ambient        Norm         NA
# 2   252.68588               Warm         Norm       Ambient        Norm         NA
# 3   124.77106               Ambient      Norm       Ambient        Norm         NA
# 4    60.86406               Warm         Hyp        Ambient        Norm         NA
# 5   177.12386               Warm         Hyp        Ambient        Norm         NA
# 6   254.02810               Warm         Norm       Ambient        Norm         NA
# 7   265.65076               Warm         Norm       Ambient        Norm         NA
# 8   144.22838               Ambient      Norm       Ambient        Norm         NA
# 9    21.39510               Ambient      Hyp        Ambient        Norm         NA
# 10  151.40562               Ambient      Hyp        Ambient        Norm         NA
# 11  119.49846               Ambient      Hyp        Ambient        Norm         NA
# 12  147.55456               Ambient      Norm       Ambient        Norm         NA
# 13  130.18912               Ambient      Norm       Ambient        Norm         NA
# 14  109.73948               Ambient      Norm       Ambient        Norm         NA
# 15  221.15500               Warm         Norm       Ambient        Norm         NA
# 16  256.30256               Warm         Norm       Ambient        Norm         NA
# 17  116.62400               Warm         Hyp        Ambient        Norm         NA
# 18  256.87106               Warm         Hyp        Ambient        Norm         NA
# 19  162.34466               Ambient      Hyp        Ambient        Norm         NA
# 20  213.10364               Ambient      Hyp        Ambient        Norm         NA
# 21  184.85558               Warm         Norm       Ambient        Norm         NA
# 22   66.35154               Ambient      Norm       Ambient        Norm         NA
# 23  146.16828               Warm         Hyp        Ambient        Norm         NA
# 24  206.16844               Warm         Hyp        Ambient        Norm         NA
# 25  166.95120               Warm         Norm       Ambient        Norm         NA
# 26  156.58266               Ambient      Hyp        Ambient        Norm         NA
# 27  273.92454               Warm         Norm       Ambient        Norm         NA
# 28  174.79134               Ambient      Hyp        Ambient        Norm         NA
# 29  110.75896               Ambient      Norm       Ambient        Norm         NA
# 30  171.53812               Ambient      Norm       Ambient        Norm         NA
# ⋮   ⋮                       ⋮            ⋮          ⋮              ⋮            ⋮
# 345 130.59110               Warm         Hyp        Warm           Norm         NA
# 346  85.59854               Warm         Hyp        Warm           Norm         NA
# 347  87.97770               Ambient      Hyp        Warm           Norm         NA
# 348 526.23600               Ambient      Hyp        Warm           Norm         NA
# 349 188.23014               Warm         Norm       Warm           Norm         NA
# 350 366.99578               Warm         Norm       Warm           Norm         NA
# 351  66.38650               Ambient      Norm       Warm           Norm         NA
# 352 152.88662               Ambient      Norm       Warm           Norm         NA
# 353  87.88224               Warm         Norm       Ambient        Hyp          NA
# 354 154.53484               Ambient      Norm       Ambient        Hyp          NA
# 355 184.28320               Warm         Hyp        Ambient        Hyp          NA
# 356  49.81220               Ambient      Norm       Ambient        Hyp          NA
# 357  87.39974               Ambient      Hyp        Ambient        Hyp          NA
# 358 121.23318               Warm         Norm       Warm           Hyp          NA
# 359  35.10390               Ambient      Hyp        Warm           Hyp          NA
# 360  64.02704               Ambient      Hyp        Warm           Hyp          NA
# 361  82.80932               Warm         Norm       Warm           Hyp          NA
# 362  52.12002               Warm         Hyp        Warm           Hyp          NA
# 363  88.97364               Warm         Hyp        Warm           Hyp          NA
# 364  11.36424               Ambient      Norm       Warm           Hyp          NA
# 365 121.02032               Warm         Norm       Warm           Hyp          NA
# 366 109.06766               Ambient      Norm       Warm           Hyp          NA
# 367 618.48038               Ambient      Hyp        Warm           Hyp          NA
# 368  66.71690               Warm         Norm       Warm           Hyp          NA
# 369  37.26032               Ambient      Norm       Warm           Hyp          NA
# 370  52.00510               Ambient      Hyp        Warm           Hyp          NA
# 371 305.18288               Warm         Hyp        Warm           Hyp          NA
# 372 105.15066               Warm         Norm       Warm           Hyp          NA
# 373  49.75426               Warm         Hyp        Warm           Hyp          NA
# 374  34.94620               Ambient      Norm       Warm           Hyp          NA

# %%
#write csv
#write_csv(matched_data, "Phase2_Nutrient/Phase2_nutrient_merged.csv")

# %%
#set contrasts
options(contrasts = c("contr.sum","contr.poly")) #could also be contr.treatment for unequal groups sum
getOption("contrasts")
# Out:
# [1] "contr.sum"  "contr.poly"

# %%
## READ IN MERGED DATA
nutrient_df <- read_csv("XXX.csv")
# Out:
# Error: 'XXX.csv' does not exist in current working directory ('/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC').
# Traceback:
#
# 1. vroom::vroom(file, delim = ",", col_names = col_names, col_types = col_types,
#  .     col_select = {
#  .         {
#  .             col_select
#  .         }
#  .     }, id = id, .name_repair = name_repair, skip = skip, n_max = n_max,
#  .     na = na, quote = quote, comment = comment, skip_empty_rows = skip_empty_rows,
#  .     trim_ws = trim_ws, escape_double = TRUE, escape_backslash = FALSE,
#  .     locale = locale, guess_max = guess_max, show_col_types = show_col_types,
#  .     progress = progress, altrep = lazy, num_threads = num_threads)
# 2. vroom_(file, delim = delim %||% col_types$delim, col_names = col_names,
#  .     col_types = col_types, id = id, skip = skip, col_select = col_select,
#  .     name_repair = .name_repair, na = na, quote = quote, trim_ws = trim_ws,
#  .     escape_double = escape_double, escape_backslash = escape_backslash,
#  .     comment = comment, skip_empty_rows = skip_empty_rows, locale = locale,
#  .     guess_max = guess_max, n_max = n_max, altrep = vroom_altrep(altrep),
#  .     num_threads = num_threads, progress = progress)
# 3. (function (path, write = FALSE)
#  . {
#  .     if (is.raw(path)) {
#  .         return(rawConnection(path, "rb"))
#  .     }
#  .     if (!is.character(path)) {
#  .         return(path)
#  .     }
#  .     if (is_url(path)) {
#  .         if (requireNamespace("curl", quietly = TRUE)) {
#  .             con <- curl::curl(path)
#  .         }
#  .         else {
#  .             inform("`curl` package not installed, falling back to using `url()`")
#  .             con <- url(path)
#  .         }
#  .         ext <- tolower(tools::file_ext(path))
#  .         return(switch(ext, zip = , bz2 = , xz = {
#  .             close(con)
#  .             stop("Reading from remote `", ext, "` compressed files is not supported,\n",
#  .                 "  download the files locally first.", call. = FALSE)
#  .         }, gz = gzcon(con), con))
#  .     }
#  .     path <- enc2utf8(path)
#  .     p <- split_path_ext(basename_utf8(path))
#  .     if (write) {
#  .         path <- normalizePath_utf8(path, mustWork = FALSE)
#  .     }
#  .     else {
#  .         path <- check_path(path)
#  .     }
#  .     if (is_installed("archive")) {
#  .         formats <- archive_formats(p$extension)
#  .         extension <- p$extension
#  .         while (is.null(formats) && nzchar(extension)) {
#  .             extension <- split_path_ext(extension)$extension
#  .             formats <- archive_formats(extension)
#  .         }
#  .         if (!is.null(formats)) {
#  .             p$extension <- extension
#  .             if (write) {
#  .                 if (is.null(formats[[1]])) {
#  .                   return(archive::file_write(path, filter = formats[[2]]))
#  .                 }
#  .                 return(archive::archive_write(path, p$path, format = formats[[1]],
#  .                   filter = formats[[2]]))
#  .             }
#  .             if (is.null(formats[[1]])) {
#  .                 return(archive::file_read(path, filter = formats[[2]]))
#  .             }
#  .             return(archive::archive_read(path, format = formats[[1]],
#  .                 filter = formats[[2]]))
#  .         }
#  .     }
#  .     if (!write) {
#  .         compression <- detect_compression(path)
#  .     }
#  .     else {
#  .         compression <- NA
#  .     }
#  .     if (is.na(compression)) {
#  .         compression <- tools::file_ext(path)
#  .     }
#  .     if (write && compression == "zip") {
#  .         stop("Can only read from, not write to, .zip", call. = FALSE)
#  .     }
#  .     switch(compression, gz = gzfile(path, ""), bz2 = bzfile(path,
#  .         ""), xz = xzfile(path, ""), zip = zipfile(path, ""),
#  .         if (!has_trailing_newline(path)) {
#  .             file(path)
#  .         } else {
#  .             path
#  .         })
#  . })("XXX.csv")
# 4. check_path(path)
# 5. stop("'", path, "' does not exist", if (!is_absolute_path(path)) {
#  .     paste0(" in current working directory ('", getwd(), "')")
#  . }, ".", call. = FALSE)
# 6. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "'XXX.csv' does not exist in current working directory ('/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC').",
#  .     base::quote(NULL))

# %% [markdown]
# # Tissue

# %% [markdown]
# ## 1. % Nitrogen in Tissue

# %%
colnames(nutrient_df)
unique(nutrient_df$Tissue_type)
# Out:
#  [1] "Sample_Name_Nutrients"   "Phase_2_treat"           "Phase_2_rep"             "Phase_2_rep_R"
#  [5] "Tissue_type"             "Tag"                     "Tag_color"               "Tag_num"
#  [9] "Linear corr d15N"        "wt_percent_n"            "N_Notes"                 "Linear corr d13C"
# [13] "wt_percent_c"            "C_Notes"                 "N_Exclude"               "...16"
# [17] "Sample_Name"             "Phase_1_treat"           "Phase_1_rep"             "Phase_1_rep_R"
# [21] "Notes_pre"               "Notes_post"              "Actual_shell_pre_mg"     "Actual_shell_post_mg"
# [25] "Actual_shell_growth_mg"  "Actual_tissue_pre_mg"    "Actual_tissue_post_mg"   "Actual_tissue_growth_mg"
# [29] "Phase_1_temp"            "Phase_1_DO"              "Phase_2.1_temp"          "Phase_2.1_DO"
# [33] "Exclude_all"
# [1] "T" "S"

# %%
#filter data
Tissue_Nitrogen <- nutrient_df%>%
filter(Tissue_type == "T")%>%
filter(is.na(N_Exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nitrogen %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Tissue (%)") +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue nitrogen
m1 <- lmer(wt_percent_n~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nitrogen, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         2.426589e+03 1  14.128743 0.0000
# Phase_1_DO                                          3.690382e-01 1   9.444754 0.5579
# Phase_1_temp                                        2.545930e+00 1   9.462947 0.1434
# Phase_2.1_temp                                      1.970548e-03 1  18.965619 0.9651
# Phase_2.1_DO                                        5.419627e+00 1  18.994435 0.0311
# Phase_1_DO:Phase_1_temp                             2.801160e-02 1   9.460570 0.8706
# Phase_1_DO:Phase_2.1_temp                           1.018302e-01 1  18.598042 0.7532
# Phase_1_temp:Phase_2.1_temp                         1.754751e+00 1  18.611492 0.2013
# Phase_1_DO:Phase_2.1_DO                             1.548781e+00 1  18.672791 0.2287
# Phase_1_temp:Phase_2.1_DO                           1.154099e+00 1  18.690577 0.2964
# Phase_2.1_temp:Phase_2.1_DO                         2.463449e+00 1  18.976559 0.1330
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.485529e-01 1  18.612863 0.7043
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                6.380859e-01 1  18.682797 0.4344
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              8.260332e-03 1  18.637453 0.9286
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            4.038412e-01 1  18.650143 0.5328
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 7.985709e-01 1  18.645157 0.3829

# %%
#diagnostics
leveneTest(wt_percent_n~Phase_1_treat*Phase_2_treat, Tissue_Nitrogen) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value Pr(>F)
# group  15 1.47417 0.1196284
#       170      NA        NA
# Plot with title “Normal Q-Q Plot”

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean    SE   df lower.CL upper.CL
#  Hyp            6.64 0.198 18.0     6.22     7.05
#  Norm           7.30 0.203 17.4     6.87     7.72
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate    SE df t.ratio p.value
#  Hyp - Norm    -0.66 0.283 19  -2.328  0.0311
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_Nitrogen %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean = mean(wt_percent_n, na.rm = TRUE),
    se = std.error(wt_percent_n, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Nitrogen in Tissue (%)") +
  ylim(6,8)+
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
(7.30/6.64)/7.30
# Out:
# [1] 0.1506024

# %% [markdown]
# ## 2. % Carbon in Tissue

# %%
#filter data
Tissue_Carbon <- nutrient_df%>%
filter(Tissue_type == "T") #%>%
#filter(is.na(C_exclude))

# %%
#format for jupyter
options(repr.plot.width = 12, repr.plot.height = 6)

#tissue carbon
summary_stats_t <- Tissue_Carbon %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_c, na.rm = TRUE),
    se_growth = std.error(wt_percent_c, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon
    #log transform to pass levene test, results are the same
m2 <- lmer(log(wt_percent_c)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Carbon, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         3.503009e+04 1  13.67815 0.0000
# Phase_1_DO                                          6.813028e-02 1  11.53027 0.7987
# Phase_1_temp                                        7.223891e-01 1  11.04485 0.4134
# Phase_2.1_temp                                      1.337238e-01 1  18.48808 0.7188
# Phase_2.1_DO                                        1.846691e+01 1  18.59466 0.0004
# Phase_1_DO:Phase_1_temp                             1.235809e+00 1  11.04145 0.2899
# Phase_1_DO:Phase_2.1_temp                           1.178527e-02 1  18.25056 0.9147
# Phase_1_temp:Phase_2.1_temp                         1.250447e+00 1  18.20454 0.2780
# Phase_1_DO:Phase_2.1_DO                             3.285482e-01 1  18.38248 0.5735
# Phase_1_temp:Phase_2.1_DO                           2.005945e-03 1  18.34983 0.9648
# Phase_2.1_temp:Phase_2.1_DO                         3.119269e-01 1  18.55019 0.5832
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              8.894539e-01 1  18.20673 0.3580
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                7.123598e-01 1  18.33898 0.4095
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              4.090986e-02 1  18.33759 0.8419
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.278657e+00 1  18.29555 0.1482
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 5.745701e-01 1  18.29296 0.4581

# %%
#posthocs
options(width = 120)
emmeans(m2,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean     SE   df lower.CL upper.CL
#  Hyp            3.92 0.0279 18.8     3.86     3.98
#  Norm           3.75 0.0284 17.5     3.69     3.81
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate     SE   df t.ratio p.value
#  Hyp - Norm    0.166 0.0386 18.6   4.297  0.0004
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.

# %%
exp(3.92)
# Out:
# [1] 50.40044

# %%
exp(3.75)
# Out:
# [1] 42.52108

# %%
(50.4-42.5)/50.4
# Out:
# [1] 0.156746

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_Carbon %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean = mean(wt_percent_c, na.rm = TRUE),
    se = std.error(wt_percent_c, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Carbon in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
ylim(40,55)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(log(wt_percent_c)~Phase_1_treat*Phase_2_treat, Tissue_Carbon)
m1.e <- residuals(m2) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.9787984 0.4796317
#       171        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 3. Carbon:Nitrogen in Tissue

# %%
#filter data
Tissue_CN <- nutrient_df%>%
filter(Tissue_type == "T")%>%
filter(is.na(N_Exclude)) #%>%
#filter(is.na(c_exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue c:n
summary_stats_t <- Tissue_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean((wt_percent_c/wt_percent_n), na.rm = TRUE),
    se_growth = std.error((wt_percent_c/wt_percent_n), na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon:nitrogen
    #log transform to pass levene test, results are the same
m3 <- lmer((wt_percent_c/wt_percent_n)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_CN, REML=TRUE)
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         3.951927e+02 1  11.990021 0.0000
# Phase_1_DO                                          3.672268e-01 1  11.174214 0.5566
# Phase_1_temp                                        5.114462e-01 1   9.470198 0.4918
# Phase_2.1_temp                                      4.590007e-01 1  18.794988 0.5063
# Phase_2.1_DO                                        1.411845e+01 1  18.841045 0.0013
# Phase_1_DO:Phase_1_temp                             8.529164e-01 1   9.469784 0.3787
# Phase_1_DO:Phase_2.1_temp                           4.216433e-03 1  18.732559 0.9489
# Phase_1_temp:Phase_2.1_temp                         4.762592e-01 1  18.617736 0.4986
# Phase_1_DO:Phase_2.1_DO                             2.554223e-02 1  18.786624 0.8747
# Phase_1_temp:Phase_2.1_DO                           9.618939e-01 1  18.692974 0.3392
# Phase_2.1_temp:Phase_2.1_DO                         4.881288e-01 1  18.815460 0.4933
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              6.148351e-01 1  18.617979 0.4428
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.082034e+00 1  18.691634 0.3115
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.050808e-01 1  18.757935 0.7494
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            6.558912e-01 1  18.653582 0.4282
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.488160e+00 1  18.652725 0.2377

# %%
#posthocs
options(width = 120)
emmeans(m3,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean    SE   df lower.CL upper.CL
#  Hyp            9.21 0.545 17.3     8.06    10.36
#  Norm           6.28 0.558 16.3     5.10     7.46
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the ( (not the response) scale.
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate   SE   df t.ratio p.value
#  Hyp - Norm     2.93 0.78 18.8   3.757  0.0013
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Note: contrasts are still on the ( scale. Consider using
#       regrid() if you want contrasts of back-transformed estimates.
# Degrees-of-freedom method: kenward-roger

# %%
(9.21-6.28)/9.21
# Out:
# [1] 0.3181325

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_CN %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean = mean((wt_percent_c/wt_percent_n), na.rm = TRUE),
    se = std.error((wt_percent_c/wt_percent_n), na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Carbon:Nitrogen in Tissue") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest((wt_percent_c/wt_percent_n)~Phase_1_treat*Phase_2_treat, Tissue_CN) 
m1.e <- residuals(m3)
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 1.805042 0.03734251
#       170       NA         NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 4. Mg Carbon and Nitrogen in Tissue

# %%
# Read in growth dataset
setwd("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC")
weight_df <- read_csv("Year_2_Data/growth_YEAR2_weights_merged.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 572 Columns: 45
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (22): Sample_Name, Phase_1_DO, Phase_1_temp, Phase_2.1_DO, Phase_2.1_temp, Phase_1_treat, Phase_2_treat, Phase_1...
# dbl (23): ...1, Actual_shell_pre_mg, Actual_tissue_pre_mg, Actual_shell_post_mg, Actual_tissue_post_mg, Actual_shell...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#calculate % N averages Tissue

summary_stats_t <- Tissue_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  summarize(
    mean_N = mean(wt_percent_n, na.rm = TRUE),
    mean_C = mean(wt_percent_c, na.rm = TRUE))

print(summary_stats_t)
# Out:
# `summarise()` has regrouped the output.
# ℹ Summaries were computed grouped by Phase_1_treat and Phase_2_treat.
# ℹ Output is grouped by Phase_1_treat.
# ℹ Use `summarise(.groups = "drop_last")` to silence this message.
# ℹ Use `summarise(.by = c(Phase_1_treat, Phase_2_treat))` for per-operation
#   grouping (`?dplyr::dplyr_by`) instead.
# # A tibble: 16 × 4
# # Groups:   Phase_1_treat [4]
#    Phase_1_treat Phase_2_treat mean_N mean_C
#    <chr>         <chr>          <dbl>  <dbl>
#  1 Both          Both            6.27   54.5
#  2 Both          Cont            6.66   42.2
#  3 Both          Hyp             6.32   52.6
#  4 Both          Warm            7.57   47.9
#  5 Cont          Both            6.22   51.8
#  6 Cont          Cont            7.36   44.6
#  7 Cont          Hyp             7.28   48.6
#  8 Cont          Warm            7.93   43.0
#  9 Hyp           Both            6.79   51.9
# 10 Hyp           Cont            7.04   44.2
# 11 Hyp           Hyp             7.43   50.0
# 12 Hyp           Warm            7.1    44.7
# 13 Warm          Both            6.39   51.2
# 14 Warm          Cont            7.21   41.6
# 15 Warm          Hyp             6.38   50.7
# 16 Warm          Warm            7.49   43.3

# %%
Tissue_Nutrients <- weight_df %>%
  filter(Exclude_year2 != "Y" | is.na(Exclude_year2)) %>%
  left_join(
    summary_stats_t,
    by = c("Phase_1_treat", "Phase_2_treat")) %>%
  mutate(mgN_tissue_P2 = (Actual_tissue_post_mg * mean_N) / 100)%>%
  mutate(mgC_tissue_P2 = (Actual_tissue_post_mg * mean_C) / 100)

View(Tissue_Nutrients)
# Out:
#     ...1 Sample_Name            Phase_1_DO Phase_1_temp Phase_2.1_DO Phase_2.1_temp Phase_1_treat Phase_2_treat
# 1    2   2024_Both01_Both02_O14 Hyp        Warm         Hyp          Warm           Both          Both
# 2    3   2024_Both01_Both03_O26 Hyp        Warm         Hyp          Warm           Both          Both
# 3    4   2024_Both01_Both05_O49 Hyp        Warm         Hyp          Warm           Both          Both
# 4    5   2024_Both01_Both05_O50 Hyp        Warm         Hyp          Warm           Both          Both
# 5    6   2024_Both01_Both06_O61 Hyp        Warm         Hyp          Warm           Both          Both
# 6    8   2024_Both01_Cont02_O13 Hyp        Warm         Norm         Ambient        Both          Cont
# 7    9   2024_Both01_Cont02_O14 Hyp        Warm         Norm         Ambient        Both          Cont
# 8   10   2024_Both01_Cont04_O38 Hyp        Warm         Norm         Ambient        Both          Cont
# 9   11   2024_Both01_Cont06_O61 Hyp        Warm         Norm         Ambient        Both          Cont
# 10  12   2024_Both01_Cont06_O62 Hyp        Warm         Norm         Ambient        Both          Cont
# 11  13   2024_Both01_Hyp02_O13  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 12  14   2024_Both01_Hyp02_O14  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 13  15   2024_Both01_Hyp03_O25  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 14  16   2024_Both01_Hyp03_O26  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 15  17   2024_Both01_Hyp04_O38  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 16  19   2024_Both01_Warm02_O13 Hyp        Warm         Norm         Warm           Both          Warm
# 17  20   2024_Both01_Warm02_O14 Hyp        Warm         Norm         Warm           Both          Warm
# 18  22   2024_Both01_Warm03_O26 Hyp        Warm         Norm         Warm           Both          Warm
# 19  23   2024_Both01_Warm06_O61 Hyp        Warm         Norm         Warm           Both          Warm
# 20  24   2024_Both01_Warm06_O62 Hyp        Warm         Norm         Warm           Both          Warm
# 21  25   2024_Both02_Both02_O15 Hyp        Warm         Hyp          Warm           Both          Both
# 22  26   2024_Both02_Both02_O16 Hyp        Warm         Hyp          Warm           Both          Both
# 23  27   2024_Both02_Both03_O28 Hyp        Warm         Hyp          Warm           Both          Both
# 24  28   2024_Both02_Both04_O39 Hyp        Warm         Hyp          Warm           Both          Both
# 25  29   2024_Both02_Both06_O63 Hyp        Warm         Hyp          Warm           Both          Both
# 26  33   2024_Both02_Cont03_O28 Hyp        Warm         Norm         Ambient        Both          Cont
# 27  34   2024_Both02_Cont05_O51 Hyp        Warm         Norm         Ambient        Both          Cont
# 28  35   2024_Both02_Cont05_O52 Hyp        Warm         Norm         Ambient        Both          Cont
# 29  36   2024_Both02_Cont06_O64 Hyp        Warm         Norm         Ambient        Both          Cont
# 30  39   2024_Both02_Hyp03_O28  Hyp        Warm         Hyp          Ambient        Both          Hyp
# ⋮   ⋮    ⋮                      ⋮          ⋮            ⋮            ⋮              ⋮             ⋮
# 444 510  2024_Warm05_Hyp02_G21  Norm       Warm         Hyp          Ambient        Warm          Hyp
# 445 511  2024_Warm05_Hyp03_G33  Norm       Warm         Hyp          Ambient        Warm          Hyp
# 446 512  2024_Warm05_Hyp03_G34  Norm       Warm         Hyp          Ambient        Warm          Hyp
# 447 513  2024_Warm05_Hyp05_G58  Norm       Warm         Hyp          Ambient        Warm          Hyp
# 448 514  2024_Warm05_Hyp06_G70  Norm       Warm         Hyp          Ambient        Warm          Hyp
# 449 515  2024_Warm05_Warm01_G10 Norm       Warm         Norm         Warm           Warm          Warm
# ⋮   ⋮                             ⋮              ⋮             ⋮        ⋮        ⋮             ⋮
# 444  434.53232                    0.5326668      NA            6.375000 50.67500 21.460248     170.58793
# 445  417.95880                    0.4271244      NA            6.375000 50.67500 19.381464     154.06363
# 446  452.21042                    0.3973766      NA            6.375000 50.67500 17.366934     138.05010
# 447  158.34738                    0.6086711      NA            6.375000 50.67500 17.314459     137.63298
# 448  260.23410                    0.4521361      NA            6.375000 50.67500 23.456652     186.45739
# 449  121.33414                    0.6787322      NA            7.490909 43.33636 11.193589      64.75709
# 450   97.60396                    0.3234103      NA            7.490909 43.33636 24.020309     138.96215
# 451  613.59724                    0.4896623      NA            7.490909 43.33636 22.350068     129.29948
# 452  211.57044                    0.6908884      NA            6.391667 51.15000 12.251581      98.04460
# 453  575.54124                    0.5756801      NA            6.391667 51.15000 34.894738     279.24889
# 454  181.21888                    0.5279023      NA            6.391667 51.15000 13.433830     107.50567
# 455  110.71736                    0.2918356      NA            6.391667 51.15000 20.428567     163.48180
# 456  144.76166                    0.4568944      NA            6.391667 51.15000 28.519201     228.22798
# 457  474.46540                    0.3896616      NA            7.208333 41.63333 25.151604     145.26868
# 458  759.32206                    0.6038933      NA            7.208333 41.63333 40.415980     233.43149
# 459  727.70340                    0.6574861      NA            7.208333 41.63333 28.185016     162.78883
# 460  610.98400                    0.5214438      NA            7.208333 41.63333 23.036798     133.05415
# 461 1359.37902                    0.5963180      NA            7.208333 41.63333 19.471779     112.46359
# 462  498.79256                    0.5150648      NA            7.208333 41.63333 15.800655      91.26020
# 463  291.53752                    0.4211373      NA            6.375000 50.67500 21.386237     169.99962
# 464  266.61150                    0.3721086      NA            6.375000 50.67500  9.255535      73.57243
# 465   52.48130                    0.2131491      NA            6.375000 50.67500  9.641530      76.64071
# 466   66.26080                    0.4755360      NA            6.375000 50.67500 14.029651     111.52197
# 467 1979.25660                    0.6575509      NA            6.375000 50.67500 22.669311     180.19880
# 468  436.25784                    0.4356731      NA            6.375000 50.67500 27.003749     214.65333
# 469  726.18014                    0.4969344      NA            7.490909 43.33636 34.367729     198.82399
# 470 1043.03112                    0.6375617      NA            7.490909 43.33636 55.544526     321.33587
# 471  380.98624                    0.3406183      NA            7.490909 43.33636 23.420219     135.49052
# 472  387.70464                    0.5689028      NA            7.490909 43.33636 31.658162     183.14862
# 473  172.52246                    0.3781915      NA            7.490909 43.33636 14.409149      83.35972

# %% [markdown]
# ### 4.1 Mg Nitrogen Analysis

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgN_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgN_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue nitrogen
    #this one is not estimating means correctly when log transformed
    #fails levene test
m1 <- lmer(mgN_tissue_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         342.21172830 1  22.86357 0.0000
# Phase_1_DO                                            0.99128015 1  20.76558 0.3309
# Phase_1_temp                                          1.44587523 1  17.69030 0.2450
# Phase_2.1_temp                                        0.15509605 1  19.46840 0.6980
# Phase_2.1_DO                                          3.17780514 1  19.51075 0.0902
# Phase_1_DO:Phase_1_temp                               0.02638518 1  17.69512 0.8728
# Phase_1_DO:Phase_2.1_temp                             0.11890998 1  19.00226 0.7340
# Phase_1_temp:Phase_2.1_temp                           0.18204665 1  18.73279 0.6745
# Phase_1_DO:Phase_2.1_DO                               1.37541354 1  19.08406 0.2553
# Phase_1_temp:Phase_2.1_DO                             3.74269543 1  18.83225 0.0682
# Phase_2.1_temp:Phase_2.1_DO                           0.63986958 1  19.49698 0.4334
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp                0.05507507 1  18.69140 0.8170
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                  0.09363727 1  18.79802 0.7630
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO                2.24319611 1  19.07669 0.1506
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO              2.89374620 1  18.84615 0.1054
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO   5.00730183 1  18.80560 0.0375

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Hyp            22.6 1.82 21.6     18.9     26.4
#  Norm           27.1 1.86 22.0     23.3     31.0
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate   SE   df t.ratio p.value
#  Hyp - Norm    -4.48 2.51 19.5  -1.783  0.0902
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %%
(27.1-22.6)/27.1
# Out:
# [1] 0.1660517

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_Nutrients %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean = mean(mgN_tissue_P2, na.rm = TRUE),
    se = std.error(mgN_tissue_P2, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Nitrogen in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
(3.24-2.88)/3.24
# Out:
# [1] 0.1111111

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# $emmeans
#  Phase_1_DO Phase_1_temp Phase_2.1_temp Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Hyp        Ambient      Ambient        Hyp            23.5 3.73 65.4     16.1     31.0
#  Norm       Ambient      Ambient        Hyp            29.1 3.67 63.3     21.7     36.4
#  Hyp        Warm         Ambient        Hyp            19.8 3.62 60.1     12.6     27.0
#  Norm       Warm         Ambient        Hyp            20.2 3.63 60.2     13.0     27.5
#  Hyp        Ambient      Warm           Hyp            26.5 3.60 58.7     19.3     33.7
#  Norm       Ambient      Warm           Hyp            20.6 3.58 56.3     13.5     27.8
#  Hyp        Warm         Warm           Hyp            20.8 3.58 57.4     13.6     28.0
#  Norm       Warm         Warm           Hyp            20.6 3.66 61.7     13.3     27.9
#  Hyp        Ambient      Ambient        Norm           24.2 3.73 60.7     16.8     31.7
#  Norm       Ambient      Ambient        Norm           23.5 3.99 68.9     15.6     31.5
#  Hyp        Warm         Ambient        Norm           25.1 3.79 56.6     17.5     32.7
#  Norm       Warm         Ambient        Norm           29.6 3.78 64.1     22.1     37.2
#  Hyp Warm Ambient Norm - Hyp Ambient Warm Norm          0.1761 5.22 57.1   0.034  0.9732
#  Hyp Warm Ambient Norm - Norm Ambient Warm Norm        -9.5042 5.26 59.1  -1.806  0.0761
#  Hyp Warm Ambient Norm - Hyp Warm Warm Norm            -1.5841 5.01 52.6  -0.316  0.7531
#  Hyp Warm Ambient Norm - Norm Warm Warm Norm           -3.2608 5.24 58.3  -0.622  0.5365
#  Norm Warm Ambient Norm - Hyp Ambient Warm Norm         4.7354 5.21 60.8   0.909  0.3670
#  Norm Warm Ambient Norm - Norm Ambient Warm Norm       -4.9448 5.26 63.0  -0.940  0.3506
#  Norm Warm Ambient Norm - Hyp Warm Warm Norm            2.9753 5.19 60.1   0.574  0.5684
#  Norm Warm Ambient Norm - Norm Warm Warm Norm           1.2986 5.06 58.5   0.257  0.7982
#  Hyp Ambient Warm Norm - Norm Ambient Warm Norm        -9.6803 4.37 40.2  -2.215  0.0325
#  Hyp Ambient Warm Norm - Hyp Warm Warm Norm            -1.7601 3.88 37.6  -0.454  0.6527
#  Hyp Ambient Warm Norm - Norm Warm Warm Norm           -3.4368 4.35 39.3  -0.791  0.4338
#  Norm Ambient Warm Norm - Hyp Warm Warm Norm            7.9201 4.34 39.2   1.824  0.0758
#  Norm Ambient Warm Norm - Norm Warm Warm Norm           6.2434 4.01 42.5   1.557  0.1269
#  Hyp Warm Warm Norm - Norm Warm Warm Norm              -1.6767 4.32 38.5  -0.388  0.6999
#
# Degrees-of-freedom method: kenward-roger

# %%
        cont warm comparisons:
Hyp Ambient Warm Norm - Norm Ambient Warm Norm        -9.6803 4.37 40.2  -2.215  0.0325
    hyp warm - cont warm
Norm Ambient Ambient Norm - Norm Ambient Warm Norm   -11.0574 5.23 61.7  -2.114  0.0385
    cont cont - cont warm
Norm Warm Warm Hyp - Norm Ambient Warm Norm          -13.9855 5.17 61.8  -2.705  0.0088
    warm both - cont warm
Hyp Warm Warm Hyp - Norm Ambient Warm Norm           -13.7876 5.12 59.6  -2.695  0.0091
    both both - cont warm
Norm Ambient Warm Hyp - Norm Ambient Warm Norm       -13.9494 4.94 56.0  -2.825  0.0065
    cont both - cont warm
Norm Warm Ambient Hyp - Norm Ambient Warm Norm       -14.3652 5.15 61.0  -2.790  0.0070
    warm hyp - cont warm
Hyp Warm Ambient Hyp - Norm Ambient Warm Norm        -14.7909 5.14 60.9  -2.876  0.0055
    both hyp - cont warm
Hyp Ambient Ambient Hyp - Norm Ambient Warm Norm     -11.0441 5.22 63.6  -2.116  0.0383
    hyp hyp - cont warm

Norm Ambient Ambient Hyp - Hyp Warm Ambient Hyp        9.2708 4.41 41.7   2.102  0.0416
    cont hyp - both hyp
Norm Ambient Ambient Hyp - Norm Warm Ambient Hyp       8.8452 4.02 43.2   2.198  0.0334
    cont hyp - warm hyp   interesting !

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_Nutrients %>%
  group_by(Phase_1_DO) %>%
  mutate(
    mean = mean(mgN_tissue_P2, na.rm = TRUE),
    se = std.error(mgN_tissue_P2, na.rm = TRUE))

#reorder
summary_stats$Phase_1_DO <- factor(summary_stats$Phase_1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_1_DO, y = mean, color = Phase_1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 1 DO", y = "Nitrogen in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_temp:Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Ambient      Hyp            24.9 2.11 33.2     20.6     29.2
#  Warm         Hyp            20.3 2.10 32.7     16.1     24.6
#  Ambient      Norm           26.8 2.16 34.1     22.4     31.2
#  Warm         Norm           27.4 2.14 32.8     23.1     31.8
#
# Results are averaged over the levels of: Phase_1_DO, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                   estimate   SE   df t.ratio p.value
#  Ambient Hyp - Warm Hyp        4.584 2.11 22.2   2.173  0.0407
#  Ambient Hyp - Ambient Norm   -1.881 2.86 30.2  -0.657  0.5163
#  Ambient Hyp - Warm Norm      -2.495 3.00 33.0  -0.831  0.4120
#  Warm Hyp - Ambient Norm      -6.465 3.01 33.4  -2.148  0.0391
#  Warm Hyp - Warm Norm         -7.079 2.84 29.2  -2.497  0.0184
#  Ambient Norm - Warm Norm     -0.614 2.15 21.7  -0.286  0.7775
#
# Results are averaged over the levels of: Phase_1_DO, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %%
(3.07 -2.91)/3.07
# Out:
# [1] 0.05211726

# %%
(3.16-2.91)/3.16
# Out:
# [1] 0.07911392

# %%
(3.21-2.91)/3.21
# Out:
# [1] 0.09345794

# %%
#format for jupyter
options(repr.plot.width = 10, repr.plot.height = 6)

#tissue nitrogen Phase_1_temp:Phase_2.1_DO
summary_stats_t <- Tissue_Nutrients %>%
  group_by(Phase_1_temp, Phase_2.1_DO) %>%
  mutate(
    mean = mean(mgN_tissue_P2, na.rm = TRUE),
    se = std.error(mgN_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_temp <- factor(summary_stats_t$Phase_1_temp, 
                                        levels = c("Ambient", "Warm"))
summary_stats_t$Phase_2.1_DO <- factor(summary_stats_t$Phase_2.1_DO, 
                                        levels = c("Norm", "Hyp"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_temp, y = mean, color = Phase_1_temp)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.1, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2.1_DO), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Norm" = "Normoxic")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Warm" = "#B00149", "Ambient" = "darkblue")) +
  labs(x = "Phase 1 Temperature", y = "Nitrogen in Tissue (Mg)") +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
ylim(15, 30)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(mgN_tissue_P2~Phase_1_treat*Phase_2_treat, Tissue_Nutrients) 
m1.e <- residuals(m1)
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 1.962718 0.01640345
#       457       NA         NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ### 4.2 Mg Carbon Analysis

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgC_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon
m1 <- lmer(mgC_tissue_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+ 
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         3.187556e+02 1  22.59911 0.0000
# Phase_1_DO                                          1.055446e-02 1  20.69719 0.9192
# Phase_1_temp                                        1.507971e-01 1  16.17978 0.7028
# Phase_2.1_temp                                      4.290833e-01 1  19.51220 0.5201
# Phase_2.1_DO                                        4.419917e-01 1  19.55003 0.5139
# Phase_1_DO:Phase_1_temp                             2.019138e-01 1  16.19027 0.6591
# Phase_1_DO:Phase_2.1_temp                           3.708324e-01 1  19.02847 0.5498
# Phase_1_temp:Phase_2.1_temp                         4.987915e-01 1  18.63718 0.4888
# Phase_1_DO:Phase_2.1_DO                             2.474263e-01 1  19.10587 0.6246
# Phase_1_temp:Phase_2.1_DO                           1.381952e+00 1  18.73786 0.2545
# Phase_2.1_temp:Phase_2.1_DO                         6.352269e-03 1  19.53697 0.9373
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              4.264886e-03 1  18.59883 0.9486
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.492368e-02 1  18.70845 0.8762
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.305201e+00 1  19.09768 0.2674
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            4.328251e-01 1  18.76423 0.5186
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.644147e+00 1  18.72670 0.1206

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp Phase_2.1_temp Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Ambient      Ambient        Hyp             167 6.08 35.2      154      179
#  Warm         Ambient        Hyp             167 5.90 32.0      155      179
#  Ambient      Warm           Hyp             185 5.80 29.6      173      196
#  Warm         Warm           Hyp             180 5.88 31.6      168      192
#  Ambient      Ambient        Norm            167 6.36 34.4      154      180
#  Warm         Ambient        Norm            152 6.17 30.6      140      165
#  Ambient      Warm           Norm            159 5.89 31.7      147      171
#  Warm         Warm           Norm            168 5.82 30.4      156      180
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                   estimate   SE   df t.ratio p.value
#  Ambient Ambient Hyp - Warm Ambient Hyp       -0.715 6.64 19.6  -0.108  0.9154
#  Ambient Ambient Hyp - Ambient Warm Hyp      -17.902 8.40 33.4  -2.131  0.0405
#  Ambient Ambient Hyp - Warm Warm Hyp         -13.838 8.46 33.5  -1.635  0.1114
#  Ambient Ambient Hyp - Ambient Ambient Norm   -0.179 8.81 35.8  -0.020  0.9839
#  Ambient Ambient Hyp - Warm Ambient Norm      14.436 8.66 32.7   1.668  0.1049
#  Ambient Ambient Hyp - Ambient Warm Norm       7.534 8.46 34.3   0.891  0.3792
#  Ambient Ambient Hyp - Warm Warm Norm         -1.470 8.42 32.8  -0.175  0.8624
#  Warm Ambient Hyp - Ambient Warm Hyp         -17.187 8.27 30.8  -2.078  0.0462
#  Warm Ambient Hyp - Warm Warm Hyp            -13.123 8.33 32.8  -1.575  0.1248
#  Warm Ambient Hyp - Ambient Ambient Norm       0.536 8.67 33.2   0.062  0.9511
#  Warm Ambient Hyp - Warm Ambient Norm         15.151 8.54 32.2   1.774  0.0855
#  Warm Ambient Hyp - Ambient Warm Norm          8.249 8.34 31.9   0.989  0.3299
#  Warm Ambient Hyp - Warm Warm Norm            -0.756 8.28 32.1  -0.091  0.9279
#  Ambient Warm Hyp - Warm Warm Hyp              4.064 6.38 17.2   0.637  0.5328
#  Ambient Warm Hyp - Ambient Ambient Norm      17.722 8.61 33.1   2.058  0.0476
#  Ambient Warm Hyp - Warm Ambient Norm         32.338 8.47 30.2   3.819  0.0006
#  Ambient Warm Hyp - Ambient Warm Norm         25.435 8.27 31.7   3.077  0.0043
#  Ambient Warm Hyp - Warm Warm Norm            16.431 8.21 30.0   2.000  0.0546
#  Warm Warm Hyp - Ambient Ambient Norm         13.659 8.65 32.9   1.578  0.1241
#  Warm Warm Hyp - Warm Ambient Norm            28.274 8.53 32.0   3.315  0.0023
#  Warm Warm Hyp - Ambient Warm Norm            21.372 8.33 31.7   2.567  0.0152
#  Warm Warm Hyp - Warm Warm Norm               12.367 8.27 32.0   1.495  0.1448
#  Ambient Ambient Norm - Warm Ambient Norm     14.615 6.89 18.0   2.122  0.0480
#  Ambient Ambient Norm - Ambient Warm Norm      7.713 8.68 34.1   0.889  0.3803
#  Ambient Ambient Norm - Warm Warm Norm        -1.291 8.62 32.5  -0.150  0.8818
#  Warm Ambient Norm - Ambient Warm Norm        -6.902 8.52 31.1  -0.810  0.4239
#  Warm Ambient Norm - Warm Warm Norm          -15.907 8.48 31.3  -1.876  0.0700
#  Ambient Warm Norm - Warm Warm Norm           -9.004 6.41 17.6  -1.406  0.1772
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger

# %%
#format display for jupyter
options(repr.plot.width = 12, repr.plot.height = 6)

# plot Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO tissue
summary_stats_t <- Tissue_Nutrients%>%
  group_by(Phase_1_temp, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgC_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_temp <- factor(summary_stats_t$Phase_1_temp, 
                                       levels = c("Ambient", "Warm"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp",  "Both"))

#plot with mean and SD
ggplot(summary_stats_t, aes(x = Phase_1_temp, y = mean_growth, color = Phase_1_temp)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 16) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(
    vars(Phase_2_treat),
    labeller = as_labeller(c(
      "Hyp" = "Hypoxic",
      "Cont" = "Control",
      "Warm" = "Warm",
      "Both" = "Both")), scales = "fixed", nrow = 1) +
  scale_color_manual(values = c("Warm" = "#B00149", "Ambient" = "darkblue")) +
  labs(x = "Phase 1 Temperature", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
ylim(120, 210)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
 Ambient Ambient Hyp - Ambient Ambient Norm  -14.574 6.93 25.5  -2.104  0.0454
    amb hyp - amb cont
 Ambient Ambient Hyp - Ambient Warm Norm     -18.668 6.92 25.5  -2.696  0.0122
    amb hyp - amb warm
 Warm Ambient Hyp - Ambient Ambient Norm     -16.139 6.93 25.4  -2.329  0.0281
    warm hyp - amb cont
 Warm Ambient Hyp - Warm Ambient Norm        -15.455 6.96 26.0  -2.222  0.0352
    warm hyp - warm cont
 Warm Ambient Hyp - Ambient Warm Norm        -20.233 6.93 25.4  -2.920  0.0072
    warm hyp - amb warm
 Ambient Ambient Norm - Warm Warm Norm        14.269 6.93 25.4   2.059  0.0498
    amb cont - warm warm
 Ambient Warm Norm - Warm Warm Norm           18.363 3.51 18.4   5.233 <0.0001
    amb warm - warm warm

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO emmean   SE   df lower.CL upper.CL
#  Hyp           172 3.08 22.5      166      179
#  Norm          164 3.13 24.3      158      171
#
# Results are averaged over the levels of: Phase_1_temp, Phase_2.1_temp, Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate   SE   df t.ratio p.value
#  Hyp - Norm     8.01 3.68 12.3   2.178  0.0496
#
# Results are averaged over the levels of: Phase_1_temp, Phase_2.1_temp, Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger

# %%
(172-164)/172
# Out:
# [1] 0.04651163

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Hyp             175 3.49 18.4      167      182
#  Norm            162 3.58 18.4      154      169
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate   SE   df t.ratio p.value
#  Hyp - Norm     13.2 5.01 19.1   2.636  0.0162
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %%
(175-162)/175
# Out:
# [1] 0.07428571

# %%
#format display for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#summary stats
summary_stats <- Tissue_Nutrients %>%
  group_by(Phase_1_DO) %>%
  mutate(
    mean_cn = mean(mgC_tissue_P2, na.rm = TRUE),
    se_cn = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder
summary_stats$Phase_1_DO <- factor(summary_stats$Phase_1_DO, levels = c("Norm", "Hyp"))
#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_1_DO, y = mean_cn, color = Phase_1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_cn - se_cn, ymax = mean_cn + se_cn), 
                width = 0.05, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 1 DO", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  ylim(150,200)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#format display for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#summary stats
summary_stats <- Tissue_Nutrients %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean_cn = mean(mgC_tissue_P2, na.rm = TRUE),
    se_cn = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))
#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean_cn, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_cn - se_cn, ymax = mean_cn + se_cn), 
                width = 0.05, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  ylim(150,190)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(mgC_tissue_P2~Phase_1_treat*Phase_2_treat, Tissue_Nutrients) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 1.342198 0.1726835
#       457       NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# # Shell

# %% [markdown]
# ## 1. % Nitrogen in Shell

# %%
#filter data
Shell_Nitrogen <- nutrient_df%>%
filter(Tissue_type == "S")%>%
filter(is.na(N_Exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_Nitrogen %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  ylim(0.1, 0.25)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell nitrogen
m1 <- lmer(wt_percent_n~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nitrogen, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         1.452624e+03 1  10.229112 0.0000
# Phase_1_DO                                          4.314664e-01 1   9.793364 0.5264
# Phase_1_temp                                        7.978597e-01 1   9.795704 0.3931
# Phase_2.1_temp                                      3.442463e-01 1  18.678531 0.5644
# Phase_2.1_DO                                        1.415425e+00 1  18.734460 0.2490
# Phase_1_DO:Phase_1_temp                             1.801189e-01 1   9.794467 0.6804
# Phase_1_DO:Phase_2.1_temp                           1.543166e-01 1  18.646554 0.6989
# Phase_1_temp:Phase_2.1_temp                         2.419900e-02 1  18.648084 0.8781
# Phase_1_DO:Phase_2.1_DO                             8.061719e-03 1  18.707380 0.9294
# Phase_1_temp:Phase_2.1_DO                           7.469170e-01 1  18.709358 0.3984
# Phase_2.1_temp:Phase_2.1_DO                         2.094671e-01 1  18.705737 0.6525
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.770747e+00 1  18.648322 0.1993
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.894392e-02 1  18.708539 0.8667
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              8.033208e+00 1  18.677057 0.0107
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            3.596102e-01 1  18.678530 0.5559
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.030182e+00 1  18.678251 0.1707

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO*Phase_2.1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_2.1_temp Phase_2.1_DO emmean     SE   df lower.CL upper.CL
#  Hyp        Ambient        Hyp           0.175 0.0117 36.4    0.151    0.199
#  Norm       Ambient        Hyp           0.150 0.0117 36.4    0.126    0.174
#  Hyp        Warm           Hyp           0.164 0.0122 41.8    0.139    0.188
#  Norm       Warm           Hyp           0.179 0.0117 36.1    0.155    0.203
#  Hyp        Ambient        Norm          0.146 0.0118 28.3    0.122    0.170
#  Norm       Ambient        Norm          0.167 0.0118 24.8    0.142    0.191
#  Hyp        Warm           Norm          0.174 0.0119 39.3    0.150    0.198
#  Norm       Warm           Norm          0.141 0.0123 41.4    0.116    0.166
#
# Results are averaged over the levels of: Phase_1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                             estimate     SE   df t.ratio p.value
#  Hyp Ambient Hyp - Norm Ambient Hyp    0.02500 0.0163 18.7   1.533  0.1421
#  Hyp Ambient Hyp - Hyp Warm Hyp        0.01142 0.0169 41.2   0.675  0.5031
#  Hyp Ambient Hyp - Norm Warm Hyp      -0.00417 0.0165 36.3  -0.252  0.8022
#  Hyp Ambient Hyp - Hyp Ambient Norm    0.02904 0.0166 33.6   1.746  0.0900
#  Hyp Ambient Hyp - Norm Ambient Norm   0.00843 0.0166 29.9   0.508  0.6153
#  Hyp Ambient Hyp - Hyp Warm Norm       0.00113 0.0167 39.6   0.068  0.9462
#  Hyp Ambient Hyp - Norm Warm Norm      0.03415 0.0169 38.9   2.019  0.0505
#  Norm Ambient Hyp - Hyp Warm Hyp      -0.01358 0.0169 39.1  -0.803  0.4266
#  Norm Ambient Hyp - Norm Warm Hyp     -0.02917 0.0165 38.4  -1.768  0.0851
#  Norm Ambient Hyp - Hyp Ambient Norm   0.00404 0.0166 32.1   0.243  0.8094
#  Norm Ambient Hyp - Norm Ambient Norm -0.01657 0.0166 31.1  -0.999  0.3257
#  Norm Ambient Hyp - Hyp Warm Norm     -0.02387 0.0167 37.9  -1.430  0.1610
#  Norm Ambient Hyp - Norm Warm Norm     0.00915 0.0169 41.4   0.541  0.5917
#  Hyp Warm Hyp - Norm Warm Hyp         -0.01558 0.0167 20.2  -0.932  0.3626
#  Hyp Warm Hyp - Hyp Ambient Norm       0.01762 0.0170 36.1   1.035  0.3075
#  Hyp Warm Hyp - Norm Ambient Norm     -0.00299 0.0170 32.1  -0.176  0.8614
#  Hyp Warm Hyp - Hyp Warm Norm         -0.01029 0.0171 42.5  -0.602  0.5506
#  Hyp Warm Hyp - Norm Warm Norm         0.02273 0.0173 41.6   1.313  0.1964
#  Norm Warm Hyp - Hyp Ambient Norm      0.03321 0.0166 32.0   1.997  0.0544
#  Norm Warm Hyp - Norm Ambient Norm     0.01259 0.0166 31.2   0.758  0.4540
#  Norm Warm Hyp - Hyp Warm Norm         0.00530 0.0167 37.7   0.317  0.7528
#  Norm Warm Hyp - Norm Warm Norm        0.03832 0.0170 41.6   2.259  0.0292
#  Hyp Ambient Norm - Norm Ambient Norm -0.02061 0.0165 13.8  -1.249  0.2324
#  Hyp Ambient Norm - Hyp Warm Norm     -0.02791 0.0168 34.7  -1.659  0.1062
#  Hyp Ambient Norm - Norm Warm Norm     0.00511 0.0170 34.4   0.300  0.7661
#  Norm Ambient Norm - Hyp Warm Norm    -0.00729 0.0168 31.1  -0.435  0.6669
#  Norm Ambient Norm - Norm Warm Norm    0.02572 0.0170 33.4   1.514  0.1394
#  Hyp Warm Norm - Norm Warm Norm        0.03302 0.0169 21.1   1.951  0.0645
#
# Results are averaged over the levels of: Phase_1_temp
# Degrees-of-freedom method: kenward-roger

# %%
Norm Warm Hyp - Norm Warm Norm        0.03832 0.0170 41.6   2.259  0.0292

# %%
(0.179-0.141)/0.179
# Out:
# [1] 0.2122905

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_Nitrogen %>%
  group_by(Phase_1_DO, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_DO <- factor(summary_stats_t$Phase_1_DO, 
                                        levels = c("Norm", "Hyp"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_DO, y = mean_growth, color = Phase_1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
#geom_jitter(data = Shell_Nitrogen,
              #aes(x = Phase_1_DO, y = wt_percent_n, color = Phase_1_DO),
              #width = 0.1, alpha = 0.5, size = 2) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 1 DO", y = "Nitrogen in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  ylim(0.1, 0.25)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(wt_percent_n~Phase_1_treat*Phase_2_treat, Shell_Nitrogen) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.7509331 0.7297672
#       171        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 2. % Carbon in Shell

# %%
#filter data
Shell_Carbon <- nutrient_df%>%
filter(Tissue_type == "S")#%>%
#filter(is.na(c_exclude))

# %%
#tissue carbon
summary_stats_t <- Shell_Carbon %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_c, na.rm = TRUE),
    se_growth = std.error(wt_percent_c, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
geom_jitter(data = Shell_Carbon,
              aes(x = Phase_1_treat, y = wt_percent_c, color = Phase_1_treat),
              width = 0.1, alpha = 0.5, size = 2) +
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
#ylim(15,18)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##Shell carbon
m2 <- lmer(wt_percent_c~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Carbon, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         1.577697e+04 1  19.76095 0.0000
# Phase_1_DO                                          1.214818e-03 1  17.47838 0.9726
# Phase_1_temp                                        3.388217e-01 1  16.21872 0.5685
# Phase_2.1_temp                                      3.780803e+00 1  18.44756 0.0673
# Phase_2.1_DO                                        2.191686e+00 1  18.62181 0.1555
# Phase_1_DO:Phase_1_temp                             1.617231e-01 1  16.21789 0.6928
# Phase_1_DO:Phase_2.1_temp                           9.608654e-01 1  18.07660 0.3399
# Phase_1_temp:Phase_2.1_temp                         1.036737e-01 1  17.88881 0.7512
# Phase_1_DO:Phase_2.1_DO                             6.421946e-02 1  18.29592 0.8028
# Phase_1_temp:Phase_2.1_DO                           3.901417e-01 1  18.14334 0.5400
# Phase_2.1_temp:Phase_2.1_DO                         1.397451e+00 1  18.56265 0.2521
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.273469e-01 1  17.89108 0.7254
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                7.448995e-02 1  18.12761 0.7880
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              2.402552e-02 1  18.23764 0.8785
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.241718e-01 1  18.06967 0.6415
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.351436e-04 1  18.06506 0.9879

# %%
#posthocs
options(width = 120)
emmeans(m2,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean    SE   df lower.CL upper.CL
#  Hyp            16.6 0.175 22.1     16.2     17.0
#  Norm           16.9 0.179 21.6     16.6     17.3
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate    SE   df t.ratio p.value
#  Hyp - Norm   -0.343 0.232 18.6  -1.480  0.1555
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %%
(16.9-16.6)/16.9
# Out:
# [1] 0.01775148

# %%
#format display for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#summary stats
summary_stats <- Shell_Carbon %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean_cn = mean(wt_percent_c, na.rm = TRUE),
    se_cn = std.error(wt_percent_c, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))
#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean_cn, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_cn - se_cn, ymax = mean_cn + se_cn), 
                width = 0.05, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Carbon in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  ylim(16,18)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(wt_percent_c~Phase_1_treat*Phase_2_treat, Shell_Carbon) 
m1.e <- residuals(m2) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.7784794 0.7001369
#       171        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 3. Carbon:Nitrogen in Shell

# %%
#filter data
Shell_CN <- nutrient_df%>%
filter(Tissue_type == "S")%>%
filter(is.na(N_Exclude))%>%
#filter(is.na(c_exclude))%>%
mutate(C_N = (wt_percent_c/wt_percent_n))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue c:n
summary_stats_t <- Shell_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(C_N, na.rm = TRUE),
    se_growth = std.error(C_N, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
geom_jitter(data = Shell_CN,
              aes(x = Phase_1_treat, y = C_N, color = Phase_1_treat),
              width = 0.1, alpha = 0.5, size = 2) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") + # Remove legend
theme(panel.background = element_rect(fill = "aliceblue"))  #fill background light blue
# Out:
# plot without title

# %%
##shell carbon:nitrogen
m3 <- lmer((wt_percent_c/wt_percent_n)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_CN, REML=TRUE)
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         9.518519e+02 1  13.80298 0.0000
# Phase_1_DO                                          1.654403e+00 1  10.32458 0.2265
# Phase_1_temp                                        5.908244e-01 1  10.33916 0.4593
# Phase_2.1_temp                                      5.521843e-02 1  18.72225 0.8168
# Phase_2.1_DO                                        2.517746e+00 1  18.79039 0.1293
# Phase_1_DO:Phase_1_temp                             6.667946e-01 1  10.33251 0.4326
# Phase_1_DO:Phase_2.1_temp                           6.376186e-02 1  18.39064 0.8034
# Phase_1_temp:Phase_2.1_temp                         7.434335e-02 1  18.40128 0.7882
# Phase_1_DO:Phase_2.1_DO                             3.562320e-03 1  18.49638 0.9530
# Phase_1_temp:Phase_2.1_DO                           4.801668e-01 1  18.51444 0.4969
# Phase_2.1_temp:Phase_2.1_DO                         4.525643e-02 1  18.75854 0.8338
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.772941e+00 1  18.40395 0.1993
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.322444e-03 1  18.50212 0.9621
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              8.574644e+00 1  18.45902 0.0088
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            6.930386e-01 1  18.46829 0.4158
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.784131e+00 1  18.46502 0.1979

# %%
#posthocs
options(width = 120)
emmeans(m3,specs = pairwise ~ Phase_1_DO*Phase_2.1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_2.1_temp Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Hyp        Ambient        Hyp             101 9.53 36.0     82.1      121
#  Norm       Ambient        Hyp             126 9.53 36.0    106.4      145
#  Hyp        Warm           Hyp             115 9.92 40.7     94.5      135
#  Norm       Warm           Hyp             106 9.54 35.9     86.6      125
#  Hyp        Ambient        Norm            129 9.73 30.4    109.3      149
#  Norm       Ambient        Norm            118 9.78 26.9     98.2      138
#  Hyp        Warm           Norm            110 9.72 38.5     89.9      129
#  Norm       Warm           Norm            138 9.94 40.5    117.6      158
#
# Results are averaged over the levels of: Phase_1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the ( (not the response) scale.
# Confidence level used: 0.95
#
# $contrasts
#  contrast                             estimate   SE   df t.ratio p.value
#  Hyp Ambient Hyp - Norm Ambient Hyp     -24.30 12.2 19.0  -1.995  0.0605
#  Hyp Ambient Hyp - Hyp Warm Hyp         -13.11 13.6 39.0  -0.962  0.3422
#  Hyp Ambient Hyp - Norm Warm Hyp         -4.55 13.5 36.0  -0.338  0.7376
#  Hyp Ambient Hyp - Hyp Ambient Norm     -27.81 13.5 33.3  -2.059  0.0474
#  Hyp Ambient Hyp - Norm Ambient Norm    -16.89 13.7 31.0  -1.237  0.2253
#  Hyp Ambient Hyp - Hyp Warm Norm         -8.12 13.5 37.6  -0.602  0.5505
#  Hyp Ambient Hyp - Norm Warm Norm       -36.25 13.8 38.2  -2.633  0.0121
#  Norm Ambient Hyp - Hyp Warm Hyp         11.19 13.8 38.3   0.813  0.4210
#  Norm Ambient Hyp - Norm Warm Hyp        19.74 13.3 36.5   1.479  0.1477
#  Norm Ambient Hyp - Hyp Ambient Norm     -3.51 13.6 33.1  -0.258  0.7982
#  Norm Ambient Hyp - Norm Ambient Norm     7.41 13.5 31.1   0.547  0.5880
#  Norm Ambient Hyp - Hyp Warm Norm        16.17 13.6 37.2   1.188  0.2422
#  Norm Ambient Hyp - Norm Warm Norm      -11.95 13.7 39.1  -0.876  0.3866
#  Hyp Warm Hyp - Norm Warm Hyp             8.55 12.5 20.6   0.685  0.5012
#  Hyp Warm Hyp - Hyp Ambient Norm        -14.70 13.8 35.5  -1.067  0.2931
#  Hyp Warm Hyp - Norm Ambient Norm        -3.78 13.9 32.9  -0.272  0.7877
#  Hyp Warm Hyp - Hyp Warm Norm             4.99 13.8 40.1   0.362  0.7191
#  Hyp Warm Hyp - Norm Warm Norm          -23.14 14.0 40.6  -1.648  0.1071
#  Norm Warm Hyp - Hyp Ambient Norm       -23.25 13.6 33.0  -1.706  0.0974
#  Norm Warm Hyp - Norm Ambient Norm      -12.34 13.5 31.2  -0.911  0.3693
#  Norm Warm Hyp - Hyp Warm Norm           -3.57 13.6 37.2  -0.262  0.7947
#  Norm Warm Hyp - Norm Warm Norm         -31.70 13.7 39.4  -2.316  0.0259
#  Hyp Ambient Norm - Norm Ambient Norm    10.92 12.3 14.2   0.885  0.3907
#  Hyp Ambient Norm - Hyp Warm Norm        19.68 13.6 34.4   1.444  0.1579
#  Hyp Ambient Norm - Norm Warm Norm       -8.44 13.9 35.1  -0.607  0.5479
#  Norm Ambient Norm - Hyp Warm Norm        8.77 13.8 32.0   0.636  0.5292
#  Norm Ambient Norm - Norm Warm Norm     -19.36 13.8 33.1  -1.403  0.1699
#  Hyp Warm Norm - Norm Warm Norm         -28.13 12.6 21.5  -2.225  0.0369
#
# Results are averaged over the levels of: Phase_1_temp
# Note: contrasts are still on the ( scale. Consider using
#       regrid() if you want contrasts of back-transformed estimates.
# Degrees-of-freedom method: kenward-roger

# %%
        comparisons with norm warm
Hyp Warm Norm - Norm Warm Norm         -28.13 12.6 21.5  -2.225  0.0369
    hyp warm - norm warm
Norm Warm Hyp - Norm Warm Norm         -31.70 13.7 39.4  -2.316  0.0259
    norm both - norm warm
Hyp Ambient Hyp - Norm Warm Norm       -36.25 13.8 38.2  -2.633  0.0121
    hyp hyp - norm warm


Hyp Ambient Hyp - Hyp Ambient Norm     -27.81 13.5 33.3  -2.059  0.0474
    hyp both - hyp cont

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_CN %>%
  group_by(Phase_1_DO, Phase_2_treat) %>%
  mutate(
    mean_growth = mean((wt_percent_c/wt_percent_n), na.rm = TRUE),
    se_growth = std.error((wt_percent_c/wt_percent_n), na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_DO <- factor(summary_stats_t$Phase_1_DO, 
                                        levels = c("Norm", "Hyp"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_DO, y = mean_growth, color = Phase_1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 1 DO", y = "Carbon:Nitrogen in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  ylim(80, 160)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(C_N~Phase_1_treat*Phase_2_treat, Shell_CN) 
m1.e <- residuals(m3) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.8878595 0.5787315
#       171        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 4. Mg Carbon and Nitrogen in Shell

# %%
#calculate % N averages Tissue

summary_stats_s <- Shell_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  summarize(
    mean_N = mean(wt_percent_n, na.rm = TRUE),
    mean_C = mean(wt_percent_c, na.rm = TRUE))

print(summary_stats_s)
# Out:
# `summarise()` has regrouped the output.
# ℹ Summaries were computed grouped by Phase_1_treat and Phase_2_treat.
# ℹ Output is grouped by Phase_1_treat.
# ℹ Use `summarise(.groups = "drop_last")` to silence this message.
# ℹ Use `summarise(.by = c(Phase_1_treat, Phase_2_treat))` for per-operation
#   grouping (`?dplyr::dplyr_by`) instead.
# # A tibble: 16 × 4
# # Groups:   Phase_1_treat [4]
#    Phase_1_treat Phase_2_treat mean_N mean_C
#    <chr>         <chr>          <dbl>  <dbl>
#  1 Both          Both           0.164   16.8
#  2 Both          Cont           0.142   16.7
#  3 Both          Hyp            0.158   16.4
#  4 Both          Warm           0.173   17.3
#  5 Cont          Both           0.2     16.6
#  6 Cont          Cont           0.167   16.8
#  7 Cont          Hyp            0.142   16.8
#  8 Cont          Warm           0.136   17.4
#  9 Hyp           Both           0.164   16.8
# 10 Hyp           Cont           0.15    16.5
# 11 Hyp           Hyp            0.192   16.3
# 12 Hyp           Warm           0.175   17.6
# 13 Warm          Both           0.158   16.6
# 14 Warm          Cont           0.167   16.4
# 15 Warm          Hyp            0.158   16.5
# 16 Warm          Warm           0.145   16.9

# %%
Shell_Nutrients <- weight_df %>%
  filter(Exclude_year2 != "Y" | is.na(Exclude_year2)) %>%
  left_join(
    summary_stats_s,
    by = c("Phase_1_treat", "Phase_2_treat")) %>%
  mutate(mgN_shell_P2 = (Actual_shell_post_mg * mean_N) / 100)%>%
  mutate(mgC_shell_P2 = (Actual_shell_post_mg * mean_C) / 100)

View(Shell_Nutrients)
# Out:
#     ...1 Sample_Name            Phase_1_DO Phase_1_temp Phase_2.1_DO Phase_2.1_temp Phase_1_treat Phase_2_treat
# 1    2   2024_Both01_Both02_O14 Hyp        Warm         Hyp          Warm           Both          Both
# 2    3   2024_Both01_Both03_O26 Hyp        Warm         Hyp          Warm           Both          Both
# 3    4   2024_Both01_Both05_O49 Hyp        Warm         Hyp          Warm           Both          Both
# 4    5   2024_Both01_Both05_O50 Hyp        Warm         Hyp          Warm           Both          Both
# 5    6   2024_Both01_Both06_O61 Hyp        Warm         Hyp          Warm           Both          Both
# 6    8   2024_Both01_Cont02_O13 Hyp        Warm         Norm         Ambient        Both          Cont
# 7    9   2024_Both01_Cont02_O14 Hyp        Warm         Norm         Ambient        Both          Cont
# 8   10   2024_Both01_Cont04_O38 Hyp        Warm         Norm         Ambient        Both          Cont
# 9   11   2024_Both01_Cont06_O61 Hyp        Warm         Norm         Ambient        Both          Cont
# 10  12   2024_Both01_Cont06_O62 Hyp        Warm         Norm         Ambient        Both          Cont
# 11  13   2024_Both01_Hyp02_O13  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 12  14   2024_Both01_Hyp02_O14  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 13  15   2024_Both01_Hyp03_O25  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 14  16   2024_Both01_Hyp03_O26  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 15  17   2024_Both01_Hyp04_O38  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 16  19   2024_Both01_Warm02_O13 Hyp        Warm         Norm         Warm           Both          Warm
# 17  20   2024_Both01_Warm02_O14 Hyp        Warm         Norm         Warm           Both          Warm
# 18  22   2024_Both01_Warm03_O26 Hyp        Warm         Norm         Warm           Both          Warm
# 19  23   2024_Both01_Warm06_O61 Hyp        Warm         Norm         Warm           Both          Warm
# 20  24   2024_Both01_Warm06_O62 Hyp        Warm         Norm         Warm           Both          Warm
# 21  25   2024_Both02_Both02_O15 Hyp        Warm         Hyp          Warm           Both          Both
# 22  26   2024_Both02_Both02_O16 Hyp        Warm         Hyp          Warm           Both          Both
# 23  27   2024_Both02_Both03_O28 Hyp        Warm         Hyp          Warm           Both          Both
# 24  28   2024_Both02_Both04_O39 Hyp        Warm         Hyp          Warm           Both          Both
# 25  29   2024_Both02_Both06_O63 Hyp        Warm         Hyp          Warm           Both          Both
# 26  33   2024_Both02_Cont03_O28 Hyp        Warm         Norm         Ambient        Both          Cont
# 27  34   2024_Both02_Cont05_O51 Hyp        Warm         Norm         Ambient        Both          Cont
# 28  35   2024_Both02_Cont05_O52 Hyp        Warm         Norm         Ambient        Both          Cont
# 29  36   2024_Both02_Cont06_O64 Hyp        Warm         Norm         Ambient        Both          Cont
# 30  39   2024_Both02_Hyp03_O28  Hyp        Warm         Hyp          Ambient        Both          Hyp
# ⋮   ⋮    ⋮                      ⋮          ⋮            ⋮            ⋮              ⋮             ⋮
# 444 510  2024_Warm05_Hyp02_G21  Norm       Warm         Hyp          Ambient        Warm          Hyp
# 445 511  2024_Warm05_Hyp03_G33  Norm       Warm         Hyp          Ambient        Warm          Hyp
# 446 512  2024_Warm05_Hyp03_G34  Norm       Warm         Hyp          Ambient        Warm          Hyp
# 447 513  2024_Warm05_Hyp05_G58  Norm       Warm         Hyp          Ambient        Warm          Hyp
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgN_shell_P2, na.rm = TRUE),
    se_growth = std.error(mgN_shell_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Shell (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell nitrogen
m1 <- lmer(log(mgN_shell_P2)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F           Df Df.res   Pr(>F)
# (Intercept)                                         1.719904056 1  21.23566 0.2037
# Phase_1_DO                                          1.897221455 1  15.93793 0.1874
# Phase_1_temp                                        0.214001864 1  12.68461 0.6515
# Phase_2.1_temp                                      0.100524492 1  19.61535 0.7546
# Phase_2.1_DO                                        0.623965331 1  19.63827 0.4390
# Phase_1_DO:Phase_1_temp                             0.241625970 1  12.71794 0.6314
# Phase_1_DO:Phase_2.1_temp                           0.164300847 1  18.79685 0.6898
# Phase_1_temp:Phase_2.1_temp                         2.536578474 1  18.55785 0.1281
# Phase_1_DO:Phase_2.1_DO                             0.005601640 1  18.86952 0.9411
# Phase_1_temp:Phase_2.1_DO                           7.664768243 1  18.63070 0.0124
# Phase_2.1_temp:Phase_2.1_DO                         0.002974432 1  19.62902 0.9571
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              3.562346924 1  18.52513 0.0749
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.721722901 1  18.61788 0.4064
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              3.881037754 1  18.87568 0.0637
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.541685166 1  18.67605 0.2297
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.005805892 1  18.64458 0.9401

# %%
#diagnostics
leveneTest(log(mgN_shell_P2)~Phase_1_treat*Phase_2_treat, Shell_Nutrients)
m1.e <- residuals(m1)
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 1.310616 0.1911244
#       457       NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ### 4.2 Mg Carbon Analysis

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgC_shell_P2, na.rm = TRUE),
    se_growth = std.error(mgC_shell_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Shell (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##Shell carbon
m1 <- lmer(mgC_shell_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         3.234031e+02 1  22.00544 0.0000
# Phase_1_DO                                          1.851485e+00 1  19.81763 0.1889
# Phase_1_temp                                        7.937513e-04 1  17.17295 0.9778
# Phase_2.1_temp                                      7.291060e-02 1  19.61775 0.7900
# Phase_2.1_DO                                        2.195175e+00 1  19.64561 0.1543
# Phase_1_DO:Phase_1_temp                             4.433028e-01 1  14.87967 0.5157
# Phase_1_DO:Phase_2.1_temp                           7.679859e-04 1  19.00068 0.9782
# Phase_1_temp:Phase_2.1_temp                         4.950790e+00 1  18.78383 0.0385
# Phase_1_DO:Phase_2.1_DO                             1.793401e-01 1  19.07616 0.6767
# Phase_1_temp:Phase_2.1_DO                           1.948051e+00 1  18.87068 0.1790
# Phase_2.1_temp:Phase_2.1_DO                         9.550111e-02 1  19.63490 0.7606
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              2.430010e-01 1  18.53420 0.6278
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.092333e-02 1  18.63956 0.8865
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.954988e+00 1  19.06906 0.1781
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            6.374219e+00 1  18.88246 0.0207
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 3.645755e+00 1  18.66511 0.0717

# %%
##Shell carbon
    #using shell pre as a covariate
m1 <- lmer(mgC_shell_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+ Actual_shell_pre_mg+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res     Pr(>F)
# (Intercept)                                         5.253585e+01 1    33.33220 0.0000
# Phase_1_DO                                          3.365075e-01 1    10.57533 0.5740
# Phase_1_temp                                        6.458072e+00 1    11.91696 0.0260
# Phase_2.1_temp                                      1.156283e-06 1    19.98958 0.9992
# Phase_2.1_DO                                        8.011631e+00 1    19.97523 0.0103
# Actual_shell_pre_mg                                 7.596008e+03 1  1074.17990 0.0000
# Phase_1_DO:Phase_1_temp                             9.515288e-01 1    10.30751 0.3517
# Phase_1_DO:Phase_2.1_temp                           1.210096e+00 1    19.95013 0.2844
# Phase_1_temp:Phase_2.1_temp                         1.649227e-01 1    19.98922 0.6890
# Phase_1_DO:Phase_2.1_DO                             7.927576e-01 1    19.95758 0.3839
# Phase_1_temp:Phase_2.1_DO                           1.589333e+00 1    20.10533 0.2219
# Phase_2.1_temp:Phase_2.1_DO                         1.198112e+00 1    19.98632 0.2867
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              6.374338e-01 1    19.98489 0.4340
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                3.906197e-01 1    19.97800 0.5390
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              5.927608e-03 1    19.96576 0.9394
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.258517e+00 1    20.14997 0.2751
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.216965e-01 1    19.98319 0.7309

# %%
#diagnostics
leveneTest(mgC_shell_P2~Phase_1_treat*Phase_2_treat, Shell_Nutrients)
m1.e <- residuals(m1)
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df   F value  Pr(>F)
# group   15 1.675162 0.05006165
#       1101       NA         NA
# Plot with title “Normal Q-Q Plot”
