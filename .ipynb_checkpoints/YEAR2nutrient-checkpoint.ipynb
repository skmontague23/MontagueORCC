# %% [markdown]
# # YEAR 2 Nutrient Analysis

# %%
Samples taken one year after experiment

# %%
library(lme4) #for linear mixed effects model
library(readr) #to read in data
library(emmeans) #for post hocs
library(esquisse) #interface for building plots
library(dplyr) #for data wrangling
library(nlme) #for linear mixed effects model
library(car) #for the Levene test
library(ggplot2) #for graphs
library(plotrix) #for standard error
library(performance) #model testing
library(lmtest) #another option than levene test for variance

# %%
setwd("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC")
getwd()
# Out:
# [1] "/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC"

# %%
# Below is NOT updated, need to swap over from phase 2 to year 2

# %% [markdown]
# ## 0. Data Formatting

# %%
year2 <- read_csv("Year_2_Data/Nutrients/Nutrient_YEAR2_working.csv")
Phase1_info <- read_csv("Oyster_Weight_Data/growth_phase2.1_weightsSKM.csv")
# Out:
# New names:
# • `` -> `...16`
# Rows: 374 Columns: 16
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (11): Sample_Name_Nutrients, Phase_2_treat, Phase_2_rep, Phase_2_rep_R, ...
# dbl  (5): Tag_num, Linear corr d15N, wt_percent_n, Linear corr d13C, wt_perc...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 1152 Columns: 37
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (20): Sample_Name, Date_MMDDYYYY_pre, Phase_1_treat, Phase_1_rep, Phase_...
# dbl (17): Order_pre, Year, Tag_num, Submerged_weight_pre, Dry_weight_pre, Or...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
colnames(Phase1_info)
# Out:
#  [1] "Sample_Name"               "Order_pre"
#  [3] "Date_MMDDYYYY_pre"         "Year"
#  [5] "Phase_1_treat"             "Phase_1_rep"
#  [7] "Phase_2_treat"             "Phase_2_rep"
#  [9] "Tag_color"                 "Tag_num"
# [11] "Submerged_weight_pre"      "Dry_weight_pre"
# [13] "Notes_pre"                 "Order_post"
# [15] "Date_MMDDYYYY_post"        "Submerged_weight_post"
# [17] "Dry_weight_post"           "double_single_dead"
# [19] "Notes_post"                "Actual_shell_pre_mg"
# [21] "Actual_shell_post_mg"      "Actual_shell_growth_mg"
# [23] "Actual_tissue_pre_mg"      "Actual_tissue_post_mg"
# [25] "Actual_tissue_growth_mg"   "Ratio_tissue_shell_mg"
# [27] "Phase_1_temp"              "Phase_1_DO"
# [29] "Phase_2.1_temp"            "Phase_2.1_DO"
# [31] "Phase1_Phase2_treat"       "Phase_1_rep_R"
# [33] "Phase_2_rep_R"             "Ratio_tissue_shell_pre_mg"
# [35] "Phase1_Phase2_rep"         "Exclude_all"
# [37] "Exclude_pre_analysis"

# %%
#Add in treatment groups etc.
nutrient_df <- year2 %>%
  inner_join(
    Phase1_info %>%
      select(
        Phase_2_rep_R, Sample_Name, Phase_1_treat, Phase_1_rep, Phase_1_rep_R,
        Tag_color, Tag_num, Notes_pre, Notes_post,
        Actual_shell_pre_mg, Actual_shell_post_mg, Actual_shell_growth_mg,
        Actual_tissue_pre_mg, Actual_tissue_post_mg, Actual_tissue_growth_mg,
        Phase_1_temp, Phase_1_DO, Phase_2.1_temp, Phase_2.1_DO,
        Exclude_all), 
      by = c("Phase_2_rep_R", "Tag_color", "Tag_num"))

# %%
colnames(nutrient_df)
# Out:
#  [1] "Sample_Name_Nutrients"   "Phase_2_treat"
#  [3] "Phase_2_rep"             "Phase_2_rep_R"
#  [5] "Tissue_type"             "Tag"
#  [7] "Tag_color"               "Tag_num"
#  [9] "Linear corr d15N"        "wt_percent_n"
# [11] "N_Notes"                 "Linear corr d13C"
# [13] "wt_percent_c"            "C_Notes"
# [15] "N_Exclude"               "...16"
# [17] "Sample_Name"             "Phase_1_treat"
# [19] "Phase_1_rep"             "Phase_1_rep_R"
# [21] "Notes_pre"               "Notes_post"
# [23] "Actual_shell_pre_mg"     "Actual_shell_post_mg"
# [25] "Actual_shell_growth_mg"  "Actual_tissue_pre_mg"
# [27] "Actual_tissue_post_mg"   "Actual_tissue_growth_mg"
# [29] "Phase_1_temp"            "Phase_1_DO"
# [31] "Phase_2.1_temp"          "Phase_2.1_DO"
# [33] "Exclude_all"

# %%
View(nutrient_df)
# Out:
#     Sample_Name_Nutrients Phase_2_treat Phase_2_rep Phase_2_rep_R Tissue_type
# 1   Cont01 B12 T          Cont          01          Cont01        T
# 2   Cont02 G23 T          Cont          02          Cont02        T
# 3   Cont02 W22 T          Cont          02          Cont02        T
# 4   Cont02 O22 T          Cont          02          Cont02        T
# 5   Cont02 O18 T          Cont          02          Cont02        T
# 6   Cont02 G13 T          Cont          02          Cont02        T
# 7   Cont02 G17 T          Cont          02          Cont02        T
# 8   Cont02 W23 T          Cont          02          Cont02        T
# 9   Cont02 B19 T          Cont          02          Cont02        T
# 10  Cont02 B15 T          Cont          02          Cont02        T
# 11  Cont03 B29 T          Cont          03          Cont03        T
# 12  Cont03 W31 T          Cont          03          Cont03        T
# 13  Cont03 W28 T          Cont          03          Cont03        T
# 14  Cont03 W29 T          Cont          03          Cont03        T
# 15  Cont03 G27 T          Cont          03          Cont03        T
# 16  Cont03 G34 T          Cont          03          Cont03        T
# 17  Cont03 O36 T          Cont          03          Cont03        T
# 18  Cont03 O34 T          Cont          03          Cont03        T
# 19  Cont03 B34 T          Cont          03          Cont03        T
# 20  Cont03 B25 T          Cont          03          Cont03        T
# 21  Cont03 G26 T          Cont          03          Cont03        T
# 22  Cont04 W39 T          Cont          04          Cont04        T
# 23  Cont04 O42 T          Cont          04          Cont04        T
# 24  Cont04 O44 T          Cont          04          Cont04        T
# 25  Cont04 G39 T          Cont          04          Cont04        T
# 26  Cont04 B43 T          Cont          04          Cont04        T
# 27  Cont04 G43 T          Cont          04          Cont04        T
# 28  Cont04 B39 T          Cont          04          Cont04        T
# 29  Cont04  W47 T         Cont          04          Cont04        T
# 30  Cont05 W56 T          Cont          05          Cont05        T
# ⋮   ⋮                     ⋮             ⋮           ⋮             ⋮
# 345 Warm06 O61 S          Warm          06          Warm06        S
# 346 Warm06 O64 S          Warm          06          Warm06        S
# 347 Warm06 B70 S          Warm          06          Warm06        S
# 348 Warm06 B62 S          Warm          06          Warm06        S
# 349 Warm06 G65 S          Warm          06          Warm06        S
# 350 Warm06 G67 S          Warm          06          Warm06        S
# 351 Warm06 W65 S          Warm          06          Warm06        S
# 352 Warm06 W69 S          Warm          06          Warm06        S
# 353 Hyp01 G1 S            Hyp           01          Hyp01         S
# 354 Hyp01 W8 S            Hyp           01          Hyp01         S
# 355 Hyp01 O5 S            Hyp           01          Hyp01         S
# 356 Hyp01 W9 S            Hyp           01          Hyp01         S
# 357 Hyp01 B5 S            Hyp           01          Hyp01         S
# 358 Both04 G43 S          Both          04          Both04        S
# 359 Both04 B44 S          Both          04          Both04        S
# 360 Both05 B57 S          Both          05          Both05        S
# 361 Both05 G59 S          Both          05          Both05        S
# 362 Both05 O53 S          Both          05          Both05        S
# 363 Both05 O55 S          Both          05          Both05        S
# 364 Both05 W53 S          Both          05          Both05        S
# 365 Both05 G51 S          Both          05          Both05        S
# 366 Both05 W57 S          Both          05          Both05        S
# 367 Both06 B65 S          Both          06          Both06        S
# 368 Both06 G69 S          Both          06          Both06        S
# 369 Both06 W63 S          Both          06          Both06        S
# 370 Both06 B69 S          Both          06          Both06        S
# 371 Both06 O72 S          Both          06          Both06        S
# 372 Both06 G66 S          Both          06          Both06        S
# 373 Both06 O63 S          Both          06          Both06        S
# 374 Both06 W67 S          Both          06          Both06        S
#     Tag Tag_color Tag_num Linear corr d15N wt_percent_n ⋯ Actual_shell_post_mg
# 1   B12 B         12      12.8             8.0          ⋯  724.2940
# 2   G23 G         23      13.3             7.7          ⋯ 1244.9159
# 3   W22 W         22      13.3             8.7          ⋯ 1167.8043
# 4   O22 O         22      12.7             7.4          ⋯  643.3822
# 5   O18 O         18      12.5             5.3          ⋯ 1739.0950
# 6   G13 G         13      13.2             5.3          ⋯ 1192.5053
# 7   G17 G         17      12.6             5.9          ⋯ 1724.5277
# 8   W23 W         23      13.0             6.5          ⋯  627.5482
# 9   B19 B         19      13.0             4.5          ⋯  940.2697
# 10  B15 B         15      13.2             8.2          ⋯  857.2996
# 11  B29 B         29      13.0             7.3          ⋯  463.0330
# 12  W31 W         31      13.0             7.4          ⋯  494.5426
# 13  W28 W         28      13.7             7.4          ⋯  556.7702
# 14  W29 W         29      13.3             5.3          ⋯  417.5894
# 15  G27 G         27      12.9             7.8          ⋯ 1300.1765
# 16  G34 G         34      13.0             9.1          ⋯ 1552.5705
# 17  O36 O         36      12.7             7.7          ⋯  458.2828
# 18  O34 O         34      11.8             6.2          ⋯  694.2094
# 19  B34 B         34      12.5             7.7          ⋯  630.0817
# 20  B25 B         25      13.3             6.5          ⋯  414.4226
# 21  G26 G         26      12.9             6.7          ⋯  973.8378
# 22  W39 W         39      12.7             5.4          ⋯  619.6312
# 23  O42 O         42      12.3             6.9          ⋯  585.2714
# 24  O44 O         44      12.4             6.2          ⋯  608.2307
# 25  G39 G         39      13.7             7.6          ⋯  806.3141
# 26  B43 B         43      13.2             7.2          ⋯  533.9693
# 27  G43 G         43      12.5             6.4          ⋯  806.9474
# 28  B39 B         39      13.2             5.9          ⋯  658.7412
# 29  W47 W         47      12.3             6.8          ⋯  488.0507
# 30  W56 W         56      13.2             7.6          ⋯  748.2033
# 30  282.1619               249.75858            421.2967
# ⋮   ⋮                      ⋮                    ⋮
# 345 409.30890              323.91076             454.5019
# 346 232.60146              251.43122             337.0298
# 347 331.72230              211.21438             299.1921
# 348 728.36400              534.63100            1060.8670
# 349 273.76986              413.84938             602.0795
# 350 694.00422              223.32340             590.3192
# 351 122.71350              123.42324             189.8097
# 352 515.71338              312.37014             465.2568
# 353 421.81776              296.46656             384.3488
# 354 360.06516              304.70622             459.2411
# 355 399.01680              396.38212             580.6653
# 356 106.08780              162.59962             212.4118
# 357 204.10026              108.69548             196.0952
# 358 201.56682              194.54360             315.7768
# 359 105.29610              123.21144             158.3153
# 360 149.47296              102.75494             166.7820
# 361 174.49068              127.36794             210.1773
# 362 118.27998              109.08654             161.2066
# 363 230.22636              199.95158             288.9252
# 364  57.63576              109.66156             121.0258
# 365 309.07968              253.33776             374.3581
# 366 174.33234              182.42818             291.4958
# 367 663.91962              572.98992            1191.4703
# 368 192.38310              140.31502             207.0319
# 369 150.73968              181.94208             219.2024
# 370  76.79490              105.22022             157.2253
# 371 406.61712              499.29694             804.4798
# 372 182.24934              133.91926             239.0699
# 373  96.74574              124.22732             173.9816
# 374  90.25380               91.84808             126.7943
#     Actual_tissue_growth_mg Phase_1_temp Phase_1_DO Phase_2.1_temp Phase_2.1_DO
# 1   101.80540               Ambient      Hyp        Ambient        Norm
# 2   252.68588               Warm         Norm       Ambient        Norm
# 3   124.77106               Ambient      Norm       Ambient        Norm
# 4    60.86406               Warm         Hyp        Ambient        Norm
# 5   177.12386               Warm         Hyp        Ambient        Norm
# 6   254.02810               Warm         Norm       Ambient        Norm
# 7   265.65076               Warm         Norm       Ambient        Norm
# 8   144.22838               Ambient      Norm       Ambient        Norm
# 9    21.39510               Ambient      Hyp        Ambient        Norm
# 10  151.40562               Ambient      Hyp        Ambient        Norm
# 11  119.49846               Ambient      Hyp        Ambient        Norm
# 12  147.55456               Ambient      Norm       Ambient        Norm
# 13  130.18912               Ambient      Norm       Ambient        Norm
# 14  109.73948               Ambient      Norm       Ambient        Norm
# 15  221.15500               Warm         Norm       Ambient        Norm
# 16  256.30256               Warm         Norm       Ambient        Norm
# 17  116.62400               Warm         Hyp        Ambient        Norm
# 18  256.87106               Warm         Hyp        Ambient        Norm
# 19  162.34466               Ambient      Hyp        Ambient        Norm
# 20  213.10364               Ambient      Hyp        Ambient        Norm
# 21  184.85558               Warm         Norm       Ambient        Norm
# 22   66.35154               Ambient      Norm       Ambient        Norm
# 23  146.16828               Warm         Hyp        Ambient        Norm
# 24  206.16844               Warm         Hyp        Ambient        Norm
# 25  166.95120               Warm         Norm       Ambient        Norm
# 26  156.58266               Ambient      Hyp        Ambient        Norm
# 27  273.92454               Warm         Norm       Ambient        Norm
# 28  174.79134               Ambient      Hyp        Ambient        Norm
# 29  110.75896               Ambient      Norm       Ambient        Norm
# 30  171.53812               Ambient      Norm       Ambient        Norm
# ⋮   ⋮                       ⋮            ⋮          ⋮              ⋮
# 345 130.59110               Warm         Hyp        Warm           Norm
# 346  85.59854               Warm         Hyp        Warm           Norm
# 347  87.97770               Ambient      Hyp        Warm           Norm
# 348 526.23600               Ambient      Hyp        Warm           Norm
# 349 188.23014               Warm         Norm       Warm           Norm
# 350 366.99578               Warm         Norm       Warm           Norm
# 351  66.38650               Ambient      Norm       Warm           Norm
# 352 152.88662               Ambient      Norm       Warm           Norm
# 353  87.88224               Warm         Norm       Ambient        Hyp
# 354 154.53484               Ambient      Norm       Ambient        Hyp
# 355 184.28320               Warm         Hyp        Ambient        Hyp
# 356  49.81220               Ambient      Norm       Ambient        Hyp
# 357  87.39974               Ambient      Hyp        Ambient        Hyp
# 358 121.23318               Warm         Norm       Warm           Hyp
# 359  35.10390               Ambient      Hyp        Warm           Hyp
# 360  64.02704               Ambient      Hyp        Warm           Hyp
# 361  82.80932               Warm         Norm       Warm           Hyp
# 362  52.12002               Warm         Hyp        Warm           Hyp
# 363  88.97364               Warm         Hyp        Warm           Hyp
# 364  11.36424               Ambient      Norm       Warm           Hyp
# 365 121.02032               Warm         Norm       Warm           Hyp
# 366 109.06766               Ambient      Norm       Warm           Hyp
# 367 618.48038               Ambient      Hyp        Warm           Hyp
# 368  66.71690               Warm         Norm       Warm           Hyp
# 369  37.26032               Ambient      Norm       Warm           Hyp
# 370  52.00510               Ambient      Hyp        Warm           Hyp
# 371 305.18288               Warm         Hyp        Warm           Hyp
# 372 105.15066               Warm         Norm       Warm           Hyp
# 373  49.75426               Warm         Hyp        Warm           Hyp
# 374  34.94620               Ambient      Norm       Warm           Hyp
#     Exclude_all
# 1   NA
# 2   NA
# 3   NA
# 4   NA
# 5   NA
# 6   NA
# 7   NA
# 8   NA
# 9   NA
# 10  NA
# 11  NA
# 12  NA
# 13  NA
# 14  NA
# 15  NA
# 16  NA
# 17  NA
# 18  NA
# 19  NA
# 20  NA
# 21  NA
# 22  NA
# 23  NA
# 24  NA
# 25  NA
# 26  NA
# 27  NA
# 28  NA
# 29  NA
# 30  NA
# ⋮   ⋮
# 345 NA
# 346 NA
# 347 NA
# 348 NA
# 349 NA
# 350 NA
# 351 NA
# 352 NA
# 353 NA
# 354 NA
# 355 NA
# 356 NA
# 357 NA
# 358 NA
# 359 NA
# 360 NA
# 361 NA
# 362 NA
# 363 NA
# 364 NA
# 365 NA
# 366 NA
# 367 NA
# 368 NA
# 369 NA
# 370 NA
# 371 NA
# 372 NA
# 373 NA
# 374 NA

# %%
#write csv
#write_csv(matched_data, "Phase2_Nutrient/Phase2_nutrient_merged.csv")

# %%
#set contrasts
options(contrasts = c("contr.sum","contr.poly")) #could also be contr.treatment for unequal groups sum
getOption("contrasts")
# Out:
# [1] "contr.sum"  "contr.poly"

# %%
## READ IN MERGED DATA
nutrient_df <- read_csv("XXX.csv")
# Out:
# Rows: 392 Columns: 25
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (17): Vial_num, n_notes, c_notes, n_exclude, c_exclude, Phase_1_treat, Phase_1_rep_R, Phase_2_treat, Phase_2_rep...
# dbl  (8): linear_corr_d15n, wt_percent_n, linear_corr_d13c, wt_percent_c, Year, Phase_1_rep, Phase_2_rep, Tag_num
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# # Tissue

# %% [markdown]
# ## 1. % Nitrogen in Tissue

# %%
colnames(nutrient_df)
unique(nutrient_df$Tissue_type)
# Out:
#  [1] "Sample_Name_Nutrients"   "Phase_2_treat"
#  [3] "Phase_2_rep"             "Phase_2_rep_R"
#  [5] "Tissue_type"             "Tag"
#  [7] "Tag_color"               "Tag_num"
#  [9] "Linear corr d15N"        "wt_percent_n"
# [11] "N_Notes"                 "Linear corr d13C"
# [13] "wt_percent_c"            "C_Notes"
# [15] "N_Exclude"               "...16"
# [17] "Sample_Name"             "Phase_1_treat"
# [19] "Phase_1_rep"             "Phase_1_rep_R"
# [21] "Notes_pre"               "Notes_post"
# [23] "Actual_shell_pre_mg"     "Actual_shell_post_mg"
# [25] "Actual_shell_growth_mg"  "Actual_tissue_pre_mg"
# [27] "Actual_tissue_post_mg"   "Actual_tissue_growth_mg"
# [29] "Phase_1_temp"            "Phase_1_DO"
# [31] "Phase_2.1_temp"          "Phase_2.1_DO"
# [33] "Exclude_all"
# [1] "T" "S"

# %%
#filter data
Tissue_Nitrogen <- nutrient_df%>%
filter(Tissue_type == "T")%>%
filter(is.na(N_Exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nitrogen %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Tissue (%)") +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue nitrogen
m1 <- lmer(wt_percent_n~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nitrogen, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res
# (Intercept)                                         2.426589e+03 1  14.128743
# Phase_1_DO                                          3.690382e-01 1   9.444754
# Phase_1_temp                                        2.545930e+00 1   9.462947
# Phase_2.1_temp                                      1.970548e-03 1  18.965619
# Phase_2.1_DO                                        5.419627e+00 1  18.994435
# Phase_1_DO:Phase_1_temp                             2.801160e-02 1   9.460570
# Phase_1_DO:Phase_2.1_temp                           1.018302e-01 1  18.598042
# Phase_1_temp:Phase_2.1_temp                         1.754751e+00 1  18.611492
# Phase_1_DO:Phase_2.1_DO                             1.548781e+00 1  18.672791
# Phase_1_temp:Phase_2.1_DO                           1.154099e+00 1  18.690577
# Phase_2.1_temp:Phase_2.1_DO                         2.463449e+00 1  18.976559
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.485529e-01 1  18.612863
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                6.380859e-01 1  18.682797
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              8.260332e-03 1  18.637453
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            4.038412e-01 1  18.650143
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 7.985709e-01 1  18.645157
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.5579
# Phase_1_temp                                        0.1434
# Phase_2.1_temp                                      0.9651
# Phase_2.1_DO                                        0.0311
# Phase_1_DO:Phase_1_temp                             0.8706
# Phase_1_DO:Phase_2.1_temp                           0.7532
# Phase_1_temp:Phase_2.1_temp                         0.2013
# Phase_1_DO:Phase_2.1_DO                             0.2287
# Phase_1_temp:Phase_2.1_DO                           0.2964
# Phase_2.1_temp:Phase_2.1_DO                         0.1330
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.7043
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.4344
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.9286
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.5328
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.3829

# %%
#diagnostics
leveneTest(wt_percent_n~Phase_1_treat*Phase_2_treat, Tissue_Nitrogen) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value Pr(>F)
# group  15 1.47417 0.1196284
#       170      NA        NA
# Plot with title “Normal Q-Q Plot”

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean    SE   df lower.CL upper.CL
#  Hyp            6.64 0.198 18.0     6.22     7.05
#  Norm           7.30 0.203 17.4     6.87     7.72
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate    SE df t.ratio p.value
#  Hyp - Norm    -0.66 0.283 19  -2.328  0.0311
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_Nitrogen %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean = mean(wt_percent_n, na.rm = TRUE),
    se = std.error(wt_percent_n, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Nitrogen in Tissue (%)") +
  ylim(6,8)+
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
(7.30/6.64)/7.30
# Out:
# [1] 0.1506024

# %% [markdown]
# ## 2. % Carbon in Tissue

# %%
#filter data
Tissue_Carbon <- nutrient_df%>%
filter(Tissue_type == "T") #%>%
#filter(is.na(C_exclude))

# %%
#format for jupyter
options(repr.plot.width = 12, repr.plot.height = 6)

#tissue carbon
summary_stats_t <- Tissue_Carbon %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_c, na.rm = TRUE),
    se_growth = std.error(wt_percent_c, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon
m2 <- lmer(wt_percent_c~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Carbon, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         3.140401e+03 1  13.877055 0.0000
# Phase_1_DO                                          6.115201e-01 1  12.751227 0.4485
# Phase_1_temp                                        5.150442e-01 1   9.464260 0.4903
# Phase_2.1_temp                                      6.652261e-01 1  18.899081 0.4249
# Phase_2.1_DO                                        2.193707e+01 1  18.939262 0.0002
# Phase_1_DO:Phase_1_temp                             1.001870e+00 1   9.462425 0.3418
# Phase_1_DO:Phase_2.1_temp                           4.618287e-02 1  18.802428 0.8322
# Phase_1_temp:Phase_2.1_temp                         5.834032e-01 1  18.559844 0.4546
# Phase_1_DO:Phase_2.1_DO                             9.169434e-02 1  18.851748 0.7654
# Phase_1_temp:Phase_2.1_DO                           1.676619e-01 1  18.645141 0.6869
# Phase_2.1_temp:Phase_2.1_DO                         1.029720e-01 1  18.920171 0.7518
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              5.100771e-01 1  18.560372 0.4840
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.804789e-01 1  18.642755 0.6758
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              3.927888e-02 1  18.829989 0.8450
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.934382e+00 1  18.609955 0.1807
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 7.396291e-02 1  18.609138 0.7886

# %%
#posthocs
options(width = 120)
emmeans(m2,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Hyp            51.4 1.18 18.1     48.9     53.9
#  Norm           43.5 1.21 17.3     41.0     46.1
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate   SE   df t.ratio p.value
#  Hyp - Norm     7.88 1.68 18.9   4.684  0.0002
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %%
(51.4-43.5)/51.4
# Out:
# [1] 0.1536965

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_Carbon %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean = mean(wt_percent_c, na.rm = TRUE),
    se = std.error(wt_percent_c, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Carbon in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
ylim(40,55)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(wt_percent_c~Phase_1_treat*Phase_2_treat, Tissue_Carbon)
m1.e <- residuals(m2) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value Pr(>F)
# group  15 1.8094  0.0366876
#       171     NA         NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 3. Carbon:Nitrogen in Tissue

# %%
#filter data
Tissue_CN <- nutrient_df%>%
filter(Tissue_type == "T")%>%
filter(is.na(N_Exclude)) #%>%
#filter(is.na(c_exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue c:n
summary_stats_t <- Tissue_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean((wt_percent_c/wt_percent_n), na.rm = TRUE),
    se_growth = std.error((wt_percent_c/wt_percent_n), na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon:nitrogen
    #log transform to pass levene test, results are the same
m3 <- lmer((wt_percent_c/wt_percent_n)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_CN, REML=TRUE)
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         3.951927e+02 1  11.990021 0.0000
# Phase_1_DO                                          3.672268e-01 1  11.174214 0.5566
# Phase_1_temp                                        5.114462e-01 1   9.470198 0.4918
# Phase_2.1_temp                                      4.590007e-01 1  18.794988 0.5063
# Phase_2.1_DO                                        1.411845e+01 1  18.841045 0.0013
# Phase_1_DO:Phase_1_temp                             8.529164e-01 1   9.469784 0.3787
# Phase_1_DO:Phase_2.1_temp                           4.216433e-03 1  18.732559 0.9489
# Phase_1_temp:Phase_2.1_temp                         4.762592e-01 1  18.617736 0.4986
# Phase_1_DO:Phase_2.1_DO                             2.554223e-02 1  18.786624 0.8747
# Phase_1_temp:Phase_2.1_DO                           9.618939e-01 1  18.692974 0.3392
# Phase_2.1_temp:Phase_2.1_DO                         4.881288e-01 1  18.815460 0.4933
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              6.148351e-01 1  18.617979 0.4428
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.082034e+00 1  18.691634 0.3115
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.050808e-01 1  18.757935 0.7494
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            6.558912e-01 1  18.653582 0.4282
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.488160e+00 1  18.652725 0.2377

# %%
#posthocs
options(width = 120)
emmeans(m3,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean    SE   df lower.CL upper.CL
#  Hyp            9.21 0.545 17.3     8.06    10.36
#  Norm           6.28 0.558 16.3     5.10     7.46
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the ( (not the response) scale.
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate   SE   df t.ratio p.value
#  Hyp - Norm     2.93 0.78 18.8   3.757  0.0013
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Note: contrasts are still on the ( scale. Consider using
#       regrid() if you want contrasts of back-transformed estimates.
# Degrees-of-freedom method: kenward-roger

# %%
(9.21-6.28)/9.21
# Out:
# [1] 0.3181325

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_CN %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean = mean((wt_percent_c/wt_percent_n), na.rm = TRUE),
    se = std.error((wt_percent_c/wt_percent_n), na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Carbon:Nitrogen in Tissue") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest((wt_percent_c/wt_percent_n)~Phase_1_treat*Phase_2_treat, Tissue_CN) 
m1.e <- residuals(m3)
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 1.805042 0.03734251
#       170       NA         NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 4. Mg Carbon and Nitrogen in Tissue

# %%
# Read in growth dataset
setwd("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC")
weight_df <- read_csv("Year_2_Data/growth_YEAR2_weights_merged.csv")
# Out:
# New names:
# • `` -> `...1`
# Rows: 572 Columns: 45
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (22): Sample_Name, Phase_1_DO, Phase_1_temp, Phase_2.1_DO, Phase_2.1_temp, Phase_1_treat, Phase_2_treat, Phase_1...
# dbl (23): ...1, Actual_shell_pre_mg, Actual_tissue_pre_mg, Actual_shell_post_mg, Actual_tissue_post_mg, Actual_shell...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#calculate % N averages Tissue

summary_stats_t <- Tissue_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  summarize(
    mean_N = mean(wt_percent_n, na.rm = TRUE),
    mean_C = mean(wt_percent_c, na.rm = TRUE))

print(summary_stats_t)
# Out:
# `summarise()` has regrouped the output.
# ℹ Summaries were computed grouped by Phase_1_treat and Phase_2_treat.
# ℹ Output is grouped by Phase_1_treat.
# ℹ Use `summarise(.groups = "drop_last")` to silence this message.
# ℹ Use `summarise(.by = c(Phase_1_treat, Phase_2_treat))` for per-operation
#   grouping (`?dplyr::dplyr_by`) instead.
# # A tibble: 16 × 4
# # Groups:   Phase_1_treat [4]
#    Phase_1_treat Phase_2_treat mean_N mean_C
#    <chr>         <chr>          <dbl>  <dbl>
#  1 Both          Both            6.27   54.5
#  2 Both          Cont            6.66   42.2
#  3 Both          Hyp             6.32   52.6
#  4 Both          Warm            7.57   47.9
#  5 Cont          Both            6.22   51.8
#  6 Cont          Cont            7.36   44.6
#  7 Cont          Hyp             7.28   48.6
#  8 Cont          Warm            7.93   43.0
#  9 Hyp           Both            6.79   51.9
# 10 Hyp           Cont            7.04   44.2
# 11 Hyp           Hyp             7.43   50.0
# 12 Hyp           Warm            7.1    44.7
# 13 Warm          Both            6.39   51.2
# 14 Warm          Cont            7.21   41.6
# 15 Warm          Hyp             6.38   50.7
# 16 Warm          Warm            7.49   43.3

# %%
Tissue_Nutrients <- weight_df %>%
  filter(Exclude_year2 != "Y" | is.na(Exclude_year2)) %>%
  left_join(
    summary_stats_t,
    by = c("Phase_1_treat", "Phase_2_treat")) %>%
  mutate(mgN_tissue_P2 = (Actual_tissue_post_mg * mean_N) / 100)%>%
  mutate(mgC_tissue_P2 = (Actual_tissue_post_mg * mean_C) / 100)

View(Tissue_Nutrients)
# Out:
#     ...1 Sample_Name            Phase_1_DO Phase_1_temp Phase_2.1_DO Phase_2.1_temp Phase_1_treat Phase_2_treat
# 1    2   2024_Both01_Both02_O14 Hyp        Warm         Hyp          Warm           Both          Both
# 2    3   2024_Both01_Both03_O26 Hyp        Warm         Hyp          Warm           Both          Both
# 3    4   2024_Both01_Both05_O49 Hyp        Warm         Hyp          Warm           Both          Both
# 4    5   2024_Both01_Both05_O50 Hyp        Warm         Hyp          Warm           Both          Both
# 5    6   2024_Both01_Both06_O61 Hyp        Warm         Hyp          Warm           Both          Both
# 6    8   2024_Both01_Cont02_O13 Hyp        Warm         Norm         Ambient        Both          Cont
# 7    9   2024_Both01_Cont02_O14 Hyp        Warm         Norm         Ambient        Both          Cont
# 8   10   2024_Both01_Cont04_O38 Hyp        Warm         Norm         Ambient        Both          Cont
# 9   11   2024_Both01_Cont06_O61 Hyp        Warm         Norm         Ambient        Both          Cont
# 10  12   2024_Both01_Cont06_O62 Hyp        Warm         Norm         Ambient        Both          Cont
# 11  13   2024_Both01_Hyp02_O13  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 12  14   2024_Both01_Hyp02_O14  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 13  15   2024_Both01_Hyp03_O25  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 14  16   2024_Both01_Hyp03_O26  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 15  17   2024_Both01_Hyp04_O38  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 16  19   2024_Both01_Warm02_O13 Hyp        Warm         Norm         Warm           Both          Warm
# 17  20   2024_Both01_Warm02_O14 Hyp        Warm         Norm         Warm           Both          Warm
# 18  22   2024_Both01_Warm03_O26 Hyp        Warm         Norm         Warm           Both          Warm
# 19  23   2024_Both01_Warm06_O61 Hyp        Warm         Norm         Warm           Both          Warm
# 20  24   2024_Both01_Warm06_O62 Hyp        Warm         Norm         Warm           Both          Warm
# 21  25   2024_Both02_Both02_O15 Hyp        Warm         Hyp          Warm           Both          Both
# 22  26   2024_Both02_Both02_O16 Hyp        Warm         Hyp          Warm           Both          Both
# 23  27   2024_Both02_Both03_O28 Hyp        Warm         Hyp          Warm           Both          Both
# 24  28   2024_Both02_Both04_O39 Hyp        Warm         Hyp          Warm           Both          Both
# 25  29   2024_Both02_Both06_O63 Hyp        Warm         Hyp          Warm           Both          Both
# 26  33   2024_Both02_Cont03_O28 Hyp        Warm         Norm         Ambient        Both          Cont
# 27  34   2024_Both02_Cont05_O51 Hyp        Warm         Norm         Ambient        Both          Cont
# 28  35   2024_Both02_Cont05_O52 Hyp        Warm         Norm         Ambient        Both          Cont
# 29  36   2024_Both02_Cont06_O64 Hyp        Warm         Norm         Ambient        Both          Cont
# 30  39   2024_Both02_Hyp03_O28  Hyp        Warm         Hyp          Ambient        Both          Hyp
# 472  387.70464                    0.5689028      NA            7.490909 43.33636 31.658162     183.14862
# 473  172.52246                    0.3781915      NA            7.490909 43.33636 14.409149      83.35972

# %% [markdown]
# ### 4.1 Mg Nitrogen Analysis

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgN_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgN_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue nitrogen
m1 <- lmer(log(mgN_tissue_P2)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         4.033926e+03 1  22.93804 0.0000
# Phase_1_DO                                          1.902932e+00 1  17.56705 0.1851
# Phase_1_temp                                        1.078816e+00 1  14.77118 0.3157
# Phase_2.1_temp                                      4.619757e-03 1  19.46234 0.9465
# Phase_2.1_DO                                        4.721941e+00 1  19.50622 0.0423
# Phase_1_DO:Phase_1_temp                             5.499888e-03 1  14.35199 0.9419
# Phase_1_DO:Phase_2.1_temp                           9.227149e-03 1  18.70529 0.9245
# Phase_1_temp:Phase_2.1_temp                         5.701201e-01 1  18.48061 0.4597
# Phase_1_DO:Phase_2.1_DO                             6.008992e-01 1  18.80955 0.4479
# Phase_1_temp:Phase_2.1_DO                           5.479104e+00 1  18.58418 0.0306
# Phase_2.1_temp:Phase_2.1_DO                         8.641933e-01 1  19.49112 0.3639
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              3.033590e-01 1  18.40728 0.5884
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                7.434885e-03 1  18.53701 0.9322
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.507202e+00 1  18.81855 0.2347
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.511347e+00 1  18.63807 0.1299
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 5.569250e+00 1  18.57560 0.0294

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean     SE   df lower.CL upper.CL
#  Hyp            2.99 0.0656 21.7     2.85     3.12
#  Norm           3.18 0.0672 22.1     3.05     3.32
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate     SE   df t.ratio p.value
#  Hyp - Norm   -0.197 0.0905 19.5  -2.173  0.0423
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.

# %%
(3.18 - 2.99)/3.18
# Out:
# [1] 0.05974843

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_Nutrients %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean = mean(mgN_tissue_P2, na.rm = TRUE),
    se = std.error(mgN_tissue_P2, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Nitrogen in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO, adjust = "none")
# Out:
# $emmeans
#  Phase_1_DO Phase_1_temp Phase_2.1_temp Phase_2.1_DO emmean    SE   df lower.CL upper.CL
#  Hyp        Ambient      Ambient        Hyp            3.07 0.126 56.1     2.81     3.32
#  Norm       Ambient      Ambient        Hyp            3.24 0.124 54.4     2.99     3.49
#  Hyp        Warm         Ambient        Hyp            2.88 0.122 51.2     2.63     3.12
#  Norm       Warm         Ambient        Hyp            2.92 0.122 51.3     2.68     3.17
#  Norm Ambient Ambient Norm - Hyp Warm Ambient Norm    -0.01058 0.145 38.9  -0.073  0.9423
#  Norm Ambient Ambient Norm - Norm Warm Ambient Norm   -0.19604 0.137 44.7  -1.431  0.1595
#  Norm Ambient Ambient Norm - Hyp Ambient Warm Norm    -0.00499 0.180 54.8  -0.028  0.9780
#  Norm Ambient Ambient Norm - Norm Ambient Warm Norm   -0.29962 0.175 53.0  -1.714  0.0923
#  Norm Ambient Ambient Norm - Hyp Warm Warm Norm       -0.13030 0.179 54.1  -0.727  0.4705
#  Norm Ambient Ambient Norm - Norm Warm Warm Norm      -0.18712 0.181 56.1  -1.032  0.3063
#  Hyp Warm Ambient Norm - Norm Warm Ambient Norm       -0.18546 0.139 35.7  -1.334  0.1906
#  Hyp Warm Ambient Norm - Hyp Ambient Warm Norm         0.00559 0.174 48.2   0.032  0.9745
#  Hyp Warm Ambient Norm - Norm Ambient Warm Norm       -0.28904 0.176 50.1  -1.642  0.1069
#  Hyp Warm Ambient Norm - Hyp Warm Warm Norm           -0.11972 0.166 43.7  -0.722  0.4744
#  Hyp Warm Ambient Norm - Norm Warm Warm Norm          -0.17654 0.175 49.5  -1.007  0.3190
#  Norm Warm Ambient Norm - Hyp Ambient Warm Norm        0.19105 0.175 51.5   1.090  0.2807
#  Norm Warm Ambient Norm - Norm Ambient Warm Norm      -0.10358 0.177 53.6  -0.585  0.5611
#  Norm Warm Ambient Norm - Hyp Warm Warm Norm           0.06574 0.174 50.8   0.377  0.7077
#  Norm Warm Ambient Norm - Norm Warm Warm Norm          0.00892 0.169 49.1   0.053  0.9581
#  Hyp Ambient Warm Norm - Norm Ambient Warm Norm       -0.29463 0.135 39.3  -2.185  0.0349
#  Hyp Ambient Warm Norm - Hyp Warm Warm Norm           -0.12531 0.122 34.9  -1.028  0.3112
#  Hyp Ambient Warm Norm - Norm Warm Warm Norm          -0.18213 0.135 38.5  -1.350  0.1851
#  Norm Ambient Warm Norm - Hyp Warm Warm Norm           0.16932 0.135 38.1   1.257  0.2163
#  Norm Ambient Warm Norm - Norm Warm Warm Norm          0.11249 0.127 40.8   0.883  0.3825
#  Hyp Warm Warm Norm - Norm Warm Warm Norm             -0.05683 0.133 37.1  -0.429  0.6708
#
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.

# %%
        cont warm comparisons:
Hyp Ambient Warm Norm - Norm Ambient Warm Norm        -9.6803 4.37 40.2  -2.215  0.0325
    hyp warm - cont warm
Norm Ambient Ambient Norm - Norm Ambient Warm Norm   -11.0574 5.23 61.7  -2.114  0.0385
    cont cont - cont warm
Norm Warm Warm Hyp - Norm Ambient Warm Norm          -13.9855 5.17 61.8  -2.705  0.0088
    warm both - cont warm
Hyp Warm Warm Hyp - Norm Ambient Warm Norm           -13.7876 5.12 59.6  -2.695  0.0091
    both both - cont warm
Norm Ambient Warm Hyp - Norm Ambient Warm Norm       -13.9494 4.94 56.0  -2.825  0.0065
    cont both - cont warm
Norm Warm Ambient Hyp - Norm Ambient Warm Norm       -14.3652 5.15 61.0  -2.790  0.0070
    warm hyp - cont warm
Hyp Warm Ambient Hyp - Norm Ambient Warm Norm        -14.7909 5.14 60.9  -2.876  0.0055
    both hyp - cont warm
Hyp Ambient Ambient Hyp - Norm Ambient Warm Norm     -11.0441 5.22 63.6  -2.116  0.0383
    hyp hyp - cont warm

Norm Ambient Ambient Hyp - Hyp Warm Ambient Hyp        9.2708 4.41 41.7   2.102  0.0416
    cont hyp - both hyp
Norm Ambient Ambient Hyp - Norm Warm Ambient Hyp       8.8452 4.02 43.2   2.198  0.0334
    cont hyp - warm hyp   interesting !

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#tissue nitrogen
summary_stats <- Tissue_Nutrients %>%
  group_by(Phase_1_DO) %>%
  mutate(
    mean = mean(mgN_tissue_P2, na.rm = TRUE),
    se = std.error(mgN_tissue_P2, na.rm = TRUE))

#reorder
summary_stats$Phase_1_DO <- factor(summary_stats$Phase_1_DO, levels = c("Norm", "Hyp"))

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_1_DO, y = mean, color = Phase_1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.05, position = position_dodge(0.9)) + 
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 1 DO", y = "Nitrogen in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_temp:Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp Phase_2.1_DO emmean     SE   df lower.CL upper.CL
#  Ambient      Hyp            3.07 0.0743 31.0     2.91     3.22
#  Warm         Hyp            2.91 0.0738 30.5     2.76     3.06
#  Ambient      Norm           3.16 0.0761 31.8     3.01     3.32
#  Warm         Norm           3.21 0.0752 30.5     3.05     3.36
#
# Results are averaged over the levels of: Phase_1_DO, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.
# Confidence level used: 0.95
#
# $contrasts
#  contrast                   estimate     SE   df t.ratio p.value
#  Ambient Hyp - Warm Hyp       0.1552 0.0686 20.7   2.262  0.0346
#  Ambient Hyp - Ambient Norm  -0.0985 0.1000 27.9  -0.981  0.3348
#  Ambient Hyp - Warm Norm     -0.1398 0.1060 30.8  -1.322  0.1959
#  Warm Hyp - Ambient Norm     -0.2537 0.1060 31.2  -2.393  0.0229
#  Warm Hyp - Warm Norm        -0.2950 0.0993 26.9  -2.972  0.0062
#  Ambient Norm - Warm Norm    -0.0413 0.0695 20.4  -0.594  0.5590
#
# Results are averaged over the levels of: Phase_1_DO, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.

# %%
(3.07 -2.91)/3.07
# Out:
# [1] 0.05211726

# %%
(3.16-2.91)/3.16
# Out:
# [1] 0.07911392

# %%
(3.21-2.91)/3.21
# Out:
# [1] 0.09345794

# %%
#format for jupyter
options(repr.plot.width = 10, repr.plot.height = 6)

#tissue nitrogen Phase_1_temp:Phase_2.1_DO
summary_stats_t <- Tissue_Nutrients %>%
  group_by(Phase_1_temp, Phase_2.1_DO) %>%
  mutate(
    mean = mean(mgN_tissue_P2, na.rm = TRUE),
    se = std.error(mgN_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_temp <- factor(summary_stats_t$Phase_1_temp, 
                                        levels = c("Ambient", "Warm"))
summary_stats_t$Phase_2.1_DO <- factor(summary_stats_t$Phase_2.1_DO, 
                                        levels = c("Norm", "Hyp"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_temp, y = mean, color = Phase_1_temp)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean - se, ymax = mean + se), 
                width = 0.1, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2.1_DO), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Norm" = "Normoxic")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Warm" = "#B00149", "Ambient" = "darkblue")) +
  labs(x = "Phase 1 Temperature", y = "Nitrogen in Tissue (Mg)") +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
ylim(15, 30)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(log(mgN_tissue_P2)~Phase_1_treat*Phase_2_treat, Tissue_Nutrients) 
m1.e <- residuals(m1)
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 1.027726 0.4246896
#       457       NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ### 4.2 Mg Carbon Analysis

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgC_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon
m1 <- lmer(mgC_tissue_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+ Actual_tissue_pre_mg+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         2.382263e+01 1   69.62919 0.0000
# Phase_1_DO                                          4.744993e+00 1   12.28007 0.0496
# Phase_1_temp                                        4.653852e-01 1   10.16426 0.5104
# Phase_2.1_temp                                      3.840647e+00 1   19.07993 0.0648
# Phase_2.1_DO                                        6.948980e+00 1   19.08321 0.0162
# Actual_tissue_pre_mg                                2.288582e+03 1  385.11183 0.0000
# Phase_1_DO:Phase_1_temp                             2.343109e-01 1   10.18386 0.6386
# Phase_1_DO:Phase_2.1_temp                           5.857969e-01 1   18.90677 0.4535
# Phase_1_temp:Phase_2.1_temp                         2.048976e+00 1   18.91721 0.1686
# Phase_1_DO:Phase_2.1_DO                             4.812620e-03 1   18.92880 0.9454
# Phase_1_temp:Phase_2.1_DO                           2.947277e-02 1   19.00927 0.8655
# Phase_2.1_temp:Phase_2.1_DO                         1.299764e+00 1   19.12183 0.2683
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              8.046834e-03 1   18.81659 0.9295
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.531285e-01 1   18.85461 0.6207
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              3.921078e-02 1   19.07096 0.8451
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            4.638010e+00 1   19.06297 0.0443
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.389833e-01 1   19.01831 0.7134

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp Phase_2.1_temp Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Ambient      Ambient        Hyp             142 4.91 25.6      132      152
#  Warm         Ambient        Hyp             140 4.91 25.7      130      151
#  Ambient      Warm           Hyp             151 4.90 25.4      141      161
#  Warm         Warm           Hyp             151 4.93 26.0      140      161
#  Ambient      Ambient        Norm            157 4.89 25.2      147      167
#  Warm         Ambient        Norm            156 4.92 25.9      146      166
#  Ambient      Warm           Norm            161 4.89 25.1      151      171
#  Warm         Warm           Norm            142 4.91 25.7      132      152
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                   estimate   SE   df t.ratio p.value
#  Ambient Ambient Hyp - Warm Ambient Hyp        1.565 3.54 19.0   0.442  0.6634
#  Ambient Ambient Hyp - Ambient Warm Hyp       -8.815 6.94 25.7  -1.271  0.2152
#  Ambient Ambient Hyp - Warm Warm Hyp          -8.554 6.96 25.9  -1.229  0.2301
#  Ambient Ambient Hyp - Ambient Ambient Norm  -14.574 6.93 25.5  -2.104  0.0454
#  Ambient Ambient Hyp - Warm Ambient Norm     -13.890 6.95 25.7  -1.999  0.0563
#  Ambient Ambient Hyp - Ambient Warm Norm     -18.668 6.92 25.5  -2.696  0.0122
#  Ambient Ambient Hyp - Warm Warm Norm         -0.305 6.94 25.6  -0.044  0.9653
#  Warm Ambient Hyp - Ambient Warm Hyp         -10.380 6.94 25.6  -1.496  0.1469
#  Warm Ambient Hyp - Warm Warm Hyp            -10.119 6.96 26.0  -1.454  0.1578
#  Warm Ambient Hyp - Ambient Ambient Norm     -16.139 6.93 25.4  -2.329  0.0281
#  Warm Ambient Hyp - Warm Ambient Norm        -15.455 6.96 26.0  -2.222  0.0352
#  Warm Ambient Hyp - Ambient Warm Norm        -20.233 6.93 25.4  -2.920  0.0072
#  Warm Ambient Hyp - Warm Warm Norm            -1.870 6.95 25.9  -0.269  0.7900
#  Ambient Warm Hyp - Warm Warm Hyp              0.261 3.54 19.1   0.074  0.9420
#  Ambient Warm Hyp - Ambient Ambient Norm      -5.759 6.92 25.4  -0.832  0.4129
#  Ambient Warm Hyp - Warm Ambient Norm         -5.075 6.95 25.7  -0.730  0.4718
#  Ambient Warm Hyp - Ambient Warm Norm         -9.853 6.92 25.4  -1.424  0.1666
#  Ambient Warm Hyp - Warm Warm Norm             8.510 6.94 25.6   1.226  0.2312
#  Warm Warm Hyp - Ambient Ambient Norm         -6.020 6.94 25.5  -0.868  0.3935
#  Warm Warm Hyp - Warm Ambient Norm            -5.336 6.97 26.1  -0.766  0.4507
#  Warm Warm Hyp - Ambient Warm Norm           -10.115 6.94 25.6  -1.458  0.1571
#  Warm Warm Hyp - Warm Warm Norm                8.249 6.96 26.0   1.186  0.2465
#  Ambient Ambient Norm - Warm Ambient Norm      0.684 3.53 18.8   0.194  0.8482
#  Ambient Ambient Norm - Ambient Warm Norm     -4.094 6.91 25.3  -0.593  0.5588
#  Ambient Ambient Norm - Warm Warm Norm        14.269 6.93 25.4   2.059  0.0498
#  Warm Ambient Norm - Ambient Warm Norm        -4.779 6.94 25.5  -0.689  0.4971
#  Warm Ambient Norm - Warm Warm Norm           13.585 6.96 26.0   1.953  0.0617
#  Ambient Warm Norm - Warm Warm Norm           18.363 3.51 18.4   5.233 <0.0001
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger

# %%
#format display for jupyter
options(repr.plot.width = 12, repr.plot.height = 6)

# plot Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO tissue
summary_stats_t <- Tissue_Nutrients%>%
  group_by(Phase_1_temp, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgC_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_temp <- factor(summary_stats_t$Phase_1_temp, 
                                       levels = c("Ambient", "Warm"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp",  "Both"))

#plot with mean and SD
ggplot(summary_stats_t, aes(x = Phase_1_temp, y = mean_growth, color = Phase_1_temp)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 16) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(
    vars(Phase_2_treat),
    labeller = as_labeller(c(
      "Hyp" = "Hypoxic",
      "Cont" = "Control",
      "Warm" = "Warm",
      "Both" = "Both")), scales = "fixed", nrow = 1) +
  scale_color_manual(values = c("Warm" = "#B00149", "Ambient" = "darkblue")) +
  labs(x = "Phase 1 Temperature", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
ylim(120, 210)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
 Ambient Ambient Hyp - Ambient Ambient Norm  -14.574 6.93 25.5  -2.104  0.0454
    amb hyp - amb cont
 Ambient Ambient Hyp - Ambient Warm Norm     -18.668 6.92 25.5  -2.696  0.0122
    amb hyp - amb warm
 Warm Ambient Hyp - Ambient Ambient Norm     -16.139 6.93 25.4  -2.329  0.0281
    warm hyp - amb cont
 Warm Ambient Hyp - Warm Ambient Norm        -15.455 6.96 26.0  -2.222  0.0352
    warm hyp - warm cont
 Warm Ambient Hyp - Ambient Warm Norm        -20.233 6.93 25.4  -2.920  0.0072
    warm hyp - amb warm
 Ambient Ambient Norm - Warm Warm Norm        14.269 6.93 25.4   2.059  0.0498
    amb cont - warm warm
 Ambient Warm Norm - Warm Warm Norm           18.363 3.51 18.4   5.233 <0.0001
    amb warm - warm warm

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO emmean   SE   df lower.CL upper.CL
#  Hyp           172 3.08 22.5      166      179
#  Norm          164 3.13 24.3      158      171
#
# Results are averaged over the levels of: Phase_1_temp, Phase_2.1_temp, Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate   SE   df t.ratio p.value
#  Hyp - Norm     8.01 3.68 12.3   2.178  0.0496
#
# Results are averaged over the levels of: Phase_1_temp, Phase_2.1_temp, Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger

# %%
(172-164)/172
# Out:
# [1] 0.04651163

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Hyp             175 3.49 18.4      167      182
#  Norm            162 3.58 18.4      154      169
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate   SE   df t.ratio p.value
#  Hyp - Norm     13.2 5.01 19.1   2.636  0.0162
#
# Results are averaged over the levels of: Phase_1_DO, Phase_1_temp, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %%
(175-162)/175
# Out:
# [1] 0.07428571

# %%
#format display for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#summary stats
summary_stats <- Tissue_Nutrients %>%
  group_by(Phase_1_DO) %>%
  mutate(
    mean_cn = mean(mgC_tissue_P2, na.rm = TRUE),
    se_cn = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder
summary_stats$Phase_1_DO <- factor(summary_stats$Phase_1_DO, levels = c("Norm", "Hyp"))
#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_1_DO, y = mean_cn, color = Phase_1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_cn - se_cn, ymax = mean_cn + se_cn), 
                width = 0.05, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 1 DO", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  ylim(150,200)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#format display for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#summary stats
summary_stats <- Tissue_Nutrients %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean_cn = mean(mgC_tissue_P2, na.rm = TRUE),
    se_cn = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))
#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean_cn, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_cn - se_cn, ymax = mean_cn + se_cn), 
                width = 0.05, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  ylim(150,190)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(mgC_tissue_P2~Phase_1_treat*Phase_2_treat, Tissue_Nutrients) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 1.342198 0.1726835
#       457       NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# # Shell

# %% [markdown]
# ## 1. % Nitrogen in Shell

# %%
#filter data
Shell_Nitrogen <- nutrient_df%>%
filter(Tissue_type == "S")%>%
filter(is.na(N_Exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_Nitrogen %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  ylim(0.1, 0.25)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell nitrogen
m1 <- lmer(wt_percent_n~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nitrogen, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         1.452624e+03 1  10.229112 0.0000
# Phase_1_DO                                          4.314664e-01 1   9.793364 0.5264
# Phase_1_temp                                        7.978597e-01 1   9.795704 0.3931
# Phase_2.1_temp                                      3.442463e-01 1  18.678531 0.5644
# Phase_2.1_DO                                        1.415425e+00 1  18.734460 0.2490
# Phase_1_DO:Phase_1_temp                             1.801189e-01 1   9.794467 0.6804
# Phase_1_DO:Phase_2.1_temp                           1.543166e-01 1  18.646554 0.6989
# Phase_1_temp:Phase_2.1_temp                         2.419900e-02 1  18.648084 0.8781
# Phase_1_DO:Phase_2.1_DO                             8.061719e-03 1  18.707380 0.9294
# Phase_1_temp:Phase_2.1_DO                           7.469170e-01 1  18.709358 0.3984
# Phase_2.1_temp:Phase_2.1_DO                         2.094671e-01 1  18.705737 0.6525
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.770747e+00 1  18.648322 0.1993
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.894392e-02 1  18.708539 0.8667
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              8.033208e+00 1  18.677057 0.0107
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            3.596102e-01 1  18.678530 0.5559
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.030182e+00 1  18.678251 0.1707

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO*Phase_2.1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_2.1_temp Phase_2.1_DO emmean     SE   df lower.CL upper.CL
#  Hyp        Ambient        Hyp           0.175 0.0117 36.4    0.151    0.199
#  Norm       Ambient        Hyp           0.150 0.0117 36.4    0.126    0.174
#  Hyp        Warm           Hyp           0.164 0.0122 41.8    0.139    0.188
#  Norm       Warm           Hyp           0.179 0.0117 36.1    0.155    0.203
#  Hyp        Ambient        Norm          0.146 0.0118 28.3    0.122    0.170
#  Norm       Ambient        Norm          0.167 0.0118 24.8    0.142    0.191
#  Hyp        Warm           Norm          0.174 0.0119 39.3    0.150    0.198
#  Norm       Warm           Norm          0.141 0.0123 41.4    0.116    0.166
#
# Results are averaged over the levels of: Phase_1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                             estimate     SE   df t.ratio p.value
#  Hyp Ambient Hyp - Norm Ambient Hyp    0.02500 0.0163 18.7   1.533  0.1421
#  Hyp Ambient Hyp - Hyp Warm Hyp        0.01142 0.0169 41.2   0.675  0.5031
#  Hyp Ambient Hyp - Norm Warm Hyp      -0.00417 0.0165 36.3  -0.252  0.8022
#  Hyp Ambient Hyp - Hyp Ambient Norm    0.02904 0.0166 33.6   1.746  0.0900
#  Hyp Ambient Hyp - Norm Ambient Norm   0.00843 0.0166 29.9   0.508  0.6153
#  Hyp Ambient Hyp - Hyp Warm Norm       0.00113 0.0167 39.6   0.068  0.9462
#  Hyp Ambient Hyp - Norm Warm Norm      0.03415 0.0169 38.9   2.019  0.0505
#  Norm Ambient Hyp - Hyp Warm Hyp      -0.01358 0.0169 39.1  -0.803  0.4266
#  Norm Ambient Hyp - Norm Warm Hyp     -0.02917 0.0165 38.4  -1.768  0.0851
#  Norm Ambient Hyp - Hyp Ambient Norm   0.00404 0.0166 32.1   0.243  0.8094
#  Norm Ambient Hyp - Norm Ambient Norm -0.01657 0.0166 31.1  -0.999  0.3257
#  Norm Ambient Hyp - Hyp Warm Norm     -0.02387 0.0167 37.9  -1.430  0.1610
#  Norm Ambient Hyp - Norm Warm Norm     0.00915 0.0169 41.4   0.541  0.5917
#  Hyp Warm Hyp - Norm Warm Hyp         -0.01558 0.0167 20.2  -0.932  0.3626
#  Hyp Warm Hyp - Hyp Ambient Norm       0.01762 0.0170 36.1   1.035  0.3075
#  Hyp Warm Hyp - Norm Ambient Norm     -0.00299 0.0170 32.1  -0.176  0.8614
#  Hyp Warm Hyp - Hyp Warm Norm         -0.01029 0.0171 42.5  -0.602  0.5506
#  Hyp Warm Hyp - Norm Warm Norm         0.02273 0.0173 41.6   1.313  0.1964
#  Norm Warm Hyp - Hyp Ambient Norm      0.03321 0.0166 32.0   1.997  0.0544
#  Norm Warm Hyp - Norm Ambient Norm     0.01259 0.0166 31.2   0.758  0.4540
#  Norm Warm Hyp - Hyp Warm Norm         0.00530 0.0167 37.7   0.317  0.7528
#  Norm Warm Hyp - Norm Warm Norm        0.03832 0.0170 41.6   2.259  0.0292
#  Hyp Ambient Norm - Norm Ambient Norm -0.02061 0.0165 13.8  -1.249  0.2324
#  Hyp Ambient Norm - Hyp Warm Norm     -0.02791 0.0168 34.7  -1.659  0.1062
#  Hyp Ambient Norm - Norm Warm Norm     0.00511 0.0170 34.4   0.300  0.7661
#  Norm Ambient Norm - Hyp Warm Norm    -0.00729 0.0168 31.1  -0.435  0.6669
#  Norm Ambient Norm - Norm Warm Norm    0.02572 0.0170 33.4   1.514  0.1394
#  Hyp Warm Norm - Norm Warm Norm        0.03302 0.0169 21.1   1.951  0.0645
#
# Results are averaged over the levels of: Phase_1_temp
# Degrees-of-freedom method: kenward-roger

# %%
#diagnostics
leveneTest(wt_percent_n~Phase_1_treat*Phase_2_treat, Shell_Nitrogen) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.7509331 0.7297672
#       171        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 2. % Carbon in Shell

# %%
#filter data
Shell_Carbon <- nutrient_df%>%
filter(Tissue_type == "S")#%>%
#filter(is.na(c_exclude))

# %%
#tissue carbon
summary_stats_t <- Shell_Carbon %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_c, na.rm = TRUE),
    se_growth = std.error(wt_percent_c, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
ylim(15,18)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##Shell carbon
m2 <- lmer(wt_percent_c~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Carbon, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         1.577697e+04 1  19.76095 0.0000
# Phase_1_DO                                          1.214818e-03 1  17.47838 0.9726
# Phase_1_temp                                        3.388217e-01 1  16.21872 0.5685
# Phase_2.1_temp                                      3.780803e+00 1  18.44756 0.0673
# Phase_2.1_DO                                        2.191686e+00 1  18.62181 0.1555
# Phase_1_DO:Phase_1_temp                             1.617231e-01 1  16.21789 0.6928
# Phase_1_DO:Phase_2.1_temp                           9.608654e-01 1  18.07660 0.3399
# Phase_1_temp:Phase_2.1_temp                         1.036737e-01 1  17.88881 0.7512
# Phase_1_DO:Phase_2.1_DO                             6.421946e-02 1  18.29592 0.8028
# Phase_1_temp:Phase_2.1_DO                           3.901417e-01 1  18.14334 0.5400
# Phase_2.1_temp:Phase_2.1_DO                         1.397451e+00 1  18.56265 0.2521
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.273469e-01 1  17.89108 0.7254
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                7.448995e-02 1  18.12761 0.7880
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              2.402552e-02 1  18.23764 0.8785
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.241718e-01 1  18.06967 0.6415
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.351436e-04 1  18.06506 0.9879

# %%
#format display for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#summary stats
summary_stats <- Shell_Carbon %>%
  group_by(Phase_2.1_DO) %>%
  mutate(
    mean_cn = mean(wt_percent_c, na.rm = TRUE),
    se_cn = std.error(wt_percent_c, na.rm = TRUE))

#reorder
summary_stats$Phase_2.1_DO <- factor(summary_stats$Phase_2.1_DO, levels = c("Norm", "Hyp"))
#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_2.1_DO, y = mean_cn, color = Phase_2.1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_cn - se_cn, ymax = mean_cn + se_cn), 
                width = 0.05, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 2 DO", y = "Carbon in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Norm" = "Normoxic")) +
  ylim(16,18)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#diagnostics
leveneTest(wt_percent_c~Phase_1_treat*Phase_2_treat, Shell_Carbon) 
m1.e <- residuals(m2) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.7784794 0.7001369
#       171        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 3. Carbon:Nitrogen in Shell

# %%
#filter data
Shell_CN <- df%>%
filter(Tissue_type == "S")%>%
filter(is.na(n_exclude))%>%
filter(is.na(c_exclude))%>%
mutate(C_N = (wt_percent_c/wt_percent_n))

# %%
#tissue c:n
summary_stats_t <- Shell_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(C_N, na.rm = TRUE),
    se_growth = std.error(C_N, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell carbon:nitrogen
m3 <- lmer((wt_percent_c/wt_percent_n)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_CN, REML=TRUE)
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         1.574742e+03 1  14.68914 0.0000
# Phase_1_DO                                          3.676224e-01 1  10.52370 0.5572
# Phase_1_temp                                        1.231866e+00 1  10.52333 0.2918
# Phase_2.1_temp                                      3.421284e+00 1  19.77954 0.0794
# Phase_2.1_DO                                        2.086412e-01 1  19.77954 0.6528
# Phase_1_DO:Phase_1_temp                             5.242249e-02 1  10.52370 0.8233
# Phase_1_DO:Phase_2.1_temp                           1.886709e+00 1  19.58366 0.1851
# Phase_1_temp:Phase_2.1_temp                         2.618342e+00 1  19.58384 0.1216
# Phase_1_DO:Phase_2.1_DO                             6.598977e-01 1  19.58366 0.4264
# Phase_1_temp:Phase_2.1_DO                           3.896123e-01 1  19.58384 0.5397
# Phase_2.1_temp:Phase_2.1_DO                         2.802683e-02 1  19.77954 0.8687
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.246871e+00 1  19.58366 0.2777
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.114544e+00 1  19.58366 0.3039
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              5.868425e-01 1  19.58366 0.4528
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.335318e-03 1  19.58384 0.9619
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.633981e-01 1  19.58366 0.6135

# %%
#diagnostics
leveneTest(C_N~Phase_1_treat*Phase_2_treat, Shell_CN) 
m1.e <- residuals(m3) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.9179332 0.5453829
#       174        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 4. Mg Carbon and Nitrogen in Shell

# %%
#calculate % N averages Tissue

summary_stats_s <- Shell_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  summarize(
    mean_N = mean(wt_percent_n, na.rm = TRUE),
    mean_C = mean(wt_percent_c, na.rm = TRUE))

print(summary_stats_s)
# Out:
# `summarise()` has regrouped the output.
# ℹ Summaries were computed grouped by Phase_1_treat and Phase_2_treat.
# ℹ Output is grouped by Phase_1_treat.
# ℹ Use `summarise(.groups = "drop_last")` to silence this message.
# ℹ Use `summarise(.by = c(Phase_1_treat, Phase_2_treat))` for per-operation
#   grouping (`?dplyr::dplyr_by`) instead.
# # A tibble: 16 × 4
# # Groups:   Phase_1_treat [4]
#    Phase_1_treat Phase_2_treat mean_N mean_C
#    <chr>         <chr>          <dbl>  <dbl>
#  1 Both          Both           0.217   16.8
#  2 Both          Cont           0.22    16.2
#  3 Both          Hyp            0.208   16.4
#  4 Both          Warm           0.2     16.3
#  5 Cont          Both           0.233   16.4
#  6 Cont          Cont           0.2     16.4
#  7 Cont          Hyp            0.217   16.1
#  8 Cont          Warm           0.225   16.4
#  9 Hyp           Both           0.192   16.1
# 10 Hyp           Cont           0.242   16.4
# 11 Hyp           Hyp            0.217   16.5
# 12 Hyp           Warm           0.192   15.9
# 13 Warm          Both           0.192   16.6
# 14 Warm          Cont           0.242   16.9
# 15 Warm          Hyp            0.208   16.2
# 16 Warm          Warm           0.2     16.4

# %%
Shell_Nutrients <- weight_df %>%
  filter(Exclude_all != "Y" | is.na(Exclude_all)) %>%
  left_join(
    summary_stats_s,
    by = c("Phase_1_treat", "Phase_2_treat")) %>%
  mutate(mgN_shell_P2 = (Actual_shell_post_mg * mean_N) / 100)%>%
  mutate(mgC_shell_P2 = (Actual_shell_post_mg * mean_C) / 100)

View(Shell_Nutrients)
# Out:
#      Sample_Name            Order_pre Date_MMDDYYYY_pre Year Phase_1_treat Phase_1_rep Phase_2_treat Phase_2_rep
# 1    2024_Both01_Both01_O1    3       7/23/24           2024 Both          01          Both          01
# 2    2024_Both01_Both01_O2    7       7/23/24           2024 Both          01          Both          01
# 3    2024_Both01_Both02_O13  50       7/23/24           2024 Both          01          Both          02
# 4    2024_Both01_Both02_O14  55       7/23/24           2024 Both          01          Both          02
# 5    2024_Both01_Both03_O25  98       7/24/24           2024 Both          01          Both          03
# 6    2024_Both01_Both03_O26 103       7/24/24           2024 Both          01          Both          03
# 7    2024_Both01_Both04_O37 214       7/24/24           2024 Both          01          Both          04
# 8    2024_Both01_Both04_O38 111       7/24/24           2024 Both          01          Both          04
# 9    2024_Both01_Both05_O49 260       7/25/24           2024 Both          01          Both          05
# 10   2024_Both01_Both05_O50 266       7/25/24           2024 Both          01          Both          05
# 11   2024_Both01_Both06_O61 383       7/26/24           2024 Both          01          Both          06
# 12   2024_Both01_Both06_O62 388       7/26/24           2024 Both          01          Both          06
# 13   2024_Both01_Cont01_O1  432       7/23/24           2024 Both          01          Cont          01
# 14   2024_Both01_Cont01_O2  172       7/23/24           2024 Both          01          Cont          01
# 15   2024_Both01_Cont02_O13 481       7/23/24           2024 Both          01          Cont          02
# 16   2024_Both01_Cont02_O14 485       7/23/24           2024 Both          01          Cont          02
# 17   2024_Both01_Cont03_O25 356       7/24/24           2024 Both          01          Cont          03
# 18   2024_Both01_Cont04_O37 620       7/24/24           2024 Both          01          Cont          04
# 19   2024_Both01_Cont04_O38 624       7/24/24           2024 Both          01          Cont          04
# 20   2024_Both01_Cont05_O49 669       7/25/24           2024 Both          01          Cont          05
# 21   2024_Both01_Cont05_O50 672       7/25/24           2024 Both          01          Cont          05
# 22   2024_Both01_Cont06_O61 729       7/25/24           2024 Both          01          Cont          06
# 23   2024_Both01_Cont06_O62 685       7/25/24           2024 Both          01          Cont          06
# 24   2024_Both01_Hyp01_O1   779       7/23/24           2024 Both          01          Hyp           01
# 25   2024_Both01_Hyp01_O2   115       7/23/24           2024 Both          01          Hyp           01
# 26   2024_Both01_Hyp02_O13  826       7/23/24           2024 Both          01          Hyp           02
# 27   2024_Both01_Hyp02_O14  830       7/23/24           2024 Both          01          Hyp           02
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgN_shell_P2, na.rm = TRUE),
    se_growth = std.error(mgN_shell_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Shell (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  ylim(1,2)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell nitrogen
m1 <- lmer(log(mgN_shell_P2)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F           Df Df.res   Pr(>F)
# (Intercept)                                         14.77985382 1  21.28009 0.0009
# Phase_1_DO                                          11.19688525 1  16.12409 0.0041
# Phase_1_temp                                         0.34375540 1  13.94367 0.5670
# Phase_2.1_temp                                       1.76911124 1  20.00035 0.1985
# Phase_2.1_DO                                         3.34565990 1  20.00056 0.0823
# Phase_1_DO:Phase_1_temp                              2.40449110 1  13.94811 0.1434
# Phase_1_DO:Phase_2.1_temp                            7.99549854 1  19.99935 0.0104
# Phase_1_temp:Phase_2.1_temp                          4.62675505 1  19.98383 0.0439
# Phase_1_DO:Phase_2.1_DO                              0.20973061 1  20.00183 0.6519
# Phase_1_temp:Phase_2.1_DO                           18.46876904 1  19.98677 0.0004
# Phase_2.1_temp:Phase_2.1_DO                          0.01016883 1  20.00057 0.9207
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp               7.20859676 1  19.99698 0.0142
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                 1.43130734 1  19.99999 0.2455
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO               4.03923352 1  20.00176 0.0581
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            12.11770268 1  19.98686 0.0024
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO  0.02793537 1  20.00010 0.8689

# %%
#diagnostics
leveneTest(log(mgN_shell_P2)~Phase_1_treat*Phase_2_treat, Shell_Nutrients) #FAILS LEVENE TEST
m1.e <- residuals(m1)
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df   F value   Pr(>F)
# group   15 0.9542526 0.5025115
#       1101        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ### 4.2 Mg Carbon Analysis

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgC_shell_P2, na.rm = TRUE),
    se_growth = std.error(mgC_shell_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Shell (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##Shell carbon
    #using tissue pre as a covariate
m1 <- lmer(mgC_shell_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+ Actual_tissue_pre_mg+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res     Pr(>F)
# (Intercept)                                         1.108161e+02 1    51.36879 0.0000
# Phase_1_DO                                          5.144037e+00 1    13.20620 0.0407
# Phase_1_temp                                        1.051415e-01 1    13.76883 0.7506
# Phase_2.1_temp                                      1.805551e-01 1    19.93525 0.6754
# Phase_2.1_DO                                        1.057583e+01 1    19.91232 0.0040
# Actual_tissue_pre_mg                                3.223048e+03 1  1039.24668 0.0000
# Phase_1_DO:Phase_1_temp                             1.593273e+00 1    13.04722 0.2290
# Phase_1_DO:Phase_2.1_temp                           2.129354e+00 1    19.95804 0.1601
# Phase_1_temp:Phase_2.1_temp                         1.044773e+00 1    19.97434 0.3189
# Phase_1_DO:Phase_2.1_DO                             1.599092e+00 1    19.96490 0.2206
# Phase_1_temp:Phase_2.1_DO                           2.338269e+00 1    20.09253 0.1418
# Phase_2.1_temp:Phase_2.1_DO                         9.365557e-01 1    19.93711 0.3448
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              7.174808e-02 1    20.00853 0.7916
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                7.902493e-01 1    19.97925 0.3846
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              6.709584e-01 1    19.96700 0.4224
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            8.705745e+00 1    20.02845 0.0079
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.662690e-02 1    19.99261 0.8987

# %%
##Shell carbon
    #using shell pre as a covariate
m1 <- lmer(mgC_shell_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+ Actual_shell_pre_mg+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res     Pr(>F)
# (Intercept)                                         5.253585e+01 1    33.33220 0.0000
# Phase_1_DO                                          3.365075e-01 1    10.57533 0.5740
# Phase_1_temp                                        6.458072e+00 1    11.91696 0.0260
# Phase_2.1_temp                                      1.156283e-06 1    19.98958 0.9992
# Phase_2.1_DO                                        8.011631e+00 1    19.97523 0.0103
# Actual_shell_pre_mg                                 7.596008e+03 1  1074.17990 0.0000
# Phase_1_DO:Phase_1_temp                             9.515288e-01 1    10.30751 0.3517
# Phase_1_DO:Phase_2.1_temp                           1.210096e+00 1    19.95013 0.2844
# Phase_1_temp:Phase_2.1_temp                         1.649227e-01 1    19.98922 0.6890
# Phase_1_DO:Phase_2.1_DO                             7.927576e-01 1    19.95758 0.3839
# Phase_1_temp:Phase_2.1_DO                           1.589333e+00 1    20.10533 0.2219
# Phase_2.1_temp:Phase_2.1_DO                         1.198112e+00 1    19.98632 0.2867
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              6.374338e-01 1    19.98489 0.4340
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                3.906197e-01 1    19.97800 0.5390
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              5.927608e-03 1    19.96576 0.9394
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.258517e+00 1    20.14997 0.2751
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.216965e-01 1    19.98319 0.7309

# %%
#diagnostics
leveneTest(mgC_shell_P2~Phase_1_treat*Phase_2_treat, Shell_Nutrients)
m1.e <- residuals(m1)
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df   F value  Pr(>F)
# group   15 1.675162 0.05006165
#       1101       NA         NA
# Plot with title “Normal Q-Q Plot”
