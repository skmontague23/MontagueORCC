# %% [markdown]
# # Phase 2 Nutrient Analysis

# %%
library(lme4) #for linear mixed effects model
library(readr) #to read in data
library(emmeans) #for post hocs
library(esquisse) #interface for building plots
library(dplyr) #for data wrangling
library(nlme) #for linear mixed effects model
library(car) #for the Levene test
library(ggplot2) #for graphs
library(plotrix) #for standard error
library(performance) #model testing
library(lmtest) #another option than levene test for variance

# %%
setwd("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC/Oyster_Nutrient_Data")
getwd()
# Out:
# [1] "/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC/Oyster_Nutrient_Data"

# %% [markdown]
# ## 0. Data Formatting

# %%
working <- read_csv("Phase2_Nutrient/Phase2_nutrient_working.csv")
preprocessing <- read_csv("NutrientPreprocessing/Oyster_Nutrient_Processing_Phase2.1.csv")
# Out:
# Rows: 384 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): Vial_num, n_notes, c_notes, n_exclude
# dbl (4): linear_corr_d15n, wt_percent_n, linear_corr_d13c, wt_percent_c
# lgl (1): c_exclude
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 384 Columns: 16
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (10): Phase_1_treat, Phase_1_treat_old, Phase_2_treat, Phase_2_treat_old, Tag_color, Tissue_type, Sample_Name_ol...
# dbl  (6): Year, Phase_1_rep, Phase_2_rep, Tag_num, Vial_num, og_order
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
colnames(working);colnames(preprocessing)
# Out:
# [1] "Vial_num"         "linear_corr_d15n" "wt_percent_n"     "n_notes"
# [5] "linear_corr_d13c" "wt_percent_c"     "c_notes"          "n_exclude"
# [9] "c_exclude"
#  [1] "Year"              "Phase_1_treat"     "Phase_1_treat_old"
#  [4] "Phase_1_rep"       "Phase_2_treat"     "Phase_2_treat_old"
#  [7] "Phase_2_rep"       "Tag_color"         "Tag_num"
# [10] "Tissue_type"       "Sample_Name_old"   "Sample_Name"
# [13] "Vial_num"          "Notes"             "og_order"
# [16] "filt_out"

# %%
#Add in treatment groups etc. by vial number
matched_data <- working %>%
  mutate(Vial_num = as.character(Vial_num)) %>%
  inner_join(
    Preprocessing %>%
      mutate(Vial_num = as.character(Vial_num)),
    by = "Vial_num")%>%
select(- c(Sample_Name_old, og_order, filt_out, Phase_1_treat_old, Phase_2_treat_old))

# %%
colnames(matched_data)
# Out:
#  [1] "Vial_num"         "linear_corr_d15n" "wt_percent_n"     "n_notes"
#  [5] "linear_corr_d13c" "wt_percent_c"     "c_notes"          "n_exclude"
#  [9] "c_exclude"        "Year"             "Phase_1_treat"    "Phase_1_rep"
# [13] "Phase_2_treat"    "Phase_2_rep"      "Tag_color"        "Tag_num"
# [17] "Tissue_type"      "Sample_Name"      "Notes"

# %%
View(matched_data)
# Out:
#     Vial_num linear_corr_d15n wt_percent_n
# 1   1        13.4              0.2
# 2   2        11.9              0.2
# 3   3         9.6              0.3
# 4   4        12.6             10.0
# 5   5        12.5             10.1
# 6   6        12.4              8.8
# 7   7        12.7              7.0
# 8   8        12.2              6.8
# 9   9        12.5              7.3
# 10  10       11.6              0.2
# 11  11       10.9              0.2
# 12  12       11.7              0.2
# 13  13       12.4              7.6
# 14  14       10.2              5.6
# 15  15       11.8              0.3
# 16  16       10.8              0.2
# 17  17       11.8              7.1
# 18  18       11.9              7.0
# 19  19       11.9              7.9
# 20  20       11.4              0.2
# 21  21        8.4              0.3
# 22  22       10.2              0.2
# 23  23       12.2              9.5
# 24  24       12.5              9.3
# 25  25        8.8              4.3
# 26  26       10.2              0.1
# 27  27       13.0              0.2
# 28  28       11.7              0.2
# 29  29       12.5              8.8
# 30  30       12.1              9.1
# ⋮   ⋮        ⋮                ⋮
# 347 350      10.8             0.2
# 348 351      10.9             0.2
# 349 352      11.9             6.2
# 350 353      12.7             8.1
# 351 354      12.8             9.0
# 352 355       4.6             0.5
# 353 356      10.5             0.2
# 354 357       6.6             0.3
# 355 358      12.3             6.8
# 356 359      12.0             7.8
# 357 360      14.4             0.2
# 358 361      11.1             0.2
# 359 362      12.4             8.5
# 360 363      11.8             5.7
# 361 364      10.9             0.2
# 362 365      12.1             0.2
# 363 366      12.0             0.2
# 364 367      12.2             8.2
# 365 368      12.5             8.5
# 366 369      12.6             8.0
# 367 370      11.3             0.3
# 368 371      10.4             0.2
# 369 372      10.0             0.2
# 370 373      12.4             8.5
# 371 374      12.2             7.5
# 372 375      12.8             7.4
# 373 376       9.4             0.2
# 374 377      10.7             0.2
# 375 378      11.7             5.7
# 376 379      13.2             7.9
#     n_notes                                   linear_corr_d13c wt_percent_c
# 1   NA                                         -9.5            17.4
# 2   NA                                         -7.4            15.9
# 3   NA                                        -10.2            18.1
# 4   NA                                        -24.0            39.3
# 5   NA                                        -23.8            41.6
# 6   NA                                        -23.6            39.2
# 7   NA                                        -25.7            49.1
# 8   NA                                        -26.2            54.9
# 9   NA                                        -26.2            52.8
# 10  NA                                         -8.6            16.8
# 11  NA                                         -7.3            15.8
# 12  NA                                         -8.8            16.9
# 13  NA                                        -25.5            48.7
# 14  small peak - error on δ15N will be higher -26.8            59.6
# 15  NA                                         -8.4            16.4
# 16  NA                                         -8.7            16.9
# 17  NA                                        -25.6            47.4
# 18  small peak - error on δ15N will be higher -26.0            49.9
# 19  NA                                        -25.9            50.6
# 20  NA                                         -9.0            17.1
# 21  NA                                         -7.0            15.5
# 22  small peak - error on δ15N will be higher  -7.7            16.2
# 23  NA                                        -24.1            41.4
# 24  NA                                        -24.4            42.1
# 25  very small peak - δ15N data unusable      -26.1            40.3
# 26  small peak - error on δ15N will be higher -10.0            17.9
# 27  NA                                         -7.9            16.1
# 28  NA                                        -11.1            18.9
# 29  NA                                        -24.2            39.9
# 30  NA                                        -25.1            45.2
# ⋮   ⋮                                         ⋮                ⋮
# 347 NA                                         -9.1            17.3
# 348 NA                                         -7.9            16.3
# 349 small peak - error on δ15N will be higher -23.5            36.6
# 350 NA                                        -25.4            49.0
# 351 NA                                        -24.2            39.7
# 352 NA                                        -11.9            20.9
# 353 NA                                         -8.6            17.2
# 354 NA                                        -10.2            19.1
# 355 small peak - error on δ15N will be higher -24.7            48.8
# 356 NA                                        -24.9            44.7
# 357 NA                                         -7.7            15.6
# 358 NA                                         -9.3            17.0
# 359 NA                                        -25.0            44.6
# 360 small peak - error on δ15N will be higher -25.7            60.8
# 361 NA                                         -8.3            16.1
# 362 NA                                         -8.4            16.2
# 363 NA                                         -7.5            15.6
# 364 NA                                        -24.2            43.7
# 365 NA                                        -24.2            44.0
# 366 NA                                        -24.3            42.1
# 367 NA                                         -8.0            15.9
# 368 NA                                         -7.4            15.4
# 369 NA                                         -8.3            16.1
# 370 NA                                        -23.9            42.8
# 371 NA                                        -24.9            51.9
# 372 NA                                        -23.9            44.6
# 373 NA                                         -9.0            16.7
# 374 NA                                         -8.3            16.3
# 375 small peak - error on δ15N will be higher -25.4            60.1
# 376 NA                                        -24.3            44.0
#     c_notes                                   n_exclude c_exclude Year
# 1   NA                                        NA        NA        2024
# 2   NA                                        NA        NA        2024
# 3   NA                                        NA        NA        2024
# 4   NA                                        NA        NA        2024
# 5   NA                                        NA        NA        2024
# 6   NA                                        NA        NA        2024
# 7   NA                                        NA        NA        2024
# 8   NA                                        NA        NA        2024
# 9   NA                                        NA        NA        2024
# 10  NA                                        NA        NA        2024
# 11  NA                                        NA        NA        2024
# 12  NA                                        NA        NA        2024
# 13  NA                                        NA        NA        2024
# 14  NA                                        NA        NA        2024
# 15  NA                                        NA        NA        2024
# 16  NA                                        NA        NA        2024
# 17  NA                                        NA        NA        2024
# 18  NA                                        NA        NA        2024
# 19  NA                                        NA        NA        2024
# 20  NA                                        NA        NA        2024
# 21  NA                                        NA        NA        2024
# 22  NA                                        NA        NA        2024
# 23  NA                                        NA        NA        2024
# 24  NA                                        NA        NA        2024
# 25  small peak - error on δ13C will be higher Y         NA        2024
# 26  NA                                        NA        NA        2024
# 27  NA                                        NA        NA        2024
# 28  NA                                        NA        NA        2024
# 29  NA                                        NA        NA        2024
# 30  NA                                        NA        NA        2024
# ⋮   ⋮                                         ⋮         ⋮         ⋮
# 347 NA                                        NA        NA        2024
# 348 NA                                        NA        NA        2024
# 349 NA                                        NA        NA        2024
# 350 NA                                        NA        NA        2024
# 351 NA                                        NA        NA        2024
# 352 NA                                        NA        NA        2024
# 353 NA                                        NA        NA        2024
# 354 NA                                        NA        NA        2024
# 355 NA                                        NA        NA        2024
# 356 NA                                        NA        NA        2024
# 357 NA                                        NA        NA        2024
# 358 NA                                        NA        NA        2024
# 359 NA                                        NA        NA        2024
# 360 NA                                        NA        NA        2024
# 361 NA                                        NA        NA        2024
# 362 NA                                        NA        NA        2024
# 363 NA                                        NA        NA        2024
# 364 NA                                        NA        NA        2024
# 365 NA                                        NA        NA        2024
# 366 NA                                        NA        NA        2024
# 367 NA                                        NA        NA        2024
# 368 NA                                        NA        NA        2024
# 369 NA                                        NA        NA        2024
# 370 NA                                        NA        NA        2024
# 371 NA                                        NA        NA        2024
# 372 NA                                        NA        NA        2024
# 373 NA                                        NA        NA        2024
# 374 NA                                        NA        NA        2024
# 375 NA                                        NA        NA        2024
# 376 NA                                        NA        NA        2024
#     Phase_1_treat Phase_1_rep Phase_2_treat Phase_2_rep Tag_color Tag_num
# 1   Warm          6           Warm          6           G         72
# 2   Hyp           5           Warm          6           B         69
# 3   Both          6           Warm          6           O         72
# 4   Warm          6           Warm          6           G         72
# 5   Hyp           5           Warm          6           B         69
# 6   Both          6           Warm          6           O         72
# 7   Both          3           Warm          6           O         66
# 8   Cont          2           Warm          6           W         63
# 9   Warm          5           Warm          6           G         69
# 10  Both          3           Warm          6           O         66
# 11  Cont          2           Warm          6           W         63
# 12  Warm          5           Warm          6           G         69
# 13  Cont          4           Warm          6           W         67
# 14  Hyp           1           Warm          6           B         61
# 15  Cont          4           Warm          6           W         67
# 16  Hyp           1           Warm          6           B         61
# 17  Both          3           Both          6           O         65
# 18  Warm          4           Both          6           G         67
# 19  Warm          3           Both          6           G         65
# 20  Warm          3           Both          6           G         65
# 21  Both          3           Both          6           O         65
# 22  Warm          4           Both          6           G         67
# 23  Cont          1           Both          6           W         62
# 24  Both          1           Both          6           O         62
# 25  Cont          5           Both          6           W         69
# 26  Both          1           Both          6           O         62
# 27  Cont          5           Both          6           W         69
# 28  Cont          1           Both          6           W         62
# 29  Cont          5           Both          3           W         34
# 30  Hyp           1           Both          3           B         25
# ⋮   ⋮             ⋮           ⋮             ⋮           ⋮         ⋮
# 347 Both          1           Cont          4           O         37
# 348 Cont          5           Cont          4           W         46
# 349 Hyp           2           Cont          4           B         40
# 350 Both          1           Cont          4           O         37
# 351 Cont          5           Cont          4           W         46
# 352 Warm          6           Cont          4           G         47
# 353 Warm          6           Cont          1           G         12
# 354 Both          3           Cont          1           O          5
# 355 Warm          6           Cont          4           G         47
# 356 Warm          6           Cont          1           G         12
# 357 Warm          3           Cont          1           G          6
# 358 Hyp           4           Cont          1           B          8
# 359 Warm          3           Cont          1           G          6
# 360 Hyp           4           Cont          1           B          8
# 361 Both          4           Hyp           6           O         67
# 362 Hyp           3           Hyp           6           B         65
# 363 Warm          1           Hyp           6           G         62
# 364 Both          4           Hyp           6           O         67
# 365 Hyp           3           Hyp           6           B         65
# 366 Warm          1           Hyp           6           G         62
# 367 Cont          4           Hyp           6           W         67
# 368 Both          3           Hyp           6           O         66
# 369 Hyp           2           Hyp           6           B         63
# 370 Cont          4           Hyp           6           W         67
# 371 Both          3           Hyp           6           O         66
# 372 Hyp           2           Hyp           6           B         63
# 373 Cont          3           Hyp           6           W         65
# 374 Warm          2           Hyp           6           G         64
# 375 Cont          3           Hyp           6           W         65
# 376 Warm          2           Hyp           6           G         64
#     Tissue_type Sample_Name              Notes
# 1   S           2024_Warm06_Warm06_G72_S May have bee tag in sample
# 2   S           2024_Hyp05_Warm06_B69_S  NA
# 3   S           2024_Both06_Warm06_O72_S NA
# 4   T           2024_Warm06_Warm06_G72_T NA
# 5   T           2024_Hyp05_Warm06_B69_T  NA
# 6   T           2024_Both06_Warm06_O72_T NA
# 7   T           2024_Both03_Warm06_O66_T NA
# 8   T           2024_Cont02_Warm06_W63_T NA
# 9   T           2024_Warm05_Warm06_G69_T NA
# 10  S           2024_Both03_Warm06_O66_S NA
# 11  S           2024_Cont02_Warm06_W63_S NA
# 12  S           2024_Warm05_Warm06_G69_S NA
# 13  T           2024_Cont04_Warm06_W67_T NA
# 14  T           2024_Hyp01_Warm06_B61_T  NA
# 15  S           2024_Cont04_Warm06_W67_S NA
# 16  S           2024_Hyp01_Warm06_B61_S  NA
# 17  T           2024_Both03_Both06_O65_T NA
# 18  T           2024_Warm04_Both06_G67_T NA
# 19  T           2024_Warm03_Both06_G65_T NA
# 20  S           2024_Warm03_Both06_G65_S NA
# 21  S           2024_Both03_Both06_O65_S NA
# 22  S           2024_Warm04_Both06_G67_S NA
# 23  T           2024_Cont01_Both06_W62_T NA
# 24  T           2024_Both01_Both06_O62_T NA
# 25  T           2024_Cont05_Both06_W69_T NA
# 26  S           2024_Both01_Both06_O62_S NA
# 27  S           2024_Cont05_Both06_W69_S NA
# 28  S           2024_Cont01_Both06_W62_S NA
# 29  T           2024_Cont05_Both03_W34_T NA
# 30  T           2024_Hyp01_Both03_B25_T  NA
# ⋮   ⋮           ⋮                        ⋮
# 347 S           2024_Both01_Cont04_O37_S NA
# 348 S           2024_Cont05_Cont04_W46_S NA
# 349 T           2024_Hyp02_Cont04_B40_T  NA
# 350 T           2024_Both01_Cont04_O37_T NA
# 351 T           2024_Cont05_Cont04_W46_T NA
# 352 S           2024_Warm06_Cont04_G47_S NA
# 353 S           2024_Warm06_Cont01_G12_S NA
# 354 S           2024_Both03_Cont01_O5_S  NA
# 355 T           2024_Warm06_Cont04_G47_T NA
# 356 T           2024_Warm06_Cont01_G12_T NA
# 357 S           2024_Warm03_Cont01_G6_S  NA
# 358 S           2024_Hyp04_Cont01_B8_S   NA
# 359 T           2024_Warm03_Cont01_G6_T  NA
# 360 T           2024_Hyp04_Cont01_B8_T   NA
# 361 S           2024_Both04_Hyp06_O67_S  NA
# 362 S           2024_Hyp03_Hyp06_B65_S   NA
# 363 S           2024_Warm01_Hyp06_G62_S  NA
# 364 T           2024_Both04_Hyp06_O67_T  NA
# 365 T           2024_Hyp03_Hyp06_B65_T   NA
# 366 T           2024_Warm01_Hyp06_G62_T  NA
# 367 S           2024_Cont04_Hyp06_W67_S  NA
# 368 S           2024_Both03_Hyp06_O66_S  NA
# 369 S           2024_Hyp02_Hyp06_B63_S   6/16/25 SC ended with this one today
# 370 T           2024_Cont04_Hyp06_W67_T  6/23/25 SC started with this one today
# 371 T           2024_Both03_Hyp06_O66_T  NA
# 372 T           2024_Hyp02_Hyp06_B63_T   NA
# 373 S           2024_Cont03_Hyp06_W65_S  NA
# 374 S           2024_Warm02_Hyp06_G64_S  NA
# 375 T           2024_Cont03_Hyp06_W65_T  NA
# 376 T           2024_Warm02_Hyp06_G64_T  6/23/25 SC ended with this one today

# %%
#write csv
#write_csv(matched_data, "Phase2_Nutrient/Phase2_nutrient_merged.csv")

# %%
#set contrasts
options(contrasts = c("contr.sum","contr.poly")) #could also be contr.treatment for unequal groups sum
getOption("contrasts")
# Out:
# [1] "contr.sum"  "contr.poly"

# %%
## READ IN MERGED DATA
df <- read_csv("Phase2_nutrient/Phase2_nutrient_merged.csv")
# Out:
# Rows: 376 Columns: 25
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (15): n_notes, c_notes, n_exclude, Phase_1_treat, Phase_1_rep_R, Phase_2...
# dbl  (9): Vial_num, linear_corr_d15n, wt_percent_n, linear_corr_d13c, wt_per...
# lgl  (1): c_exclude
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# # Tissue

# %% [markdown]
# ## 1. % Nitrogen in Tissue

# %%
colnames(df)
unique(df$Tissue_type)
# Out:
#  [1] "Vial_num"         "linear_corr_d15n" "wt_percent_n"     "n_notes"
#  [5] "linear_corr_d13c" "wt_percent_c"     "c_notes"          "n_exclude"
#  [9] "c_exclude"        "Year"             "Phase_1_treat"    "Phase_1_rep"
# [13] "Phase_1_rep_R"    "Phase_2_treat"    "Phase_2_rep"      "Phase_2_rep_R"
# [17] "Tag_color"        "Tag_num"          "Tissue_type"      "Sample_Name"
# [21] "Notes"            "Phase_1_DO"       "Phase_1_temp"     "Phase_2.1_DO"
# [25] "Phase_2.1_temp"
# [1] "S" "T"

# %%
#filter data
Tissue_Nitrogen <- df%>%
filter(Tissue_type == "T")%>%
filter(is.na(n_exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nitrogen %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue nitrogen
m1 <- lmer(wt_percent_n~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nitrogen, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         2.457860e+03 1  17.999518 0.0000
# Phase_1_DO                                          1.026739e+00 1   9.337507 0.3365
# Phase_1_temp                                        9.826509e-02 1  12.413582 0.7591
# Phase_2.1_temp                                      1.408822e+00 1  19.946699 0.2492
# Phase_2.1_DO                                        2.863404e-01 1  19.945646 0.5985
# Phase_1_DO:Phase_1_temp                             7.568086e-02 1   9.338734 0.7892
# Phase_1_DO:Phase_2.1_temp                           1.143335e-02 1  19.477158 0.9159
# Phase_1_temp:Phase_2.1_temp                         1.523059e-01 1  19.660118 0.7005
# Phase_1_DO:Phase_2.1_DO                             1.035264e+00 1  19.452760 0.3214
# Phase_1_temp:Phase_2.1_DO                           2.916674e+00 1  19.650057 0.1034
# Phase_2.1_temp:Phase_2.1_DO                         8.460369e-01 1  19.943632 0.3687
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              2.362032e+00 1  19.397778 0.1405
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.863695e+00 1  19.374321 0.1066
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              8.114037e-05 1  19.458983 0.9929
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.224969e-02 1  19.643736 0.8829
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.770860e+00 1  19.382210 0.1121

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp, adjust = "none") 

(119.3-95.5)/119.3
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_1_temp Phase_2.1_temp emmean    SE   df lower.CL upper.CL
#  Hypoxic    Ambient      Ambient          8.09 0.308 47.5     7.47     8.71
#  Normoxic   Ambient      Ambient          8.78 0.308 47.4     8.16     9.40
#  Hypoxic    Warm         Ambient          8.55 0.327 55.4     7.89     9.20
#  Normoxic   Warm         Ambient          8.24 0.309 47.7     7.62     8.86
#  Hypoxic    Ambient      Warm             8.21 0.317 51.4     7.57     8.84
#  Normoxic   Ambient      Warm             7.89 0.319 52.8     7.25     8.53
#  Hypoxic    Warm         Warm             7.84 0.319 51.8     7.20     8.48
#  Normoxic   Warm         Warm             8.31 0.323 50.6     7.66     8.96
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                           estimate    SE   df t.ratio p.value
#  Hypoxic Ambient Ambient - Normoxic Ambient Ambient  -0.6900 0.373 27.4  -1.847  0.0755
#  Hypoxic Ambient Ambient - Hypoxic Warm Ambient      -0.4597 0.389 30.8  -1.182  0.2463
#  Hypoxic Ambient Ambient - Normoxic Warm Ambient     -0.1555 0.372 27.1  -0.418  0.6794
#  Hypoxic Ambient Ambient - Hypoxic Ambient Warm      -0.1209 0.444 63.4  -0.272  0.7864
#  Hypoxic Ambient Ambient - Normoxic Ambient Warm      0.1977 0.444 50.1   0.446  0.6578
#  Hypoxic Ambient Ambient - Hypoxic Warm Warm          0.2489 0.443 49.3   0.562  0.5768
#  Hypoxic Ambient Ambient - Normoxic Warm Warm        -0.2207 0.447 49.0  -0.494  0.6234
#  Normoxic Ambient Ambient - Hypoxic Warm Ambient      0.2303 0.388 30.5   0.594  0.5567
#  Normoxic Ambient Ambient - Normoxic Warm Ambient     0.5345 0.374 27.5   1.428  0.1645
#  Normoxic Ambient Ambient - Hypoxic Ambient Warm      0.5691 0.441 48.9   1.292  0.2025
#  Normoxic Ambient Ambient - Normoxic Ambient Warm     0.8877 0.444 63.8   1.999  0.0499
#  Normoxic Ambient Ambient - Hypoxic Warm Warm         0.9389 0.444 49.8   2.113  0.0396
#  Normoxic Ambient Ambient - Normoxic Warm Warm        0.4693 0.446 49.1   1.051  0.2983
#  Hypoxic Warm Ambient - Normoxic Warm Ambient         0.3042 0.390 31.0   0.781  0.4410
#  Hypoxic Warm Ambient - Hypoxic Ambient Warm          0.3388 0.454 52.9   0.747  0.4586
#  Hypoxic Warm Ambient - Normoxic Ambient Warm         0.6574 0.457 54.2   1.438  0.1563
#  Hypoxic Warm Ambient - Hypoxic Warm Warm             0.7086 0.458 70.1   1.549  0.1259
#  Hypoxic Warm Ambient - Normoxic Warm Warm            0.2390 0.459 53.0   0.520  0.6051
#  Normoxic Warm Ambient - Hypoxic Ambient Warm         0.0345 0.446 50.5   0.077  0.9385
#  Normoxic Warm Ambient - Normoxic Ambient Warm        0.3531 0.444 50.2   0.796  0.4300
#  Normoxic Warm Ambient - Hypoxic Warm Warm            0.4044 0.443 49.3   0.912  0.3660
#  Normoxic Warm Ambient - Normoxic Warm Warm          -0.0653 0.447 61.9  -0.146  0.8844
#  Hypoxic Ambient Warm - Normoxic Ambient Warm         0.3186 0.390 31.5   0.817  0.4202
#  Hypoxic Ambient Warm - Hypoxic Warm Warm             0.3698 0.390 31.1   0.947  0.3507
#  Hypoxic Ambient Warm - Normoxic Warm Warm           -0.0998 0.390 29.6  -0.256  0.7998
#  Normoxic Ambient Warm - Hypoxic Warm Warm            0.0512 0.391 31.4   0.131  0.8964
#  Normoxic Ambient Warm - Normoxic Warm Warm          -0.4184 0.394 31.0  -1.062  0.2963
#  Hypoxic Warm Warm - Normoxic Warm Warm              -0.4696 0.392 29.8  -1.198  0.2405
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# [1] 0.1994971

# %%
#diagnostics
leveneTest(Actual_tissue_growth_mg~Phase1_Phase2_treat, Growth_Data_forR_full) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)

# %% [markdown]
#  Normoxic Ambient Ambient - Normoxic Ambient Warm p = 0.0499
#      control ambient > control warm
#  Normoxic Ambient Ambient - Hypoxic Warm Warm p = 0.0396
#      control ambient - both warm

# %% [markdown]
# ## 2. % Carbon in Tissue

# %%
#filter data
Tissue_Carbon <- df%>%
filter(Tissue_type == "T")%>%
filter(is.na(c_exclude))

# %%
#tissue carbon
summary_stats_t <- Tissue_Carbon %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_c, na.rm = TRUE),
    se_growth = std.error(wt_percent_c, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon
m2 <- lmer(wt_percent_c~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Carbon, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res
# (Intercept)                                         4.371415e+03 1  18.48525
# Phase_1_DO                                          9.679824e-01 1  10.65952
# Phase_1_temp                                        5.609544e-01 1  12.62056
# Phase_2.1_temp                                      2.208661e-01 1  19.74958
# Phase_2.1_DO                                        3.484227e-01 1  19.74704
# Phase_1_DO:Phase_1_temp                             1.309010e-02 1  10.66452
# Phase_1_DO:Phase_2.1_temp                           5.233254e-01 1  19.08024
# Phase_1_temp:Phase_2.1_temp                         3.329169e-01 1  19.24540
# Phase_1_DO:Phase_2.1_DO                             1.660700e-01 1  19.05059
# Phase_1_temp:Phase_2.1_DO                           2.527498e+00 1  19.22537
# Phase_2.1_temp:Phase_2.1_DO                         4.327672e-02 1  19.74875
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              6.112737e+00 1  19.03063
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                6.299625e-01 1  18.99837
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.469471e+00 1  19.08874
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.831882e+00 1  19.24303
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.617278e-03 1  19.04178
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.3470
# Phase_1_temp                                        0.4676
# Phase_2.1_temp                                      0.6435
# Phase_2.1_DO                                        0.5617
# Phase_1_DO:Phase_1_temp                             0.9110
# Phase_1_DO:Phase_2.1_temp                           0.4782
# Phase_1_temp:Phase_2.1_temp                         0.5706
# Phase_1_DO:Phase_2.1_DO                             0.6882
# Phase_1_temp:Phase_2.1_DO                           0.1282
# Phase_2.1_temp:Phase_2.1_DO                         0.8373
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.0230
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.4372
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.2402
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.1086
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.9683

# %%
#posthocs
options(width = 120)
emmeans(m2,specs = pairwise ~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_1_temp Phase_2.1_temp emmean   SE   df lower.CL upper.CL
#  Hyp        Ambient      Ambient          42.8 1.36 46.2     40.1     45.5
#  Norm       Ambient      Ambient          44.6 1.36 46.2     41.9     47.3
#  Hyp        Warm         Ambient          44.7 1.44 54.5     41.8     47.5
#  Norm       Warm         Ambient          42.4 1.36 46.2     39.6     45.1
#  Hyp        Ambient      Warm             46.4 1.38 48.6     43.6     49.2
#  Norm       Ambient      Warm             43.2 1.38 48.6     40.4     46.0
#  Hyp        Warm         Warm             43.4 1.38 48.6     40.6     46.2
#  Norm       Warm         Warm             43.8 1.42 49.8     41.0     46.7
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                   estimate   SE   df t.ratio p.value
#  Hyp Ambient Ambient - Norm Ambient Ambient   -1.775 1.58 26.1  -1.124  0.2712
#  Hyp Ambient Ambient - Hyp Warm Ambient       -1.847 1.73 31.2  -1.067  0.2942
#  Hyp Ambient Ambient - Norm Warm Ambient       0.446 1.66 27.7   0.268  0.7904
#  Hyp Ambient Ambient - Hyp Ambient Warm       -3.612 1.89 60.6  -1.914  0.0604
#  Hyp Ambient Ambient - Norm Ambient Warm      -0.378 1.94 47.4  -0.195  0.8459
#  Hyp Ambient Ambient - Hyp Warm Warm          -0.584 1.94 47.4  -0.302  0.7642
#  Hyp Ambient Ambient - Norm Warm Warm         -1.034 1.96 48.0  -0.527  0.6008
#  Norm Ambient Ambient - Hyp Warm Ambient      -0.072 1.73 31.3  -0.042  0.9671
#  Norm Ambient Ambient - Norm Warm Ambient      2.221 1.66 27.6   1.337  0.1921
#  Norm Ambient Ambient - Hyp Ambient Warm      -1.837 1.93 47.4  -0.949  0.3474
#  Norm Ambient Ambient - Norm Ambient Warm      1.397 1.89 60.6   0.740  0.4622
#  Norm Ambient Ambient - Hyp Warm Warm          1.191 1.94 47.4   0.615  0.5412
#  Norm Ambient Ambient - Norm Warm Warm         0.741 1.96 48.0   0.377  0.7075
#  Hyp Warm Ambient - Norm Warm Ambient          2.293 1.65 29.8   1.388  0.1756
#  Hyp Warm Ambient - Hyp Ambient Warm          -1.765 2.00 51.6  -0.884  0.3806
#  Hyp Warm Ambient - Norm Ambient Warm          1.469 2.00 51.6   0.736  0.4651
#  Hyp Warm Ambient - Hyp Warm Warm              1.263 1.95 66.9   0.648  0.5194
#  Hyp Warm Ambient - Norm Warm Warm             0.813 2.02 52.1   0.402  0.6894
#  Norm Warm Ambient - Hyp Ambient Warm         -4.057 1.93 47.4  -2.097  0.0414
#  Norm Warm Ambient - Norm Ambient Warm        -0.824 1.94 47.4  -0.426  0.6721
#  Norm Warm Ambient - Hyp Warm Warm            -1.030 1.94 47.4  -0.532  0.5972
#  Norm Warm Ambient - Norm Warm Warm           -1.480 1.92 60.7  -0.772  0.4429
#  Hyp Ambient Warm - Norm Ambient Warm          3.233 1.62 28.2   1.996  0.0556
#  Hyp Ambient Warm - Hyp Warm Warm              3.028 1.70 29.2   1.784  0.0848
#  Hyp Ambient Warm - Norm Warm Warm             2.577 1.73 29.5   1.494  0.1458
#  Norm Ambient Warm - Hyp Warm Warm            -0.206 1.70 29.8  -0.121  0.9046
#  Norm Ambient Warm - Norm Warm Warm           -0.656 1.73 30.4  -0.379  0.7076
#  Hyp Warm Warm - Norm Warm Warm               -0.450 1.64 27.9  -0.274  0.7860
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger

# %%
#Normoxic Warm Ambient - Hypoxic Ambient Warm p = 0.0414
    #warm ambient(42.4) - hypoxic warm (46.4)

# %% [markdown]
# ## 3. Carbon:Nitrogen in Tissue

# %%
#filter data
Tissue_CN <- df%>%
filter(Tissue_type == "T")%>%
filter(is.na(n_exclude))%>%
filter(is.na(c_exclude))

# %%
#tissue c:n
summary_stats_t <- Tissue_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean((wt_percent_c/wt_percent_n), na.rm = TRUE),
    se_growth = std.error((wt_percent_c/wt_percent_n), na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon:nitrogen
m3 <- lmer((wt_percent_c/wt_percent_n)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_CN, REML=TRUE)
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         8.644026e+02 1  17.749050 0.0000
# Phase_1_DO                                          1.031452e+00 1   9.302079 0.3355
# Phase_1_temp                                        1.168882e+00 1  13.053238 0.2992
# Phase_2.1_temp                                      5.702890e-01 1  19.936224 0.4590
# Phase_2.1_DO                                        1.404593e-01 1  19.934988 0.7118
# Phase_1_DO:Phase_1_temp                             6.135026e-03 1   9.303212 0.9392
# Phase_1_DO:Phase_2.1_temp                           1.768789e-02 1  19.465892 0.8956
# Phase_1_temp:Phase_2.1_temp                         2.097541e-01 1  19.699710 0.6520
# Phase_1_DO:Phase_2.1_DO                             1.512956e+00 1  19.441419 0.2334
# Phase_1_temp:Phase_2.1_DO                           2.895257e+00 1  19.691365 0.1046
# Phase_2.1_temp:Phase_2.1_DO                         6.185760e-02 1  19.932689 0.8061
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.168898e-01 1  19.399029 0.7361
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.873021e+00 1  19.375279 0.1061
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              2.876406e-01 1  19.448055 0.5978
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.558644e-01 1  19.685190 0.6186
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.131498e+00 1  19.383400 0.3005

# %% [markdown]
# # Shell

# %% [markdown]
# ## 1. % Nitrogen in Shell

# %%
#filter data
Shell_Nitrogen <- df%>%
filter(Tissue_type == "S")%>%
filter(is.na(n_exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_Nitrogen %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  ylim(0.15, 0.30)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell nitrogen
m1 <- lmer(wt_percent_n~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nitrogen, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         2.043063e+03 1  12.36742 0.0000
# Phase_1_DO                                          1.397427e-02 1  10.85770 0.9081
# Phase_1_temp                                        1.499748e-02 1  10.15219 0.9049
# Phase_2.1_temp                                      3.464505e+00 1  19.85048 0.0776
# Phase_2.1_DO                                        9.711794e-01 1  19.85048 0.3362
# Phase_1_DO:Phase_1_temp                             1.215836e+00 1  10.15220 0.2956
# Phase_1_DO:Phase_2.1_temp                           2.366202e+00 1  19.79724 0.1398
# Phase_1_temp:Phase_2.1_temp                         1.217189e+00 1  19.76710 0.2832
# Phase_1_DO:Phase_2.1_DO                             3.501232e-01 1  19.79724 0.5607
# Phase_1_temp:Phase_2.1_DO                           1.217449e+00 1  19.76710 0.2831
# Phase_2.1_temp:Phase_2.1_DO                         2.026221e+00 1  19.85048 0.1701
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              3.381658e+00 1  19.76709 0.0810
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                7.363015e-01 1  19.76709 0.4011
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.134302e+00 1  19.79724 0.2997
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.217449e+00 1  19.76710 0.2831
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.504309e-02 1  19.76709 0.9036

# %% [markdown]
# ## 2. % Carbon in Shell

# %%
#filter data
Shell_Carbon <- df%>%
filter(Tissue_type == "S")%>%
filter(is.na(c_exclude))

# %%
#tissue carbon
summary_stats_t <- Shell_Carbon %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_c, na.rm = TRUE),
    se_growth = std.error(wt_percent_c, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
ylim(15,18)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##Shell carbon
m2 <- lmer(wt_percent_c~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Carbon, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         2.272049e+04 1  18.78179 0.0000
# Phase_1_DO                                          1.302377e-01 1  13.00526 0.7240
# Phase_1_temp                                        1.896658e+00 1  13.00274 0.1917
# Phase_2.1_temp                                      5.720248e-02 1  19.32695 0.8135
# Phase_2.1_DO                                        3.432965e-03 1  19.32695 0.9539
# Phase_1_DO:Phase_1_temp                             9.004444e-02 1  13.00513 0.7689
# Phase_1_DO:Phase_2.1_temp                           4.684673e-01 1  18.69820 0.5021
# Phase_1_temp:Phase_2.1_temp                         4.479149e-01 1  18.70035 0.5115
# Phase_1_DO:Phase_2.1_DO                             1.368940e+00 1  18.69820 0.2567
# Phase_1_temp:Phase_2.1_DO                           5.073884e-05 1  18.70035 0.9944
# Phase_2.1_temp:Phase_2.1_DO                         1.584004e+00 1  19.32695 0.2232
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              2.229833e+00 1  18.69815 0.1521
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                6.642651e-02 1  18.69815 0.7994
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              5.212313e-02 1  18.69820 0.8219
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.201167e+00 1  18.70035 0.2870
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 5.073884e-05 1  18.69815 0.9944

# %% [markdown]
# ## 3. Carbon:Nitrogen in Shell

# %%
#filter data
Shell_CN <- df%>%
filter(Tissue_type == "S")%>%
filter(is.na(n_exclude))%>%
filter(is.na(c_exclude))

# %%
#tissue c:n
summary_stats_t <- Shell_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean((wt_percent_c/wt_percent_n), na.rm = TRUE),
    se_growth = std.error((wt_percent_c/wt_percent_n), na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell carbon:nitrogen
m3 <- lmer((wt_percent_c/wt_percent_n)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_CN, REML=TRUE)
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         1.574742e+03 1  14.68914 0.0000
# Phase_1_DO                                          3.676224e-01 1  10.52370 0.5572
# Phase_1_temp                                        1.231866e+00 1  10.52333 0.2918
# Phase_2.1_temp                                      3.421284e+00 1  19.77954 0.0794
# Phase_2.1_DO                                        2.086412e-01 1  19.77954 0.6528
# Phase_1_DO:Phase_1_temp                             5.242249e-02 1  10.52370 0.8233
# Phase_1_DO:Phase_2.1_temp                           1.886709e+00 1  19.58366 0.1851
# Phase_1_temp:Phase_2.1_temp                         2.618342e+00 1  19.58384 0.1216
# Phase_1_DO:Phase_2.1_DO                             6.598977e-01 1  19.58366 0.4264
# Phase_1_temp:Phase_2.1_DO                           3.896123e-01 1  19.58384 0.5397
# Phase_2.1_temp:Phase_2.1_DO                         2.802683e-02 1  19.77954 0.8687
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.246871e+00 1  19.58366 0.2777
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.114544e+00 1  19.58366 0.3039
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              5.868425e-01 1  19.58366 0.4528
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.335318e-03 1  19.58384 0.9619
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.633981e-01 1  19.58366 0.6135
