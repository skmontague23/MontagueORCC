# %% [markdown]
# # Phase 2 Nutrient Analysis (in Tissue)

# %%
library(lme4) #for linear mixed effects model
library(readr) #to read in data
library(emmeans) #for post hocs
library(esquisse) #interface for building plots
library(dplyr) #for data wrangling
library(nlme) #for linear mixed effects model
library(car) #for the Levene test
library(ggplot2) #for graphs
library(plotrix) #for standard error
library(performance) #model testing
library(lmtest) #another option than levene test for variance

# %%
setwd("/Users/sophiemontague/Desktop/")

# %%
data <- read_csv("Phase2_nutrient_merged copy.csv")
# Out:
# Rows: 182 Columns: 31
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (17): Vial_num, n_notes, Phase_1_treat, Phase_1_treat_old, Phase_1_rep_R...
# dbl  (9): linear_corr_d15n, wt_percent_n, linear_corr_d13c, wt_percent_c, Ye...
# lgl  (5): c_notes, n_exclude, c_exclude, Tissue_type, filt_out_preprocessing
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
colnames(data)
# Out:
#  [1] "Vial_num"               "linear_corr_d15n"       "wt_percent_n"
#  [4] "n_notes"                "linear_corr_d13c"       "wt_percent_c"
#  [7] "c_notes"                "n_exclude"              "c_exclude"
# [10] "Year"                   "Phase_1_treat"          "Phase_1_treat_old"
# [13] "Phase_1_rep"            "Phase_1_rep_R"          "Phase_2_treat"
# [16] "Phase_2_treat_old"      "Phase_2_rep"            "Phase_2_rep_R"
# [19] "Tag_color"              "Tag_num"                "Tissue_type"
# [22] "Sample_Name_old"        "Sample_Name"            "Notes"
# [25] "og_order"               "filt_out_preprocessing" "treats_1and2"
# [28] "Phase_1_temp"           "Phase_2.1_temp"         "Phase_1_DO"
# [31] "Phase_2.1_DO"

# %%
#set contrasts
options(contrasts = c("contr.sum","contr.poly")) #could also be contr.treatment for unequal groups sum
getOption("contrasts")
# Out:
# [1] "contr.sum"  "contr.poly"

# %% [markdown]
# ## 1. % Nitrogen in Tissue

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- data %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue nitrogen
m1 <- lmer(wt_percent_n~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = data, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         2.460607e+03 1  17.995337 0.0000
# Phase_1_DO                                          1.002611e+00 1   9.336845 0.3419
# Phase_1_temp                                        1.009569e-01 1  12.424869 0.7560
# Phase_2.1_temp                                      1.402046e+00 1  19.946527 0.2503
# Phase_2.1_DO                                        2.789255e-01 1  19.945471 0.6032
# Phase_1_DO:Phase_1_temp                             8.286588e-02 1   9.338071 0.7797
# Phase_1_DO:Phase_2.1_temp                           1.415350e-02 1  19.476957 0.9065
# Phase_1_temp:Phase_2.1_temp                         1.556939e-01 1  19.660839 0.6974
# Phase_1_DO:Phase_2.1_DO                             1.046116e+00 1  19.452557 0.3190
# Phase_1_temp:Phase_2.1_DO                           2.877669e+00 1  19.650810 0.1056
# Phase_2.1_temp:Phase_2.1_DO                         8.601115e-01 1  19.943452 0.3648
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              2.322334e+00 1  19.397794 0.1437
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.842682e+00 1  19.374332 0.1078
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              2.031440e-04 1  19.458788 0.9888
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.536262e-02 1  19.644491 0.8751
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.790661e+00 1  19.382225 0.1109

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp, adjust = "none") 

(119.3-95.5)/119.3
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_1_temp Phase_2.1_temp emmean    SE   df lower.CL upper.CL
#  Hypoxic    Ambient      Ambient          8.09 0.308 47.5     7.47     8.71
#  Normoxic   Ambient      Ambient          8.78 0.308 47.4     8.16     9.40
#  Hypoxic    Warm         Ambient          8.55 0.327 55.4     7.89     9.20
#  Normoxic   Warm         Ambient          8.24 0.309 47.7     7.62     8.86
#  Hypoxic    Ambient      Warm             8.21 0.317 51.4     7.57     8.84
#  Normoxic   Ambient      Warm             7.89 0.319 52.8     7.25     8.53
#  Hypoxic    Warm         Warm             7.84 0.319 51.8     7.20     8.48
#  Normoxic   Warm         Warm             8.31 0.323 50.6     7.66     8.96
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                           estimate    SE   df t.ratio p.value
#  Hypoxic Ambient Ambient - Normoxic Ambient Ambient  -0.6900 0.373 27.4  -1.847  0.0755
#  Hypoxic Ambient Ambient - Hypoxic Warm Ambient      -0.4597 0.389 30.8  -1.182  0.2463
#  Hypoxic Ambient Ambient - Normoxic Warm Ambient     -0.1555 0.372 27.1  -0.418  0.6794
#  Hypoxic Ambient Ambient - Hypoxic Ambient Warm      -0.1209 0.444 63.4  -0.272  0.7864
#  Hypoxic Ambient Ambient - Normoxic Ambient Warm      0.1977 0.444 50.1   0.446  0.6578
#  Hypoxic Ambient Ambient - Hypoxic Warm Warm          0.2489 0.443 49.3   0.562  0.5768
#  Hypoxic Ambient Ambient - Normoxic Warm Warm        -0.2207 0.447 49.0  -0.494  0.6234
#  Normoxic Ambient Ambient - Hypoxic Warm Ambient      0.2303 0.388 30.5   0.594  0.5567
#  Normoxic Ambient Ambient - Normoxic Warm Ambient     0.5345 0.374 27.5   1.428  0.1645
#  Normoxic Ambient Ambient - Hypoxic Ambient Warm      0.5691 0.441 48.9   1.292  0.2025
#  Normoxic Ambient Ambient - Normoxic Ambient Warm     0.8877 0.444 63.8   1.999  0.0499
#  Normoxic Ambient Ambient - Hypoxic Warm Warm         0.9389 0.444 49.8   2.113  0.0396
#  Normoxic Ambient Ambient - Normoxic Warm Warm        0.4693 0.446 49.1   1.051  0.2983
#  Hypoxic Warm Ambient - Normoxic Warm Ambient         0.3042 0.390 31.0   0.781  0.4410
#  Hypoxic Warm Ambient - Hypoxic Ambient Warm          0.3388 0.454 52.9   0.747  0.4586
#  Hypoxic Warm Ambient - Normoxic Ambient Warm         0.6574 0.457 54.2   1.438  0.1563
#  Hypoxic Warm Ambient - Hypoxic Warm Warm             0.7086 0.458 70.1   1.549  0.1259
#  Hypoxic Warm Ambient - Normoxic Warm Warm            0.2390 0.459 53.0   0.520  0.6051
#  Normoxic Warm Ambient - Hypoxic Ambient Warm         0.0345 0.446 50.5   0.077  0.9385
#  Normoxic Warm Ambient - Normoxic Ambient Warm        0.3531 0.444 50.2   0.796  0.4300
#  Normoxic Warm Ambient - Hypoxic Warm Warm            0.4044 0.443 49.3   0.912  0.3660
#  Normoxic Warm Ambient - Normoxic Warm Warm          -0.0653 0.447 61.9  -0.146  0.8844
#  Hypoxic Ambient Warm - Normoxic Ambient Warm         0.3186 0.390 31.5   0.817  0.4202
#  Hypoxic Ambient Warm - Hypoxic Warm Warm             0.3698 0.390 31.1   0.947  0.3507
#  Hypoxic Ambient Warm - Normoxic Warm Warm           -0.0998 0.390 29.6  -0.256  0.7998
#  Normoxic Ambient Warm - Hypoxic Warm Warm            0.0512 0.391 31.4   0.131  0.8964
#  Normoxic Ambient Warm - Normoxic Warm Warm          -0.4184 0.394 31.0  -1.062  0.2963
#  Hypoxic Warm Warm - Normoxic Warm Warm              -0.4696 0.392 29.8  -1.198  0.2405
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# [1] 0.1994971

# %%
#diagnostics
leveneTest(Actual_tissue_growth_mg~Phase1_Phase2_treat, Growth_Data_forR_full) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)

# %% [markdown]
#  Normoxic Ambient Ambient - Normoxic Ambient Warm p = 0.0499
#      control ambient > control warm
#  Normoxic Ambient Ambient - Hypoxic Warm Warm p = 0.0396
#      control ambient - both warm

# %% [markdown]
# ## 2. % Carbon in Tissue

# %%
#tissue carbon
summary_stats_t <- data %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_c, na.rm = TRUE),
    se_growth = std.error(wt_percent_c, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon
m2 <- lmer(wt_percent_c~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = data, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         4.549976e+03 1  18.49973 0.0000
# Phase_1_DO                                          5.298016e-01 1  11.00513 0.4819
# Phase_1_temp                                        1.051704e+00 1  11.08988 0.3270
# Phase_2.1_temp                                      1.463683e-01 1  19.72952 0.7061
# Phase_2.1_DO                                        2.467386e-01 1  19.71865 0.6249
# Phase_1_DO:Phase_1_temp                             2.291650e-03 1  11.00408 0.9627
# Phase_1_DO:Phase_2.1_temp                           2.005662e-01 1  19.08209 0.6593
# Phase_1_temp:Phase_2.1_temp                         7.640881e-01 1  19.03447 0.3929
# Phase_1_DO:Phase_2.1_DO                             4.137640e-01 1  19.02830 0.5277
# Phase_1_temp:Phase_2.1_DO                           2.191891e+00 1  18.98038 0.1551
# Phase_2.1_temp:Phase_2.1_DO                         1.179495e-02 1  19.71607 0.9146
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              7.039527e+00 1  18.98721 0.0157
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                4.086445e-01 1  18.93508 0.5303
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              9.678738e-01 1  19.05339 0.3375
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.526608e+00 1  18.99981 0.1284
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.164699e-02 1  18.96105 0.9152

# %%
#posthocs
options(width = 120)
emmeans(m2,specs = pairwise ~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_1_temp Phase_2.1_temp emmean   SE   df lower.CL upper.CL
#  Hypoxic    Ambient      Ambient          42.8 1.31 44.3     40.2     45.5
#  Normoxic   Ambient      Ambient          44.6 1.31 44.3     41.9     47.2
#  Hypoxic    Warm         Ambient          44.7 1.40 52.5     41.9     47.5
#  Normoxic   Warm         Ambient          42.4 1.31 44.3     39.7     45.0
#  Hypoxic    Ambient      Warm             46.4 1.34 46.7     43.7     49.1
#  Normoxic   Ambient      Warm             43.3 1.37 49.8     40.6     46.1
#  Hypoxic    Warm         Warm             42.7 1.36 48.5     40.0     45.5
#  Normoxic   Warm         Warm             43.9 1.37 47.8     41.1     46.6
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                           estimate   SE   df t.ratio p.value
#  Hypoxic Ambient Ambient - Normoxic Ambient Ambient  -1.7750 1.58 25.9  -1.127  0.2701
#  Hypoxic Ambient Ambient - Hypoxic Warm Ambient      -1.8571 1.65 29.5  -1.126  0.2694
#  Hypoxic Ambient Ambient - Normoxic Warm Ambient      0.4458 1.58 26.0   0.283  0.7798
#  Hypoxic Ambient Ambient - Hypoxic Ambient Warm      -3.6007 1.82 59.1  -1.977  0.0527
#  Hypoxic Ambient Ambient - Normoxic Ambient Warm     -0.5155 1.90 47.1  -0.272  0.7868
#  Hypoxic Ambient Ambient - Hypoxic Warm Warm          0.0774 1.89 46.4   0.041  0.9676
#  Hypoxic Ambient Ambient - Normoxic Warm Warm        -1.0772 1.90 46.1  -0.566  0.5739
#  Normoxic Ambient Ambient - Hypoxic Warm Ambient     -0.0821 1.65 29.6  -0.050  0.9606
#  Normoxic Ambient Ambient - Normoxic Warm Ambient     2.2208 1.58 25.9   1.407  0.1712
#  Normoxic Ambient Ambient - Hypoxic Ambient Warm     -1.8257 1.88 45.5  -0.973  0.3356
#  Normoxic Ambient Ambient - Normoxic Ambient Warm     1.2595 1.84 61.0   0.684  0.4966
#  Normoxic Ambient Ambient - Hypoxic Warm Warm         1.8524 1.89 46.4   0.978  0.3331
#  Normoxic Ambient Ambient - Normoxic Warm Warm        0.6978 1.90 46.1   0.367  0.7154
#  Hypoxic Warm Ambient - Normoxic Warm Ambient         2.3030 1.65 29.5   1.398  0.1725
#  Hypoxic Warm Ambient - Hypoxic Ambient Warm         -1.7436 1.94 49.6  -0.900  0.3724
#  Hypoxic Warm Ambient - Normoxic Ambient Warm         1.3416 1.96 51.2   0.686  0.4958
#  Hypoxic Warm Ambient - Hypoxic Warm Warm             1.9345 1.90 67.2   1.016  0.3131
#  Hypoxic Warm Ambient - Normoxic Warm Warm            0.7799 1.96 50.2   0.397  0.6927
#  Normoxic Warm Ambient - Hypoxic Ambient Warm        -4.0466 1.88 45.5  -2.157  0.0363
#  Normoxic Warm Ambient - Normoxic Ambient Warm       -0.9613 1.90 47.1  -0.507  0.6144
#  Normoxic Warm Ambient - Hypoxic Warm Warm           -0.3685 1.89 46.4  -0.195  0.8466
#  Normoxic Warm Ambient - Normoxic Warm Warm          -1.5230 1.85 59.2  -0.824  0.4133
#  Hypoxic Ambient Warm - Normoxic Ambient Warm         3.0852 1.64 29.3   1.885  0.0694
#  Hypoxic Ambient Warm - Hypoxic Warm Warm             3.6781 1.63 28.3   2.250  0.0324
#  Hypoxic Ambient Warm - Normoxic Warm Warm            2.5235 1.64 27.8   1.539  0.1351
#  Normoxic Ambient Warm - Hypoxic Warm Warm            0.5929 1.66 30.4   0.357  0.7237
#  Normoxic Ambient Warm - Normoxic Warm Warm          -0.5617 1.67 29.9  -0.336  0.7389
#  Hypoxic Warm Warm - Normoxic Warm Warm              -1.1546 1.66 28.5  -0.697  0.4916
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger

# %%
Normoxic Warm Ambient - Hypoxic Ambient Warm p = 0.0363
    warm ambient - hypoxic warm
Hypoxic Ambient Warm - Hypoxic Warm Warm  p = 0.0324
    hypoxic warm - both warm


hypoxic warm (46.4) - warm ambient(42.4)
hypoxic warm (46.4) - both warm (42.7)

# %%
##tissue carbon:nitrogen
m3 <- lmer((wt_percent_c/wt_percent_n)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = data, REML=TRUE)
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         8.666516e+02 1  17.735921 0.0000
# Phase_1_DO                                          1.013657e+00 1   9.302263 0.3395
# Phase_1_temp                                        1.148475e+00 1  13.065792 0.3033
# Phase_2.1_temp                                      5.800358e-01 1  19.935713 0.4552
# Phase_2.1_DO                                        1.371026e-01 1  19.934467 0.7151
# Phase_1_DO:Phase_1_temp                             4.910305e-03 1   9.303388 0.9456
# Phase_1_DO:Phase_2.1_temp                           1.546589e-02 1  19.465746 0.9023
# Phase_1_temp:Phase_2.1_temp                         2.020645e-01 1  19.700538 0.6580
# Phase_1_DO:Phase_2.1_DO                             1.487744e+00 1  19.441279 0.2372
# Phase_1_temp:Phase_2.1_DO                           2.864387e+00 1  19.692224 0.1063
# Phase_2.1_temp:Phase_2.1_DO                         6.437854e-02 1  19.932156 0.8023
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.226588e-01 1  19.399283 0.7299
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.902899e+00 1  19.375534 0.1044
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              2.980929e-01 1  19.447916 0.5913
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.484321e-01 1  19.686059 0.6237
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.109169e+00 1  19.383647 0.3052
