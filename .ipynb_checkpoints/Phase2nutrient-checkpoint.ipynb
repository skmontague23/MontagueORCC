# %% [markdown]
# # Phase 2 Nutrient Analysis

# %%
library(lme4) #for linear mixed effects model
library(readr) #to read in data
library(emmeans) #for post hocs
library(esquisse) #interface for building plots
library(dplyr) #for data wrangling
library(nlme) #for linear mixed effects model
library(car) #for the Levene test
library(ggplot2) #for graphs
library(plotrix) #for standard error
library(performance) #model testing
library(lmtest) #another option than levene test for variance

# %%
setwd("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC/Oyster_Nutrient_Data")
getwd()
# Out:
# [1] "/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC/Oyster_Nutrient_Data"

# %% [markdown]
# ## 0. Data Formatting

# %%
working <- read_csv("Phase2_Nutrient/Phase2_nutrient_working.csv")
preprocessing <- read_csv("NutrientPreprocessing/Oyster_Nutrient_Processing_Phase2.1.csv")
# Out:
# Rows: 384 Columns: 9
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): Vial_num, n_notes, c_notes, n_exclude
# dbl (4): linear_corr_d15n, wt_percent_n, linear_corr_d13c, wt_percent_c
# lgl (1): c_exclude
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Rows: 384 Columns: 16
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (10): Phase_1_treat, Phase_1_treat_old, Phase_2_treat, Phase_2_treat_old, Tag_color, Tissue_type, Sample_Name_ol...
# dbl  (6): Year, Phase_1_rep, Phase_2_rep, Tag_num, Vial_num, og_order
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
colnames(working);colnames(preprocessing)
# Out:
# [1] "Vial_num"         "linear_corr_d15n" "wt_percent_n"     "n_notes"          "linear_corr_d13c" "wt_percent_c"
# [7] "c_notes"          "n_exclude"        "c_exclude"
#  [1] "Year"              "Phase_1_treat"     "Phase_1_treat_old" "Phase_1_rep"       "Phase_2_treat"
#  [6] "Phase_2_treat_old" "Phase_2_rep"       "Tag_color"         "Tag_num"           "Tissue_type"
# [11] "Sample_Name_old"   "Sample_Name"       "Vial_num"          "Notes"             "og_order"
# [16] "filt_out"

# %%
#Add in treatment groups etc. by vial number
matched_data <- working %>%
  mutate(Vial_num = as.character(Vial_num)) %>%
  inner_join(
    Preprocessing %>%
      mutate(Vial_num = as.character(Vial_num)),
    by = "Vial_num")%>%
select(- c(Sample_Name_old, og_order, filt_out, Phase_1_treat_old, Phase_2_treat_old))

# %%
colnames(matched_data)
# Out:
#  [1] "Vial_num"         "linear_corr_d15n" "wt_percent_n"     "n_notes"          "linear_corr_d13c" "wt_percent_c"
#  [7] "c_notes"          "n_exclude"        "c_exclude"        "Year"             "Phase_1_treat"    "Phase_1_rep"
# [13] "Phase_2_treat"    "Phase_2_rep"      "Tag_color"        "Tag_num"          "Tissue_type"      "Sample_Name"
# [19] "Notes"

# %%
View(matched_data)
# Out:
#     Vial_num linear_corr_d15n wt_percent_n n_notes                                   linear_corr_d13c wt_percent_c
# 1   1        13.4              0.2         NA                                         -9.5            17.4
# 2   2        11.9              0.2         NA                                         -7.4            15.9
# 3   3         9.6              0.3         NA                                        -10.2            18.1
# 4   4        12.6             10.0         NA                                        -24.0            39.3
# 5   5        12.5             10.1         NA                                        -23.8            41.6
# 6   6        12.4              8.8         NA                                        -23.6            39.2
# 373 376       9.4             0.2          NA                                         -9.0            16.7
# 374 377      10.7             0.2          NA                                         -8.3            16.3
# 375 378      11.7             5.7          small peak - error on δ15N will be higher -25.4            60.1
# 376 379      13.2             7.9          NA                                        -24.3            44.0
#     c_notes                                   n_exclude c_exclude Year Phase_1_treat Phase_1_rep Phase_2_treat
# 1   NA                                        NA        NA        2024 Warm          6           Warm
# 2   NA                                        NA        NA        2024 Hyp           5           Warm
# 3   NA                                        NA        NA        2024 Both          6           Warm
# 4   NA                                        NA        NA        2024 Warm          6           Warm
# 5   NA                                        NA        NA        2024 Hyp           5           Warm
# 6   NA                                        NA        NA        2024 Both          6           Warm
# 7   NA                                        NA        NA        2024 Both          3           Warm
# 8   NA                                        NA        NA        2024 Cont          2           Warm
# 9   NA                                        NA        NA        2024 Warm          5           Warm
# 10  NA                                        NA        NA        2024 Both          3           Warm
# 11  NA                                        NA        NA        2024 Cont          2           Warm
# 12  NA                                        NA        NA        2024 Warm          5           Warm
# 13  NA                                        NA        NA        2024 Cont          4           Warm
# 14  NA                                        NA        NA        2024 Hyp           1           Warm
# 15  NA                                        NA        NA        2024 Cont          4           Warm
# 16  NA                                        NA        NA        2024 Hyp           1           Warm
# 17  NA                                        NA        NA        2024 Both          3           Both
# 18  NA                                        NA        NA        2024 Warm          4           Both
# 19  NA                                        NA        NA        2024 Warm          3           Both
# 20  NA                                        NA        NA        2024 Warm          3           Both
# 21  NA                                        NA        NA        2024 Both          3           Both
# 22  NA                                        NA        NA        2024 Warm          4           Both
# 23  NA                                        NA        NA        2024 Cont          1           Both
# 24  NA                                        NA        NA        2024 Both          1           Both
# 25  small peak - error on δ13C will be higher Y         NA        2024 Cont          5           Both
# 26  NA                                        NA        NA        2024 Both          1           Both
# 27  NA                                        NA        NA        2024 Cont          5           Both
# 28  NA                                        NA        NA        2024 Cont          1           Both
# 29  NA                                        NA        NA        2024 Cont          5           Both
# 30  NA                                        NA        NA        2024 Hyp           1           Both
# ⋮   ⋮                                         ⋮         ⋮         ⋮    ⋮             ⋮           ⋮
# 347 NA                                        NA        NA        2024 Both          1           Cont
# 348 NA                                        NA        NA        2024 Cont          5           Cont
# 349 NA                                        NA        NA        2024 Hyp           2           Cont
# 350 NA                                        NA        NA        2024 Both          1           Cont
# 351 NA                                        NA        NA        2024 Cont          5           Cont
# 352 NA                                        NA        NA        2024 Warm          6           Cont
# 353 NA                                        NA        NA        2024 Warm          6           Cont
# 354 NA                                        NA        NA        2024 Both          3           Cont
# 355 NA                                        NA        NA        2024 Warm          6           Cont
# 356 NA                                        NA        NA        2024 Warm          6           Cont
# 357 NA                                        NA        NA        2024 Warm          3           Cont
# 358 NA                                        NA        NA        2024 Hyp           4           Cont
# 359 NA                                        NA        NA        2024 Warm          3           Cont
# 360 NA                                        NA        NA        2024 Hyp           4           Cont
# 361 NA                                        NA        NA        2024 Both          4           Hyp
# 362 NA                                        NA        NA        2024 Hyp           3           Hyp
# 363 NA                                        NA        NA        2024 Warm          1           Hyp
# 351 4           W         46      T           2024_Cont05_Cont04_W46_T NA
# 352 4           G         47      S           2024_Warm06_Cont04_G47_S NA
# 353 1           G         12      S           2024_Warm06_Cont01_G12_S NA
# 354 1           O          5      S           2024_Both03_Cont01_O5_S  NA
# 355 4           G         47      T           2024_Warm06_Cont04_G47_T NA
# 356 1           G         12      T           2024_Warm06_Cont01_G12_T NA
# 357 1           G          6      S           2024_Warm03_Cont01_G6_S  NA
# 358 1           B          8      S           2024_Hyp04_Cont01_B8_S   NA
# 359 1           G          6      T           2024_Warm03_Cont01_G6_T  NA
# 360 1           B          8      T           2024_Hyp04_Cont01_B8_T   NA
# 361 6           O         67      S           2024_Both04_Hyp06_O67_S  NA
# 362 6           B         65      S           2024_Hyp03_Hyp06_B65_S   NA
# 363 6           G         62      S           2024_Warm01_Hyp06_G62_S  NA
# 364 6           O         67      T           2024_Both04_Hyp06_O67_T  NA
# 365 6           B         65      T           2024_Hyp03_Hyp06_B65_T   NA
# 366 6           G         62      T           2024_Warm01_Hyp06_G62_T  NA
# 367 6           W         67      S           2024_Cont04_Hyp06_W67_S  NA
# 368 6           O         66      S           2024_Both03_Hyp06_O66_S  NA
# 369 6           B         63      S           2024_Hyp02_Hyp06_B63_S   6/16/25 SC ended with this one today
# 370 6           W         67      T           2024_Cont04_Hyp06_W67_T  6/23/25 SC started with this one today
# 371 6           O         66      T           2024_Both03_Hyp06_O66_T  NA
# 372 6           B         63      T           2024_Hyp02_Hyp06_B63_T   NA
# 373 6           W         65      S           2024_Cont03_Hyp06_W65_S  NA
# 374 6           G         64      S           2024_Warm02_Hyp06_G64_S  NA
# 375 6           W         65      T           2024_Cont03_Hyp06_W65_T  NA
# 376 6           G         64      T           2024_Warm02_Hyp06_G64_T  6/23/25 SC ended with this one today

# %%
#write csv
#write_csv(matched_data, "Phase2_Nutrient/Phase2_nutrient_merged.csv")

# %%
#set contrasts
options(contrasts = c("contr.sum","contr.poly")) #could also be contr.treatment for unequal groups sum
getOption("contrasts")
# Out:
# [1] "contr.sum"  "contr.poly"

# %%
## READ IN MERGED DATA
df <- read_csv("Phase2_nutrient/Phase2_nutrient_merged.csv")
# Out:
# Rows: 392 Columns: 25
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (17): Vial_num, n_notes, c_notes, n_exclude, c_exclude, Phase_1_treat, Phase_1_rep_R, Phase_2_treat, Phase_2_rep...
# dbl  (8): linear_corr_d15n, wt_percent_n, linear_corr_d13c, wt_percent_c, Year, Phase_1_rep, Phase_2_rep, Tag_num
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# # Tissue

# %% [markdown]
# ## 1. % Nitrogen in Tissue

# %%
colnames(df)
unique(df$Tissue_type)
# Out:
#  [1] "Vial_num"         "linear_corr_d15n" "wt_percent_n"     "n_notes"          "linear_corr_d13c" "wt_percent_c"
#  [7] "c_notes"          "n_exclude"        "c_exclude"        "Year"             "Phase_1_treat"    "Phase_1_rep"
# [13] "Phase_1_rep_R"    "Phase_2_treat"    "Phase_2_rep"      "Phase_2_rep_R"    "Tag_color"        "Tag_num"
# [19] "Tissue_type"      "Sample_Name"      "Notes"            "Phase_1_DO"       "Phase_1_temp"     "Phase_2.1_DO"
# [25] "Phase_2.1_temp"
# [1] "S" "T"

# %%
#filter data
Tissue_Nitrogen <- df%>%
filter(Tissue_type == "T")%>%
filter(is.na(n_exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nitrogen %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue nitrogen
m1 <- lmer(wt_percent_n~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nitrogen, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         2.460607e+03 1  17.995337 0.0000
# Phase_1_DO                                          1.002611e+00 1   9.336845 0.3419
# Phase_1_temp                                        1.009569e-01 1  12.424869 0.7560
# Phase_2.1_temp                                      1.402046e+00 1  19.946527 0.2503
# Phase_2.1_DO                                        2.789255e-01 1  19.945471 0.6032
# Phase_1_DO:Phase_1_temp                             8.286588e-02 1   9.338071 0.7797
# Phase_1_DO:Phase_2.1_temp                           1.415350e-02 1  19.476957 0.9065
# Phase_1_temp:Phase_2.1_temp                         1.556939e-01 1  19.660839 0.6974
# Phase_1_DO:Phase_2.1_DO                             1.046116e+00 1  19.452557 0.3190
# Phase_1_temp:Phase_2.1_DO                           2.877669e+00 1  19.650810 0.1056
# Phase_2.1_temp:Phase_2.1_DO                         8.601115e-01 1  19.943452 0.3648
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              2.322334e+00 1  19.397794 0.1437
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.842682e+00 1  19.374332 0.1078
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              2.031440e-04 1  19.458788 0.9888
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.536262e-02 1  19.644491 0.8751
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.790661e+00 1  19.382225 0.1109

# %% [markdown]
# Nothing significant

# %%
#diagnostics
leveneTest(wt_percent_n~Phase_1_treat*Phase_2_treat, Tissue_Nitrogen) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 0.540328 0.9146876
#       166       NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 2. % Carbon in Tissue

# %%
#filter data
Tissue_Carbon <- df%>%
filter(Tissue_type == "T")%>%
filter(is.na(c_exclude))

# %%
#tissue carbon
summary_stats_t <- Tissue_Carbon %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_c, na.rm = TRUE),
    se_growth = std.error(wt_percent_c, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon
m2 <- lmer(wt_percent_c~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Carbon, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F
# (Intercept)                                         4.404600e+03
# Phase_1_DO                                          9.712223e-01
# Phase_1_temp                                        5.353824e-01
# Phase_2.1_temp                                      2.360766e-01
# Phase_2.1_DO                                        3.511163e-01
# Phase_1_DO:Phase_1_temp                             1.280955e-02
# Phase_1_DO:Phase_2.1_temp                           5.253806e-01
# Phase_1_temp:Phase_2.1_temp                         3.109066e-01
# Phase_1_DO:Phase_2.1_DO                             1.488905e-01
# Phase_1_temp:Phase_2.1_DO                           2.535599e+00
# Phase_2.1_temp:Phase_2.1_DO                         4.323475e-02
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              6.116850e+00
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                6.705267e-01
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.533658e+00
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.833157e+00
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 4.534282e-03
#                                                     Df
# (Intercept)                                         1
# Phase_1_DO                                          1
# Phase_1_temp                                        1
# Phase_2.1_temp                                      1
# Phase_2.1_DO                                        1
# Phase_1_DO:Phase_1_temp                             1
# Phase_1_DO:Phase_2.1_temp                           1
# Phase_1_temp:Phase_2.1_temp                         1
# Phase_1_DO:Phase_2.1_DO                             1
# Phase_1_temp:Phase_2.1_DO                           1
# Phase_2.1_temp:Phase_2.1_DO                         1
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1
#                                                     Df.res
# (Intercept)                                         18.42064
# Phase_1_DO                                          10.60208
# Phase_1_temp                                        12.55844
# Phase_2.1_temp                                      19.75749
# Phase_2.1_DO                                        19.75507
# Phase_1_DO:Phase_1_temp                             10.60697
# Phase_1_DO:Phase_2.1_temp                           19.10093
# Phase_1_temp:Phase_2.1_temp                         19.26239
# Phase_1_DO:Phase_2.1_DO                             19.07223
# Phase_1_temp:Phase_2.1_DO                           19.24310
# Phase_2.1_temp:Phase_2.1_DO                         19.75667
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              19.05131
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                19.02004
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              19.10914
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            19.25996
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 19.06210
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.3463
# Phase_1_temp                                        0.4778
# Phase_2.1_temp                                      0.6324
# Phase_2.1_DO                                        0.5602
# Phase_1_DO:Phase_1_temp                             0.9120
# Phase_1_DO:Phase_2.1_temp                           0.4773
# Phase_1_temp:Phase_2.1_temp                         0.5835
# Phase_1_DO:Phase_2.1_DO                             0.7039
# Phase_1_temp:Phase_2.1_DO                           0.1276
# Phase_2.1_temp:Phase_2.1_DO                         0.8374
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.0230
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.4230
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.2306
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.1085
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.9470

# %%
#posthocs
options(width = 120)
emmeans(m2,specs = pairwise ~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_1_temp Phase_2.1_temp emmean   SE   df lower.CL upper.CL
#  Hyp        Ambient      Ambient          42.8 1.35 46.2     40.1     45.5
#  Norm       Ambient      Ambient          44.6 1.35 46.2     41.9     47.3
#  Hyp        Warm         Ambient          44.7 1.44 54.5     41.8     47.5
#  Norm       Warm         Ambient          42.4 1.35 46.2     39.6     45.1
#  Hyp        Ambient      Warm             46.4 1.38 48.6     43.7     49.2
#  Norm       Ambient      Warm             43.2 1.38 48.6     40.4     46.0
#  Hyp        Warm         Warm             43.4 1.38 48.6     40.7     46.2
#  Norm       Warm         Warm             43.9 1.41 49.8     41.0     46.7
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                   estimate   SE   df t.ratio p.value
#  Hyp Ambient Ambient - Norm Ambient Ambient  -1.7750 1.57 26.1  -1.128  0.2698
#  Hyp Ambient Ambient - Hyp Warm Ambient      -1.8453 1.73 31.1  -1.069  0.2933
#  Hyp Ambient Ambient - Norm Warm Ambient      0.4417 1.66 27.7   0.267  0.7917
#  Hyp Ambient Ambient - Hyp Ambient Warm      -3.6124 1.88 60.7  -1.917  0.0599
#  Hyp Ambient Ambient - Norm Ambient Warm     -0.3810 1.93 47.4  -0.197  0.8443
#  Hyp Ambient Ambient - Hyp Warm Warm         -0.6208 1.93 47.5  -0.322  0.7491
#  Hyp Ambient Ambient - Norm Warm Warm        -1.0730 1.96 48.0  -0.548  0.5861
#  Norm Ambient Ambient - Hyp Warm Ambient     -0.0703 1.73 31.2  -0.041  0.9678
#  Norm Ambient Ambient - Norm Warm Ambient     2.2167 1.66 27.6   1.338  0.1917
#  Norm Ambient Ambient - Hyp Ambient Warm     -1.8374 1.93 47.4  -0.952  0.3457
#  Norm Ambient Ambient - Norm Ambient Warm     1.3940 1.88 60.7   0.740  0.4623
#  Norm Ambient Ambient - Hyp Warm Warm         1.1542 1.93 47.5   0.598  0.5526
#  Norm Ambient Ambient - Norm Warm Warm        0.7020 1.96 48.0   0.359  0.7214
#  Hyp Warm Ambient - Norm Warm Ambient         2.2870 1.65 29.7   1.388  0.1754
#  Hyp Warm Ambient - Hyp Ambient Warm         -1.7671 1.99 51.6  -0.888  0.3786
#  Hyp Warm Ambient - Norm Ambient Warm         1.4643 1.99 51.6   0.736  0.4651
#  Hyp Warm Ambient - Hyp Warm Warm             1.2244 1.95 67.0   0.629  0.5316
#  Hyp Warm Ambient - Norm Warm Warm            0.7723 2.02 52.1   0.383  0.7033
#  Norm Warm Ambient - Hyp Ambient Warm        -4.0541 1.93 47.4  -2.101  0.0409
#  Norm Warm Ambient - Norm Ambient Warm       -0.8227 1.93 47.4  -0.426  0.6718
#  Norm Warm Ambient - Hyp Warm Warm           -1.0625 1.93 47.5  -0.551  0.5845
#  Norm Warm Ambient - Norm Warm Warm          -1.5146 1.91 60.7  -0.792  0.4316
#  Hyp Ambient Warm - Norm Ambient Warm         3.2314 1.61 28.2   2.001  0.0551
#  Hyp Ambient Warm - Hyp Warm Warm             2.9916 1.69 29.2   1.768  0.0875
#  Hyp Ambient Warm - Norm Warm Warm            2.5394 1.72 29.5   1.476  0.1505
#  Norm Ambient Warm - Hyp Warm Warm           -0.2398 1.70 29.7  -0.141  0.8884
#  Norm Ambient Warm - Norm Warm Warm          -0.6920 1.73 30.4  -0.401  0.6914
#  Hyp Warm Warm - Norm Warm Warm              -0.4521 1.64 27.9  -0.276  0.7845
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger

# %%
#Normoxic Warm Ambient - Hypoxic Ambient Warm p = 0.0414
    #warm ambient(42.4) - hypoxic warm (46.4)

#not a strong indication of anything in particular

# %%
#diagnostics
leveneTest(wt_percent_c~Phase_1_treat*Phase_2_treat, Tissue_Carbon) 
m1.e <- residuals(m2) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.6587568 0.8217245
#       168        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 3. Carbon:Nitrogen in Tissue

# %%
#filter data
Tissue_CN <- df%>%
filter(Tissue_type == "T")%>%
filter(is.na(n_exclude))%>%
filter(is.na(c_exclude))

# %%
#tissue c:n
summary_stats_t <- Tissue_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean((wt_percent_c/wt_percent_n), na.rm = TRUE),
    se_growth = std.error((wt_percent_c/wt_percent_n), na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Tissue (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon:nitrogen
m3 <- lmer((wt_percent_c/wt_percent_n)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_CN, REML=TRUE)
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res    Pr(>F)
# (Intercept)                                         8.666382e+02 1  17.736215 0.0000
# Phase_1_DO                                          1.012578e+00 1   9.302556 0.3397
# Phase_1_temp                                        1.148062e+00 1  13.062418 0.3034
# Phase_2.1_temp                                      5.795778e-01 1  19.935732 0.4554
# Phase_2.1_DO                                        1.373187e-01 1  19.934486 0.7149
# Phase_1_DO:Phase_1_temp                             4.838243e-03 1   9.303681 0.9460
# Phase_1_DO:Phase_2.1_temp                           1.558996e-02 1  19.465815 0.9019
# Phase_1_temp:Phase_2.1_temp                         2.025274e-01 1  19.700347 0.6576
# Phase_1_DO:Phase_2.1_DO                             1.489019e+00 1  19.441349 0.2370
# Phase_1_temp:Phase_2.1_DO                           2.866928e+00 1  19.692023 0.1062
# Phase_2.1_temp:Phase_2.1_DO                         6.452938e-02 1  19.932176 0.8021
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.222958e-01 1  19.399305 0.7303
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.901208e+00 1  19.375559 0.1045
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              2.986337e-01 1  19.447983 0.5910
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.480864e-01 1  19.685859 0.6239
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.108102e+00 1  19.383669 0.3054

# %% [markdown]
# Nothing significant

# %%
#diagnostics
leveneTest((wt_percent_c/wt_percent_n)~Phase_1_treat*Phase_2_treat, Tissue_CN) 
m1.e <- residuals(m3) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.5807604 0.8867979
#       166        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## 4. Mg Carbon and Nitrogen in Tissue

# %%
# Read in growth dataset
setwd("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC")
weight_df <- read_csv("Oyster_Weight_Data/growth_phase2.1_weightsSKM.csv")
# Out:
# Rows: 1152 Columns: 37
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (20): Sample_Name, Date_MMDDYYYY_pre, Phase_1_treat, Phase_1_rep, Phase_2_treat, Phase_2_rep, Tag_color, Notes_p...
# dbl (17): Order_pre, Year, Tag_num, Submerged_weight_pre, Dry_weight_pre, Order_post, Date_MMDDYYYY_post, Submerged_...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
#calculate % N averages Tissue

summary_stats_t <- Tissue_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  summarize(
    mean_N = mean(wt_percent_n, na.rm = TRUE),
    mean_C = mean(wt_percent_c, na.rm = TRUE))

print(summary_stats_t)
# Out:
# `summarise()` has regrouped the output.
# ℹ Summaries were computed grouped by Phase_1_treat and Phase_2_treat.
# ℹ Output is grouped by Phase_1_treat.
# ℹ Use `summarise(.groups = "drop_last")` to silence this message.
# ℹ Use `summarise(.by = c(Phase_1_treat, Phase_2_treat))` for per-operation
#   grouping (`?dplyr::dplyr_by`) instead.
# # A tibble: 16 × 4
# # Groups:   Phase_1_treat [4]
#    Phase_1_treat Phase_2_treat mean_N mean_C
#    <chr>         <chr>          <dbl>  <dbl>
#  1 Both          Both            7.95   44.6
#  2 Both          Cont            8.99   44.9
#  3 Both          Hyp             7.82   44.5
#  4 Both          Warm            7.89   40.6
#  5 Cont          Both            8.03   42.6
#  6 Cont          Cont            9.16   43.4
#  7 Cont          Hyp             8.27   45.8
#  8 Cont          Warm            7.79   44.1
#  9 Hyp           Both            8.32   45.5
# 10 Hyp           Cont            7.8    43.4
# 11 Hyp           Hyp             8.53   42.2
# 12 Hyp           Warm            7.64   47.1
# 13 Warm          Both            8.12   45.1
# 14 Warm          Cont            8.58   41.8
# 15 Warm          Hyp             8.13   42.9
# 16 Warm          Warm            8.44   42.1

# %%
Tissue_Nutrients <- weight_df %>%
  filter(Exclude_all != "Y" | is.na(Exclude_all)) %>%
  left_join(
    summary_stats_t,
    by = c("Phase_1_treat", "Phase_2_treat")) %>%
  mutate(mgN_tissue_P2 = (Actual_tissue_post_mg * mean_N) / 100)%>%
  mutate(mgC_tissue_P2 = (Actual_tissue_post_mg * mean_C) / 100)

View(Tissue_Nutrients)
# Out:
#      Sample_Name            Order_pre Date_MMDDYYYY_pre Year Phase_1_treat Phase_1_rep Phase_2_treat Phase_2_rep
# 1    2024_Both01_Both01_O1    3       7/23/24           2024 Both          01          Both          01
# 2    2024_Both01_Both01_O2    7       7/23/24           2024 Both          01          Both          01
# 3    2024_Both01_Both02_O13  50       7/23/24           2024 Both          01          Both          02
# 4    2024_Both01_Both02_O14  55       7/23/24           2024 Both          01          Both          02
# 5    2024_Both01_Both03_O25  98       7/24/24           2024 Both          01          Both          03
# 6    2024_Both01_Both03_O26 103       7/24/24           2024 Both          01          Both          03
# 7    2024_Both01_Both04_O37 214       7/24/24           2024 Both          01          Both          04
# 8    2024_Both01_Both04_O38 111       7/24/24           2024 Both          01          Both          04
# 9    2024_Both01_Both05_O49 260       7/25/24           2024 Both          01          Both          05
# 10   2024_Both01_Both05_O50 266       7/25/24           2024 Both          01          Both          05
# 11   2024_Both01_Both06_O61 383       7/26/24           2024 Both          01          Both          06
# 12   2024_Both01_Both06_O62 388       7/26/24           2024 Both          01          Both          06
# 13   2024_Both01_Cont01_O1  432       7/23/24           2024 Both          01          Cont          01
# 14   2024_Both01_Cont01_O2  172       7/23/24           2024 Both          01          Cont          01
# 15   2024_Both01_Cont02_O13 481       7/23/24           2024 Both          01          Cont          02
# 16   2024_Both01_Cont02_O14 485       7/23/24           2024 Both          01          Cont          02
# 17   2024_Both01_Cont03_O25 356       7/24/24           2024 Both          01          Cont          03
# 18   2024_Both01_Cont04_O37 620       7/24/24           2024 Both          01          Cont          04
# 19   2024_Both01_Cont04_O38 624       7/24/24           2024 Both          01          Cont          04
# 20   2024_Both01_Cont05_O49 669       7/25/24           2024 Both          01          Cont          05
# 21   2024_Both01_Cont05_O50 672       7/25/24           2024 Both          01          Cont          05
# 22   2024_Both01_Cont06_O61 729       7/25/24           2024 Both          01          Cont          06
# 23   2024_Both01_Cont06_O62 685       7/25/24           2024 Both          01          Cont          06
# 1114 NA                   8.435000 42.13000 35.64809      178.05027
# 1115 NA                   8.435000 42.13000 39.35787      196.57937
# 1116 NA                   8.435000 42.13000 16.22516       81.03922
# 1117 NA                   8.435000 42.13000 41.18107      205.68566

# %% [markdown]
# ### 4.1 Mg Nitrogen Analysis

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgN_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgN_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue nitrogen
m1 <- lmer(mgN_tissue_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         3.738647e+02 1  23.88718 0.0000
# Phase_1_DO                                          6.078182e+00 1  18.79308 0.0235
# Phase_1_temp                                        1.379146e-01 1  16.84790 0.7150
# Phase_2.1_temp                                      1.022468e+00 1  20.00037 0.3240
# Phase_2.1_DO                                        1.219191e+00 1  20.00079 0.2826
# Phase_1_DO:Phase_1_temp                             8.556301e-03 1  16.85127 0.9274
# Phase_1_DO:Phase_2.1_temp                           7.078516e-02 1  19.99877 0.7929
# Phase_1_temp:Phase_2.1_temp                         2.298760e-01 1  19.98332 0.6368
# Phase_1_DO:Phase_2.1_DO                             2.185021e+00 1  20.00299 0.1549
# Phase_1_temp:Phase_2.1_DO                           1.029574e+01 1  19.98825 0.0044
# Phase_2.1_temp:Phase_2.1_DO                         5.801581e-02 1  20.00080 0.8121
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              5.790823e-01 1  19.99656 0.4556
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.574596e+00 1  20.00161 0.2240
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.795336e-01 1  20.00284 0.6763
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.344789e+00 1  19.98835 0.1414
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 8.258576e-02 1  20.00173 0.7768

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO, adjust = "none")
emmeans(m1,specs = pairwise ~ Phase_1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO emmean  SE   df lower.CL upper.CL
#  Hyp          26.6 1.6 30.4     23.3     29.9
#  Norm         29.8 1.6 30.3     26.5     33.1
#
# Results are averaged over the levels of: Phase_1_temp, Phase_2.1_temp, Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast   estimate  SE   df t.ratio p.value
#  Hyp - Norm    -3.19 1.3 18.8  -2.465  0.0235
#
# Results are averaged over the levels of: Phase_1_temp, Phase_2.1_temp, Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Ambient      Hyp            28.2 2.14 27.5     23.8     32.6
#  Warm         Hyp            25.1 2.14 27.7     20.8     29.5
#  Ambient      Norm           28.7 2.14 27.3     24.3     33.0
#  Warm         Norm           30.8 2.14 27.7     26.4     35.2
#
# Results are averaged over the levels of: Phase_1_DO, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                   estimate   SE   df t.ratio p.value
#  Ambient Hyp - Warm Hyp        3.057 1.48 23.7   2.064  0.0502
#  Ambient Hyp - Ambient Norm   -0.453 2.87 23.3  -0.157  0.8762
#  Ambient Hyp - Warm Norm      -2.591 3.03 27.6  -0.856  0.3996
#  Warm Hyp - Ambient Norm      -3.510 3.03 27.5  -1.160  0.2560
#  Warm Hyp - Warm Norm         -5.648 2.88 23.6  -1.959  0.0621
#  Ambient Norm - Warm Norm     -2.138 1.48 23.3  -1.449  0.1607
#
# Results are averaged over the levels of: Phase_1_DO, Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %% [markdown]
# Takeaways:
#
# Oysters exposed to early life hypoxia stored less nitrogen in tissue, regardless of phase 2 environment.
#
# Oysters in phase 2 hypoxia stored less nitrogen when they had previously been exposed to warming.

# %%
#diagnostics
leveneTest(mgN_tissue_P2~Phase_1_treat*Phase_2_treat, Tissue_Nutrients) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df   F value  Pr(>F)
# group   15 1.218471 0.2505762
#       1101       NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ### 4.2 Mg Carbon Analysis

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Tissue_Nutrients %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgC_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue carbon
m1 <- lmer(mgC_tissue_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+ Actual_tissue_pre_mg+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Tissue_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res      Pr(>F)
# (Intercept)                                         3.346819e+01 1    46.225117 0.0000
# Phase_1_DO                                          3.650573e-01 1    10.693156 0.5583
# Phase_1_temp                                        8.752793e+00 1     9.876744 0.0145
# Phase_2.1_temp                                      2.657859e-01 1    19.941065 0.6118
# Phase_2.1_DO                                        2.984221e+00 1    19.919417 0.0996
# Actual_tissue_pre_mg                                5.641330e+03 1  1031.152743 0.0000
# Phase_1_DO:Phase_1_temp                             1.835864e-02 1     9.877463 0.8949
# Phase_1_DO:Phase_2.1_temp                           1.551548e-01 1    19.961672 0.6978
# Phase_1_temp:Phase_2.1_temp                         5.386981e+00 1    19.971911 0.0310
# Phase_1_DO:Phase_2.1_DO                             1.952067e-01 1    19.966206 0.6634
# Phase_1_temp:Phase_2.1_DO                           5.938547e+00 1    20.094939 0.0242
# Phase_2.1_temp:Phase_2.1_DO                         2.408016e+00 1    19.942773 0.1364
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              2.740489e+01 1    20.008928 0.0000
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                8.709250e-03 1    19.976668 0.9266
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              3.183260e+00 1    19.967986 0.0896
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            7.228200e+00 1    20.027621 0.0141
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.402105e+00 1    19.989396 0.2503

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp Phase_2.1_temp Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Ambient      Ambient        Hyp             142 4.91 25.6      132      152
#  Warm         Ambient        Hyp             140 4.91 25.7      130      151
#  Ambient      Warm           Hyp             151 4.90 25.4      141      161
#  Warm         Warm           Hyp             151 4.93 26.0      140      161
#  Ambient      Ambient        Norm            157 4.89 25.2      147      167
#  Warm         Ambient        Norm            156 4.92 25.9      146      166
#  Ambient      Warm           Norm            161 4.89 25.1      151      171
#  Warm         Warm           Norm            142 4.91 25.7      132      152
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                   estimate   SE   df t.ratio p.value
#  Ambient Ambient Hyp - Warm Ambient Hyp        1.565 3.54 19.0   0.442  0.6634
#  Ambient Ambient Hyp - Ambient Warm Hyp       -8.815 6.94 25.7  -1.271  0.2152
#  Ambient Ambient Hyp - Warm Warm Hyp          -8.554 6.96 25.9  -1.229  0.2301
#  Ambient Ambient Hyp - Ambient Ambient Norm  -14.574 6.93 25.5  -2.104  0.0454
#  Ambient Ambient Hyp - Warm Ambient Norm     -13.890 6.95 25.7  -1.999  0.0563
#  Ambient Ambient Hyp - Ambient Warm Norm     -18.668 6.92 25.5  -2.696  0.0122
#  Ambient Ambient Hyp - Warm Warm Norm         -0.305 6.94 25.6  -0.044  0.9653
#  Warm Ambient Hyp - Ambient Warm Hyp         -10.380 6.94 25.6  -1.496  0.1469
#  Warm Ambient Hyp - Warm Warm Hyp            -10.119 6.96 26.0  -1.454  0.1578
#  Warm Ambient Hyp - Ambient Ambient Norm     -16.139 6.93 25.4  -2.329  0.0281
#  Warm Ambient Hyp - Warm Ambient Norm        -15.455 6.96 26.0  -2.222  0.0352
#  Warm Ambient Hyp - Ambient Warm Norm        -20.233 6.93 25.4  -2.920  0.0072
#  Warm Ambient Hyp - Warm Warm Norm            -1.870 6.95 25.9  -0.269  0.7900
#  Ambient Warm Hyp - Warm Warm Hyp              0.261 3.54 19.1   0.074  0.9420
#  Ambient Warm Hyp - Ambient Ambient Norm      -5.759 6.92 25.4  -0.832  0.4129
#  Ambient Warm Hyp - Warm Ambient Norm         -5.075 6.95 25.7  -0.730  0.4718
#  Ambient Warm Hyp - Ambient Warm Norm         -9.853 6.92 25.4  -1.424  0.1666
#  Ambient Warm Hyp - Warm Warm Norm             8.510 6.94 25.6   1.226  0.2312
#  Warm Warm Hyp - Ambient Ambient Norm         -6.020 6.94 25.5  -0.868  0.3935
#  Warm Warm Hyp - Warm Ambient Norm            -5.336 6.97 26.1  -0.766  0.4507
#  Warm Warm Hyp - Ambient Warm Norm           -10.115 6.94 25.6  -1.458  0.1571
#  Warm Warm Hyp - Warm Warm Norm                8.249 6.96 26.0   1.186  0.2465
#  Ambient Ambient Norm - Warm Ambient Norm      0.684 3.53 18.8   0.194  0.8482
#  Ambient Ambient Norm - Ambient Warm Norm     -4.094 6.91 25.3  -0.593  0.5588
#  Ambient Ambient Norm - Warm Warm Norm        14.269 6.93 25.4   2.059  0.0498
#  Warm Ambient Norm - Ambient Warm Norm        -4.779 6.94 25.5  -0.689  0.4971
#  Warm Ambient Norm - Warm Warm Norm           13.585 6.96 26.0   1.953  0.0617
#  Ambient Warm Norm - Warm Warm Norm           18.363 3.51 18.4   5.233 <0.0001
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger

# %%
#format display for jupyter
options(repr.plot.width = 12, repr.plot.height = 6)

# plot Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO tissue
summary_stats_t <- Tissue_Nutrients%>%
  group_by(Phase_1_temp, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgC_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_temp <- factor(summary_stats_t$Phase_1_temp, 
                                       levels = c("Ambient", "Warm"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp",  "Both"))

#plot with mean and SD
ggplot(summary_stats_t, aes(x = Phase_1_temp, y = mean_growth, color = Phase_1_temp)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 16) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(
    vars(Phase_2_treat),
    labeller = as_labeller(c(
      "Hyp" = "Hypoxic",
      "Cont" = "Control",
      "Warm" = "Warm",
      "Both" = "Both")), scales = "fixed", nrow = 1) +
  scale_color_manual(values = c("Warm" = "#B00149", "Ambient" = "darkblue")) +
  labs(x = "Phase 1 Temperature", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
Ambient Ambient Hyp - Ambient Ambient Norm  -14.574 6.93 25.5  -2.104  0.0454
    ambient hyp - ambient cont
Ambient Ambient Hyp - Ambient Warm Norm     -18.668 6.92 25.5  -2.696  0.0122
    ambient hyp - ambient warm
Warm Ambient Hyp - Ambient Ambient Norm     -16.139 6.93 25.4  -2.329  0.0281
    warm hyp - ambient cont
Warm Ambient Hyp - Warm Ambient Norm        -15.455 6.96 26.0  -2.222  0.0352
    warm hyp - warm cont
Warm Ambient Hyp - Ambient Warm Norm        -20.233 6.93 25.4  -2.920  0.0072
    warm hyp - ambient warm
Ambient Ambient Norm - Warm Warm Norm        14.269 6.93 25.4   2.059  0.0498
    ambient cont - warm warm
Ambient Warm Norm - Warm Warm Norm           18.363 3.51 18.4   5.233 <0.0001
    ambient warm - warm warm

# %%
#posthocs
options(width = 120)
emmeans(m1,specs = pairwise ~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_1_temp Phase_2.1_temp emmean   SE   df lower.CL upper.CL
#  Hyp        Ambient      Ambient           146 3.90 36.1      138      153
#  Norm       Ambient      Ambient           153 3.89 35.7      145      161
#  Hyp        Warm         Ambient           154 3.93 37.2      146      162
#  Norm       Warm         Ambient           143 3.92 36.8      135      150
#  Hyp        Ambient      Warm              160 3.89 36.0      153      168
#  Norm       Ambient      Warm              151 3.89 35.7      143      159
#  Hyp        Warm         Warm              142 3.93 37.3      134      150
#  Norm       Warm         Warm              151 3.91 36.7      143      159
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                   estimate   SE   df t.ratio p.value
#  Hyp Ambient Ambient - Norm Ambient Ambient   -7.653 3.56 26.2  -2.151  0.0409
#  Hyp Ambient Ambient - Hyp Warm Ambient       -8.351 3.54 26.9  -2.358  0.0259
#  Hyp Ambient Ambient - Norm Warm Ambient       2.948 3.59 27.1   0.821  0.4189
#  Hyp Ambient Ambient - Hyp Ambient Warm      -14.974 5.51 39.1  -2.718  0.0097
#  Hyp Ambient Ambient - Norm Ambient Warm      -5.588 5.50 35.9  -1.015  0.3167
#  Hyp Ambient Ambient - Hyp Warm Warm           3.336 5.53 36.7   0.603  0.5503
#  Hyp Ambient Ambient - Norm Warm Warm         -5.274 5.52 36.4  -0.955  0.3460
#  Norm Ambient Ambient - Hyp Warm Ambient      -0.698 3.59 27.1  -0.195  0.8472
#  Norm Ambient Ambient - Norm Warm Ambient     10.600 3.52 26.1   3.015  0.0057
#  Norm Ambient Ambient - Hyp Ambient Warm      -7.321 5.50 35.9  -1.330  0.1919
#  Norm Ambient Ambient - Norm Ambient Warm      2.065 5.49 38.7   0.376  0.7091
#  Norm Ambient Ambient - Hyp Warm Warm         10.989 5.53 36.6   1.987  0.0544
#  Norm Ambient Ambient - Norm Warm Warm         2.379 5.52 36.2   0.431  0.6689
#  Hyp Warm Ambient - Norm Warm Ambient         11.299 3.62 28.1   3.117  0.0042
#  Hyp Warm Ambient - Hyp Ambient Warm          -6.623 5.53 36.5  -1.198  0.2386
#  Hyp Warm Ambient - Norm Ambient Warm          2.763 5.52 36.5   0.500  0.6200
#  Hyp Warm Ambient - Hyp Warm Warm             11.688 5.55 40.3   2.104  0.0416
#  Hyp Warm Ambient - Norm Warm Warm             3.077 5.54 37.0   0.555  0.5822
#  Norm Warm Ambient - Hyp Ambient Warm        -17.922 5.53 36.5  -3.242  0.0025
#  Norm Warm Ambient - Norm Ambient Warm        -8.536 5.52 36.2  -1.548  0.1304
#  Norm Warm Ambient - Hyp Warm Warm             0.389 5.55 37.2   0.070  0.9446
#  Norm Warm Ambient - Norm Warm Warm           -8.221 5.54 39.9  -1.484  0.1455
#  Hyp Ambient Warm - Norm Ambient Warm          9.386 3.56 26.1   2.639  0.0138
#  Hyp Ambient Warm - Hyp Warm Warm             18.310 3.54 26.7   5.178 <0.0001
#  Hyp Ambient Warm - Norm Warm Warm             9.700 3.58 26.8   2.707  0.0116
#  Norm Ambient Warm - Hyp Warm Warm             8.924 3.60 27.2   2.482  0.0195
#  Norm Ambient Warm - Norm Warm Warm            0.314 3.52 26.1   0.089  0.9295
#  Hyp Warm Warm - Norm Warm Warm               -8.610 3.62 28.0  -2.377  0.0245
#
# Results are averaged over the levels of: Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger

# %%
#format display for jupyter
options(repr.plot.width = 12, repr.plot.height = 6)

# plot Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO tissue
summary_stats_t <- Tissue_Nutrients%>%
  group_by(Phase_1_DO, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(mgC_tissue_P2, na.rm = TRUE),
    se_growth = std.error(mgC_tissue_P2, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_DO <- factor(summary_stats_t$Phase_1_DO, 
                                       levels = c("Norm", "Hyp"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp",  "Both"))

#plot with mean and SD
ggplot(summary_stats_t, aes(x = Phase_1_DO, y = mean_growth, color = Phase_1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 16) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(
    vars(Phase_2_treat),
    labeller = as_labeller(c(
      "Hyp" = "Hypoxic",
      "Cont" = "Control",
      "Warm" = "Warm",
      "Both" = "Both")), scales = "fixed", nrow = 1) +
  scale_color_manual(values = c("Hyp" = "darkmagenta", "Norm" = "seagreen")) +
  labs(x = "Phase 1 DO", y = "Carbon in Tissue (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#Hyp Ambient Ambient - Norm Ambient Ambient   -7.653 3.56 26.2  -2.151  0.0409
    hyp 
#Hyp Ambient Ambient - Hyp Warm Ambient       -8.351 3.54 26.9  -2.358  0.0259
#Hyp Ambient Ambient - Hyp Ambient Warm      -14.974 5.51 39.1  -2.718  0.0097
#Norm Ambient Ambient - Norm Warm Ambient     10.600 3.52 26.1   3.015  0.0057
#Hyp Warm Ambient - Norm Warm Ambient         11.299 3.62 28.1   3.117  0.0042
#Hyp Warm Ambient - Hyp Warm Warm             11.688 5.55 40.3   2.104  0.0416
#Norm Warm Ambient - Hyp Ambient Warm        -17.922 5.53 36.5  -3.242  0.0025
#Hyp Ambient Warm - Norm Ambient Warm          9.386 3.56 26.1   2.639  0.0138
#Hyp Ambient Warm - Hyp Warm Warm             18.310 3.54 26.7   5.178 <0.0001
#Hyp Ambient Warm - Norm Warm Warm             9.700 3.58 26.8   2.707  0.0116
#Norm Ambient Warm - Hyp Warm Warm             8.924 3.60 27.2   2.482  0.0195
#Hyp Warm Warm - Norm Warm Warm               -8.610 3.62 28.0  -2.377  0.0245

# %% [markdown]
# # Shell

# %% [markdown]
# ## 1. % Nitrogen in Shell

# %%
#filter data
Shell_Nitrogen <- df%>%
filter(Tissue_type == "S")%>%
filter(is.na(n_exclude))

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#tissue nitrogen
summary_stats_t <- Shell_Nitrogen %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_n, na.rm = TRUE),
    se_growth = std.error(wt_percent_n, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  ylim(0.15, 0.30)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell nitrogen
m1 <- lmer(wt_percent_n~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nitrogen, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         2.043063e+03 1  12.36742 0.0000
# Phase_1_DO                                          1.397427e-02 1  10.85770 0.9081
# Phase_1_temp                                        1.499748e-02 1  10.15219 0.9049
# Phase_2.1_temp                                      3.464505e+00 1  19.85048 0.0776
# Phase_2.1_DO                                        9.711794e-01 1  19.85048 0.3362
# Phase_1_DO:Phase_1_temp                             1.215836e+00 1  10.15220 0.2956
# Phase_1_DO:Phase_2.1_temp                           2.366202e+00 1  19.79724 0.1398
# Phase_1_temp:Phase_2.1_temp                         1.217189e+00 1  19.76710 0.2832
# Phase_1_DO:Phase_2.1_DO                             3.501232e-01 1  19.79724 0.5607
# Phase_1_temp:Phase_2.1_DO                           1.217449e+00 1  19.76710 0.2831
# Phase_2.1_temp:Phase_2.1_DO                         2.026221e+00 1  19.85048 0.1701
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              3.381658e+00 1  19.76709 0.0810
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                7.363015e-01 1  19.76709 0.4011
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.134302e+00 1  19.79724 0.2997
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.217449e+00 1  19.76710 0.2831
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.504309e-02 1  19.76709 0.9036

# %% [markdown]
# ## 2. % Carbon in Shell

# %%
#filter data
Shell_Carbon <- df%>%
filter(Tissue_type == "S")%>%
filter(is.na(c_exclude))

# %%
#tissue carbon
summary_stats_t <- Shell_Carbon %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(wt_percent_c, na.rm = TRUE),
    se_growth = std.error(wt_percent_c, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Carbon in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
ylim(15,18)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##Shell carbon
m2 <- lmer(wt_percent_c~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Carbon, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         2.272049e+04 1  18.78179 0.0000
# Phase_1_DO                                          1.302377e-01 1  13.00526 0.7240
# Phase_1_temp                                        1.896658e+00 1  13.00274 0.1917
# Phase_2.1_temp                                      5.720248e-02 1  19.32695 0.8135
# Phase_2.1_DO                                        3.432965e-03 1  19.32695 0.9539
# Phase_1_DO:Phase_1_temp                             9.004444e-02 1  13.00513 0.7689
# Phase_1_DO:Phase_2.1_temp                           4.684673e-01 1  18.69820 0.5021
# Phase_1_temp:Phase_2.1_temp                         4.479149e-01 1  18.70035 0.5115
# Phase_1_DO:Phase_2.1_DO                             1.368940e+00 1  18.69820 0.2567
# Phase_1_temp:Phase_2.1_DO                           5.073884e-05 1  18.70035 0.9944
# Phase_2.1_temp:Phase_2.1_DO                         1.584004e+00 1  19.32695 0.2232
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              2.229833e+00 1  18.69815 0.1521
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                6.642651e-02 1  18.69815 0.7994
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              5.212313e-02 1  18.69820 0.8219
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.201167e+00 1  18.70035 0.2870
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 5.073884e-05 1  18.69815 0.9944

# %% [markdown]
# ## 3. Carbon:Nitrogen in Shell

# %%
#filter data
Shell_CN <- df%>%
filter(Tissue_type == "S")%>%
filter(is.na(n_exclude))%>%
filter(is.na(c_exclude))

# %%
#tissue c:n
summary_stats_t <- Shell_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean((wt_percent_c/wt_percent_n), na.rm = TRUE),
    se_growth = std.error((wt_percent_c/wt_percent_n), na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Shell (%)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell carbon:nitrogen
m3 <- lmer((wt_percent_c/wt_percent_n)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_CN, REML=TRUE)
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         1.574742e+03 1  14.68914 0.0000
# Phase_1_DO                                          3.676224e-01 1  10.52370 0.5572
# Phase_1_temp                                        1.231866e+00 1  10.52333 0.2918
# Phase_2.1_temp                                      3.421284e+00 1  19.77954 0.0794
# Phase_2.1_DO                                        2.086412e-01 1  19.77954 0.6528
# Phase_1_DO:Phase_1_temp                             5.242249e-02 1  10.52370 0.8233
# Phase_1_DO:Phase_2.1_temp                           1.886709e+00 1  19.58366 0.1851
# Phase_1_temp:Phase_2.1_temp                         2.618342e+00 1  19.58384 0.1216
# Phase_1_DO:Phase_2.1_DO                             6.598977e-01 1  19.58366 0.4264
# Phase_1_temp:Phase_2.1_DO                           3.896123e-01 1  19.58384 0.5397
# Phase_2.1_temp:Phase_2.1_DO                         2.802683e-02 1  19.77954 0.8687
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.246871e+00 1  19.58366 0.2777
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.114544e+00 1  19.58366 0.3039
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              5.868425e-01 1  19.58366 0.4528
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.335318e-03 1  19.58384 0.9619
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 2.633981e-01 1  19.58366 0.6135

# %% [markdown]
# ## 4. Mg Carbon and Nitrogen in Shell

# %%
#calculate % N averages Tissue

summary_stats_s <- Shell_CN %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  summarize(
    mean_N = mean(wt_percent_n, na.rm = TRUE),
    mean_C = mean(wt_percent_c, na.rm = TRUE))

print(summary_stats_s)
# Out:
# `summarise()` has regrouped the output.
# ℹ Summaries were computed grouped by Phase_1_treat and Phase_2_treat.
# ℹ Output is grouped by Phase_1_treat.
# ℹ Use `summarise(.groups = "drop_last")` to silence this message.
# ℹ Use `summarise(.by = c(Phase_1_treat, Phase_2_treat))` for per-operation
#   grouping (`?dplyr::dplyr_by`) instead.
# # A tibble: 16 × 4
# # Groups:   Phase_1_treat [4]
#    Phase_1_treat Phase_2_treat mean_N mean_C
#    <chr>         <chr>          <dbl>  <dbl>
#  1 Both          Both           0.217   16.9
#  2 Both          Cont           0.258   16.5
#  3 Both          Hyp            0.208   16.4
#  4 Both          Warm           0.2     16.3
#  5 Cont          Both           0.233   16.4
#  6 Cont          Cont           0.2     16.4
#  7 Cont          Hyp            0.217   16.1
#  8 Cont          Warm           0.225   16.4
#  9 Hyp           Both           0.192   16.1
# 10 Hyp           Cont           0.242   16.4
# 11 Hyp           Hyp            0.217   16.5
# 12 Hyp           Warm           0.192   15.9
# 13 Warm          Both           0.192   16.6
# 14 Warm          Cont           0.242   16.9
# 15 Warm          Hyp            0.208   16.2
# 16 Warm          Warm           0.2     16.4

# %%
Shell_Nutrients <- weight_df %>%
  filter(Exclude_all != "Y" | is.na(Exclude_all)) %>%
  left_join(
    summary_stats_s,
    by = c("Phase_1_treat", "Phase_2_treat")) %>%
  mutate(mgN_shell_P2 = (Actual_shell_post_mg * mean_N) / 100)%>%
  mutate(mgC_shell_P2 = (Actual_shell_post_mg * mean_C) / 100)

View(Shell_Nutrients)
# Out:
#      Sample_Name            Order_pre Date_MMDDYYYY_pre Year Phase_1_treat Phase_1_rep Phase_2_treat Phase_2_rep
# 1    2024_Both01_Both01_O1    3       7/23/24           2024 Both          01          Both          01
# 2    2024_Both01_Both01_O2    7       7/23/24           2024 Both          01          Both          01
# 3    2024_Both01_Both02_O13  50       7/23/24           2024 Both          01          Both          02
# 4    2024_Both01_Both02_O14  55       7/23/24           2024 Both          01          Both          02
# 5    2024_Both01_Both03_O25  98       7/24/24           2024 Both          01          Both          03
# 6    2024_Both01_Both03_O26 103       7/24/24           2024 Both          01          Both          03
# 7    2024_Both01_Both04_O37 214       7/24/24           2024 Both          01          Both          04
# 8    2024_Both01_Both04_O38 111       7/24/24           2024 Both          01          Both          04
# 9    2024_Both01_Both05_O49 260       7/25/24           2024 Both          01          Both          05
# 10   2024_Both01_Both05_O50 266       7/25/24           2024 Both          01          Both          05
# 11   2024_Both01_Both06_O61 383       7/26/24           2024 Both          01          Both          06
# 12   2024_Both01_Both06_O62 388       7/26/24           2024 Both          01          Both          06
# 13   2024_Both01_Cont01_O1  432       7/23/24           2024 Both          01          Cont          01
# 14   2024_Both01_Cont01_O2  172       7/23/24           2024 Both          01          Cont          01
# 15   2024_Both01_Cont02_O13 481       7/23/24           2024 Both          01          Cont          02
# 16   2024_Both01_Cont02_O14 485       7/23/24           2024 Both          01          Cont          02
# 17   2024_Both01_Cont03_O25 356       7/24/24           2024 Both          01          Cont          03
# 18   2024_Both01_Cont04_O37 620       7/24/24           2024 Both          01          Cont          04
# 19   2024_Both01_Cont04_O38 624       7/24/24           2024 Both          01          Cont          04
# 20   2024_Both01_Cont05_O49 669       7/25/24           2024 Both          01          Cont          05
# 21   2024_Both01_Cont05_O50 672       7/25/24           2024 Both          01          Cont          05
# 22   2024_Both01_Cont06_O61 729       7/25/24           2024 Both          01          Cont          06
# 23   2024_Both01_Cont06_O62 685       7/25/24           2024 Both          01          Cont          06
# 24   2024_Both01_Hyp01_O1   779       7/23/24           2024 Both          01          Hyp           01
# 25   2024_Both01_Hyp01_O2   115       7/23/24           2024 Both          01          Hyp           01
# 26   2024_Both01_Hyp02_O13  826       7/23/24           2024 Both          01          Hyp           02
# 27   2024_Both01_Hyp02_O14  830       7/23/24           2024 Both          01          Hyp           02
# 28   2024_Both01_Hyp03_O25  874       7/24/24           2024 Both          01          Hyp           03
# 29   2024_Both01_Hyp03_O26  878       7/24/24           2024 Both          01          Hyp           03
# 30   2024_Both01_Hyp04_O37  953       7/24/24           2024 Both          01          Hyp           04
treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))

#plot with mean and SD, TISSUE
ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2_treat), 
             labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Nitrogen in Shell (Mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  ylim(1,2)+
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##shell nitrogen
m1 <- lmer(mgN_shell_P2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Shell_Nutrients, REML=TRUE)
aov_tab<-Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res   Pr(>F)
# (Intercept)                                         322.78715436 1  21.81261 0.0000
# Phase_1_DO                                            5.15731998 1  20.96032 0.0338
# Phase_1_temp                                          0.07942791 1  16.05212 0.7817
# Phase_2.1_temp                                        1.76864114 1  20.00027 0.1985
# Phase_2.1_DO                                          2.49326076 1  20.00051 0.1300
# Phase_1_DO:Phase_1_temp                               2.77770887 1  15.39229 0.1158
# Phase_1_DO:Phase_2.1_temp                             5.04398576 1  20.00097 0.0362
# Phase_1_temp:Phase_2.1_temp                           9.23096825 1  19.98606 0.0065
# Phase_1_DO:Phase_2.1_DO                               0.04755906 1  20.00328 0.8296
# Phase_1_temp:Phase_2.1_DO                            16.93999241 1  19.98976 0.0005
# Phase_2.1_temp:Phase_2.1_DO                           0.09748007 1  20.00051 0.7581
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp                8.21656633 1  19.99362 0.0095
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                  0.50625424 1  19.99766 0.4850
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO                3.77405039 1  20.00321 0.0663
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO             17.65424682 1  19.98987 0.0004
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO   0.20406258 1  19.99776 0.6563
