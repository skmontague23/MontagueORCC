# %% [markdown]
# # ORCC year 2 growth analysis

# %% [markdown]
# ### This analysis examines oyster growth from the end of august phase 2 (2024) until august the following year (2025) in response to phase 1 and phase 2 treatments

# %%
#load packages
library(lme4) #for linear mixed effects model
library(readr) #to read in data
library(tidyr)
library(emmeans) #for post hocs
library(esquisse) #interface for building plots
library(dplyr) #for data wrangling
library(nlme) #for linear mixed effects model
library(car) #for the Levene test
library(ggplot2) #for graphs
library(plotrix) #for standard error
library(performance) #model testing
library(lmtest) #another option than levene test for variance
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘tidyr’
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, pack, unpack
#
#
# Warning message:
# “package ‘emmeans’ was built under R version 4.4.3”
# Welcome to emmeans.
# Caution: You lose important information if you filter this package's results.
# See '? untidy'
#
# Warning message:
# “package ‘dplyr’ was built under R version 4.4.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘nlme’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     collapse
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmList
#
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
#
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.4.3”
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
#set contrasts ALWAYS RUN
options(contrasts = c("contr.sum","contr.poly")) #could also be contr.treatment for unequal groups sum
getOption("contrasts")
# Out:
# [1] "contr.sum"  "contr.poly"

# %%
getwd()
setwd("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC/Oyster_Weight_Data")

Year2_Growth <- read_csv("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC/Year_2_Data/growth_YEAR2_weights_merged.csv", 
                             col_types = cols(Phase_1_temp = col_factor(), 
                                              Phase_1_DO =col_factor(), 
                                              Phase_2.1_temp =col_factor(), 
                                              Phase_2.1_DO=col_factor(), 
                                              Phase_1_rep =col_factor(), 
                                              Phase_2_rep =col_factor(),
                                              Phase_1_treat = col_factor(),
                                              Phase_2_treat = col_factor(),
                                              Phase_2_rep_R = col_factor(),
                                              Phase_1_rep_R = col_factor(),
                                              double_single_dead_year2 = col_factor()))
# Out:
# [1] "/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC"
# New names:
# • `` -> `...1`

# %%
Year2_Growth_clean <- Year2_Growth %>%
  drop_na(Actual_tissue_growth_year2_mg) %>%
  filter(Exclude_year2 != "Y" | is.na(Exclude_year2)) %>%
  filter(!is.na(Phase_1_treat) & Phase_1_treat != "NA") %>%
  mutate(
    Actual_tissue_growth_year2_mg = as.numeric(Actual_tissue_growth_year2_mg),
    Actual_shell_growth_year2_mg = as.numeric(Actual_shell_growth_year2_mg),
    Ratio_TS_year2 = as.numeric(Ratio_TS_year2))

head(Year2_Growth_clean)
# Out:
#   ...1 Sample_Name            Phase_1_DO Phase_1_temp Phase_2.1_DO
# 1 2    2024_Both01_Both02_O14 Hyp        Warm         Hyp
# 2 3    2024_Both01_Both03_O26 Hyp        Warm         Hyp
# 3 4    2024_Both01_Both05_O49 Hyp        Warm         Hyp
# 4 5    2024_Both01_Both05_O50 Hyp        Warm         Hyp
# 5 6    2024_Both01_Both06_O61 Hyp        Warm         Hyp
# 6 8    2024_Both01_Cont02_O13 Hyp        Warm         Norm
#   Phase_2.1_temp Phase_1_treat Phase_2_treat Phase_1_rep_R Phase_2_rep_R ⋯
# 1 Warm           Both          Both          Both01        Both02        ⋯
# 2 Warm           Both          Both          Both01        Both03        ⋯
# 3 Warm           Both          Both          Both01        Both05        ⋯
# 4 Warm           Both          Both          Both01        Both05        ⋯
# 5 Warm           Both          Both          Both01        Both06        ⋯
# 6 Ambient        Both          Cont          Both01        Cont02        ⋯
#   Submerged_weight_year2 Dry_weight_year2 double_single_dead_year2 Notes_year2
# 1  517.1                 1309.3           NA                       NA
# 2  797.2                 1828.7           NA                       NA
# 3  726.4                 1811.5           NA                       NA
# 4  726.2                 1682.6           NA                       NA
# 5  346.2                  799.6           NA                       NA
# 6 1309.1                 3109.3           NA                       NA
#   Actual_shell_year2_mg Actual_tissue_year2_mg Actual_shell_growth_year2_mg
# 1  816.4478              492.8522              161.0318
# 2 1259.9582              568.7418              799.4587
# 3 1147.8535              663.6465              529.3306
# 4 1147.5368              535.0632              437.3351
# 5  545.8448              253.7552              254.6107
# 6 2070.5006             1038.7994              929.1391
#   Actual_tissue_growth_year2_mg Ratio_TS_year2 Exclude_year2
# 1 125.96822                     0.7822569      NA
# 2 368.54134                     0.4609886      NA
# 3 334.26938                     0.6314945      NA
# 4 181.36492                     0.4147047      NA
# 5  57.48928                     0.2257928      NA
# 6 566.36088                     0.6095544      NA

# %% [markdown]
# # 1. Tissue Growth

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#all, TISSUE
summary_stats_t <- Year2_Growth_clean %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(Actual_tissue_growth_year2_mg, na.rm = TRUE),
    se_growth = std.error(Actual_tissue_growth_year2_mg, na.rm = TRUE))

  #reorder Phase_1_treat and Phase_2_treat
  summary_stats_t$Phase_1_treat <- factor(summary_stats_t$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
  summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
  
  #plot with mean and SD, TISSUE
  ggplot(summary_stats_t, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
    geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
    geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                  width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
    theme_classic(base_size = 20) +
    guides(color = "none") + # Remove legend for color
    facet_wrap(vars(Phase_2_treat), 
               labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
               scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
    scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
    labs(x = "Phase 1 Treatment", y = "Year 2 Tissue Growth (mg)") +
    scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
    theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
##tissue growth (mg)
m1 <- lmer(Actual_tissue_growth_year2_mg~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Year2_Growth_clean, REML=TRUE)
aov_tab <- Anova(m1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res
# (Intercept)                                         125.97939863 1  19.498259
# Phase_1_DO                                            0.07811728 1   9.668258
# Phase_1_temp                                          0.60760628 1   9.691794
# Phase_2.1_temp                                        1.98004682 1  19.717533
# Phase_2.1_DO                                          2.80547777 1  19.719094
# Phase_1_DO:Phase_1_temp                               0.61110683 1   9.744911
# Phase_1_DO:Phase_2.1_temp                             0.11537460 1  18.765695
# Phase_1_temp:Phase_2.1_temp                           6.91763395 1  18.816840
# Phase_1_DO:Phase_2.1_DO                               0.01171423 1  18.779308
# Phase_1_temp:Phase_2.1_DO                             1.98230423 1  18.829101
# Phase_2.1_temp:Phase_2.1_DO                           0.18551450 1  19.718382
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp                1.51385733 1  18.796827
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                  0.22521022 1  18.812621
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO                0.36790033 1  18.780910
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO              4.67549497 1  18.832411
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO   0.21648475 1  18.812714
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.7858
# Phase_1_temp                                        0.4543
# Phase_2.1_temp                                      0.1750
# Phase_2.1_DO                                        0.1097
# Phase_1_DO:Phase_1_temp                             0.4529
# Phase_1_DO:Phase_2.1_temp                           0.7379
# Phase_1_temp:Phase_2.1_temp                         0.0166
# Phase_1_DO:Phase_2.1_DO                             0.9150
# Phase_1_temp:Phase_2.1_DO                           0.1754
# Phase_2.1_temp:Phase_2.1_DO                         0.6713
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.2337
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.6406
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.5514
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.0437
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.6471

# %%
#diagnostics
leveneTest(Actual_tissue_year2_mg~Phase_1_treat*Phase_2_treat, Year2_Growth_clean) 
m1.e <- residuals(m1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 1.646683 0.05867498
#       457       NA         NA
# Plot with title “Normal Q-Q Plot”

# %%
#posthocs
emmeans(m1,specs = pairwise ~ Phase_1_temp*Phase_2.1_temp, adjust = "none")
emmeans(m1,specs = pairwise ~ Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp Phase_2.1_temp emmean   SE   df lower.CL upper.CL
#  Warm         Warm              314 54.0 23.5      203      426
#  Ambient      Warm              403 54.0 23.4      292      515
#  Warm         Ambient           485 55.3 24.6      371      599
#  Ambient      Ambient           437 56.0 25.8      322      553
#
# Results are averaged over the levels of: Phase_1_DO, Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                       estimate   SE   df t.ratio p.value
#  Warm Warm - Ambient Warm          -88.8 35.9 14.8  -2.473  0.0260
#  Warm Warm - Warm Ambient         -171.0 77.2 24.3  -2.215  0.0364
#  Warm Warm - Ambient Ambient      -123.1 77.8 24.6  -1.583  0.1263
#  Ambient Warm - Warm Ambient       -82.2 77.3 24.0  -1.063  0.2982
#  Ambient Warm - Ambient Ambient    -34.3 77.7 24.9  -0.442  0.6623
#  Warm Ambient - Ambient Ambient     47.8 38.0 16.1   1.260  0.2255
#
# Results are averaged over the levels of: Phase_1_DO, Phase_2.1_DO
# Degrees-of-freedom method: kenward-roger
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp Phase_2.1_temp Phase_2.1_DO emmean   SE   df lower.CL upper.CL
#  Warm         Warm           Hyp             279 76.5 23.9      121      437
#  Ambient      Warm           Hyp             348 76.1 23.4      191      505
#  Warm         Ambient        Hyp             362 76.6 24.1      204      520
#  Ambient      Ambient        Hyp             407 77.6 25.2      247      567
#  Warm         Warm           Norm            350 76.2 23.6      193      507
#  Ambient      Warm           Norm            458 76.5 23.9      300      616
#  Warm         Ambient        Norm            608 79.7 25.5      444      773
#  Ambient      Ambient        Norm            468 80.7 26.7      302      634
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                   estimate    SE   df t.ratio p.value
#  Warm Warm Hyp - Ambient Warm Hyp             -69.18  50.6 17.2  -1.367  0.1891
#  Warm Warm Hyp - Warm Ambient Hyp             -83.33 108.0 24.0  -0.770  0.4486
#  Warm Warm Hyp - Ambient Ambient Hyp         -128.31 109.0 24.6  -1.178  0.2501
#  Warm Warm Hyp - Warm Warm Norm               -71.18 108.0 23.8  -0.660  0.5157
#  Warm Warm Hyp - Ambient Warm Norm           -179.58 108.0 23.9  -1.661  0.1098
#  Warm Warm Hyp - Warm Ambient Norm           -329.78 110.0 24.7  -2.987  0.0063
#  Warm Warm Hyp - Ambient Ambient Norm        -189.13 111.0 25.3  -1.701  0.1012
#  Ambient Warm Hyp - Warm Ambient Hyp          -14.15 108.0 23.8  -0.131  0.8968
#  Ambient Warm Hyp - Ambient Ambient Hyp       -59.13 109.0 24.4  -0.545  0.5910
#  Ambient Warm Hyp - Warm Warm Norm             -1.99 108.0 23.5  -0.019  0.9854
#  Ambient Warm Hyp - Ambient Warm Norm        -110.39 108.0 23.7  -1.024  0.3162
#  Ambient Warm Hyp - Warm Ambient Norm        -260.59 110.0 24.5  -2.365  0.0263
#  Ambient Warm Hyp - Ambient Ambient Norm     -119.95 111.0 25.1  -1.082  0.2896
#  Warm Ambient Hyp - Ambient Ambient Hyp       -44.98  52.7 19.6  -0.853  0.4040
#  Warm Ambient Hyp - Warm Warm Norm             12.16 108.0 23.9   0.113  0.9113
#  Warm Ambient Hyp - Ambient Warm Norm         -96.24 108.0 24.0  -0.889  0.3827
#  Warm Ambient Hyp - Warm Ambient Norm        -246.44 110.0 24.8  -2.230  0.0350
#  Warm Ambient Hyp - Ambient Ambient Norm     -105.80 111.0 25.4  -0.951  0.3507
#  Ambient Ambient Hyp - Warm Warm Norm          57.13 109.0 24.4   0.526  0.6040
#  Ambient Ambient Hyp - Ambient Warm Norm      -51.27 109.0 24.6  -0.471  0.6418
#  Ambient Ambient Hyp - Warm Ambient Norm     -201.47 111.0 25.4  -1.811  0.0820
#  Ambient Ambient Hyp - Ambient Ambient Norm   -60.82 112.0 26.0  -0.544  0.5914
#  Warm Warm Norm - Ambient Warm Norm          -108.40  50.7 17.6  -2.137  0.0469
#  Warm Warm Norm - Warm Ambient Norm          -258.60 110.0 24.6  -2.347  0.0273
#  Warm Warm Norm - Ambient Ambient Norm       -117.95 111.0 25.2  -1.063  0.2980
#  Ambient Warm Norm - Warm Ambient Norm       -150.20 110.0 24.7  -1.360  0.1862
#  Ambient Warm Norm - Ambient Ambient Norm      -9.55 111.0 25.4  -0.086  0.9322
#  Warm Ambient Norm - Ambient Ambient Norm     140.65  54.3 17.7   2.589  0.0187
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger

# %% [markdown]
# ### plotting significant interactions

# %%
 Warm Warm - Ambient Warm          -88.8 35.9 14.8  -2.473  0.0260
 Warm Warm - Warm Ambient         -171.0 77.2 24.3  -2.215  0.0364

# %%
#format display for jupyter
options(repr.plot.width = 8, repr.plot.height = 6)

summary_stats_t <- Year2_Growth_clean %>%
  filter(!is.na(Actual_tissue_growth_year2_mg)) %>%
  group_by(Phase_1_temp, Phase_2.1_temp) %>%
  mutate(
    mean_growth = mean(Actual_tissue_growth_year2_mg, na.rm = TRUE),
    se_growth = std.error(Actual_tissue_growth_year2_mg, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_temp <- factor(summary_stats_t$Phase_1_temp, 
                                        levels = c("Ambient", "Warm"))
summary_stats_t$Phase_2.1_temp <- factor(summary_stats_t$Phase_2.1_temp, 
                                        levels = c("Ambient", "Warm"))

ggplot(summary_stats_t, aes(x = Phase_1_temp, y = mean_growth, color = Phase_1_temp)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(vars(Phase_2.1_temp), 
             labeller = as_labeller(c("Warm" = "Warm", "Ambient" = "Ambient")), 
             scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
  scale_color_manual(values = c("Warm" = "#B00149", "Ambient" = "darkblue")) +
  labs(x = "Phase 1 Temperature", y = "Year 2 Tissue Growth (mg)") +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %% [markdown]
# ### Oysters grew less tissue when exposed to warming twice than once in either phase (p = 0.01)

# %% [markdown]
# More time exposed = more acclimated to those conditions AND/OR more certain about those environments after experiencing them twice.
#
#
# Then the environment for the next 9 months was control conditions, an environmental mismatch from the warm temperatures they experienced, and they performed much worse.

# %%
#format display for jupyter
options(repr.plot.width = 12, repr.plot.height = 6)

# plot Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO tissue  year 2 
summary_stats_t <- Year2_Growth_clean%>%
  group_by(Phase_1_temp, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(Actual_tissue_growth_year2_mg, na.rm = TRUE),
    se_growth = std.error(Actual_tissue_growth_year2_mg, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_t$Phase_1_temp <- factor(summary_stats_t$Phase_1_temp, 
                                       levels = c("Ambient", "Warm"))
summary_stats_t$Phase_2_treat <- factor(summary_stats_t$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp",  "Both"))

#plot with mean and SD
ggplot(summary_stats_t, aes(x = Phase_1_temp, y = mean_growth, color = Phase_1_temp)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 16) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(
    vars(Phase_2_treat),
    labeller = as_labeller(c(
      "Hyp" = "Hypoxic",
      "Cont" = "Control",
      "Warm" = "Warm",
      "Both" = "Both")), scales = "fixed", nrow = 1) +
  scale_color_manual(values = c("Warm" = "#B00149", "Ambient" = "darkblue")) +
  labs(x = "Phase 1 Temperature", y = "Year 2 Tissue Growth (mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#Warm control comparisons

#Warm Warm Hyp - Warm Ambient Norm           p =  0.0063
#    warm both - warm control

#Ambient Warm Hyp - Warm Ambient Norm        p = 0.0263
#    ambient both - warm control

#            Warm control grew more tissue than oysters in both phase 2

#Warm Ambient Hyp - Warm Ambient Norm        p = 0.0350
#    warm hyp - warm control

#Warm Warm Norm - Warm Ambient Norm          p = 0.0273
#    warm warm - warm control

#            oysters that experienced early life warming performed better 
#            after experiencing control phase 2 conditions than warm or hypoxic phase 2 conditions

#Warm Ambient Norm - Ambient Ambient Norm    p = 0.0187
#    warm control - ambient control

#            oysters that experienced early life warming grew more tissue in control conditions over the next year

# %%
#Warm Warm Norm - Ambient Warm Norm          p = 0.0469
#    warm warm - ambient warm

#            oysters grew less tissue when exposed to warming twice than once in either phase 

#Also \/ repeated from above supports this
#Warm Warm Norm - Warm Ambient Norm          p = 0.0273
#    warm warm - warm control

# %% [markdown]
# # 2. Shell Growth

# %%
m2 <- lmer(Actual_shell_growth_year2_mg~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Year2_Growth_clean, REML=TRUE)
Anova(m2, test="F", type="III")

# %%
#format for jupyter
options(repr.plot.width = 14, repr.plot.height = 6)

#all, TISSUE
summary_stats_s <- Year2_Growth_clean %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(Actual_shell_growth_year2_mg, na.rm = TRUE),
    se_growth = std.error(Actual_shell_growth_year2_mg, na.rm = TRUE))

  #reorder Phase_1_treat and Phase_2_treat
  summary_stats_s$Phase_1_treat <- factor(summary_stats_s$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
  summary_stats_s$Phase_2_treat <- factor(summary_stats_s$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
  
  #plot with mean and SD, TISSUE
  ggplot(summary_stats_s, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
    geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
    geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                  width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
    theme_classic(base_size = 20) +
    guides(color = "none") + # Remove legend for color
    facet_wrap(vars(Phase_2_treat), 
               labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
               scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
    scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
    labs(x = "Phase 1 Treatment", y = "Year 2 Shell Growth (mg)") +
    scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
    theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %% [markdown]
# ## statistical analysis

# %%
m2 <- lmer(log(Actual_shell_growth_year2_mg)~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Year2_Growth_clean, REML=TRUE)
aov_tab<-Anova(m2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                                                     F            Df Df.res
# (Intercept)                                         4.916910e+03 1  19.441325
# Phase_1_DO                                          8.749062e-03 1   9.658786
# Phase_1_temp                                        4.588245e-01 1  12.316596
# Phase_2.1_temp                                      2.748809e+00 1  19.690207
# Phase_2.1_DO                                        3.484354e+00 1  19.692298
# Phase_1_DO:Phase_1_temp                             1.463281e-01 1   9.712867
# Phase_1_DO:Phase_2.1_temp                           2.310815e-01 1  18.767845
# Phase_1_temp:Phase_2.1_temp                         2.227788e-01 1  18.983693
# Phase_1_DO:Phase_2.1_DO                             1.268691e-01 1  18.783494
# Phase_1_temp:Phase_2.1_DO                           9.479841e-01 1  18.994303
# Phase_2.1_temp:Phase_2.1_DO                         6.963481e-02 1  19.691411
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              3.561799e+00 1  18.774797
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                2.215459e-01 1  18.792241
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.091793e-01 1  18.785476
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            4.638679e+00 1  18.995437
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 5.024389e-01 1  18.792969
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.9274
# Phase_1_temp                                        0.5107
# Phase_2.1_temp                                      0.1132
# Phase_2.1_DO                                        0.0769
# Phase_1_DO:Phase_1_temp                             0.7103
# Phase_1_DO:Phase_2.1_temp                           0.6363
# Phase_1_temp:Phase_2.1_temp                         0.6423
# Phase_1_DO:Phase_2.1_DO                             0.7257
# Phase_1_temp:Phase_2.1_DO                           0.3425
# Phase_2.1_temp:Phase_2.1_DO                         0.7946
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.0747
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.6433
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.7447
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.0443
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.4871

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

#diagnostics
leveneTest(log(Actual_shell_growth_year2_mg)~Phase_1_treat*Phase_2_treat, Year2_Growth_clean) 
m1.e <- residuals(m2) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value  Pr(>F)
# group  15 1.395772 0.1446627
#       457       NA        NA
# Plot with title “Normal Q-Q Plot”

# %%
#posthocs
emmeans(m2,specs = pairwise ~ Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO, adjust = "none")

#could also do 
#emmeans(m2,specs = pairwise ~ Phase_2.1_DO, adjust = "none")
#emmeans(m2,specs = pairwise ~ Phase_2.1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp Phase_2.1_temp Phase_2.1_DO emmean    SE   df lower.CL upper.CL
#  Warm         Warm           Hyp            6.09 0.195 25.9     5.69     6.49
#  Ambient      Warm           Hyp            6.09 0.194 25.3     5.69     6.49
#  Warm         Ambient        Hyp            6.21 0.195 26.1     5.81     6.61
#  Ambient      Ambient        Hyp            6.47 0.198 27.4     6.07     6.88
#  Warm         Warm           Norm           6.29 0.194 25.5     5.89     6.69
#  Ambient      Warm           Norm           6.47 0.195 25.9     6.07     6.87
#  Warm         Ambient        Norm           6.84 0.204 27.5     6.43     7.26
#  Ambient      Ambient        Norm           6.62 0.207 28.9     6.19     7.04
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.
# Confidence level used: 0.95
#
# $contrasts
#  contrast                                   estimate    SE   df t.ratio p.value
#  Warm Warm Hyp - Ambient Warm Hyp            0.00186 0.152 17.9   0.012  0.9904
#  Warm Warm Hyp - Warm Ambient Hyp           -0.12254 0.276 26.0  -0.444  0.6607
#  Warm Warm Hyp - Ambient Ambient Hyp        -0.38241 0.278 26.6  -1.375  0.1806
#  Warm Warm Hyp - Warm Warm Norm             -0.19959 0.275 25.7  -0.725  0.4748
#  Warm Warm Hyp - Ambient Warm Norm          -0.38134 0.276 25.9  -1.382  0.1788
#  Warm Warm Hyp - Warm Ambient Norm          -0.75319 0.282 26.7  -2.671  0.0127
#  Warm Warm Hyp - Ambient Ambient Norm       -0.52642 0.284 27.4  -1.853  0.0747
#  Ambient Warm Hyp - Warm Ambient Hyp        -0.12440 0.275 25.7  -0.452  0.6553
#  Ambient Warm Hyp - Ambient Ambient Hyp     -0.38427 0.277 26.4  -1.387  0.1771
#  Ambient Warm Hyp - Warm Warm Norm          -0.20145 0.275 25.4  -0.734  0.4700
#  Ambient Warm Hyp - Ambient Warm Norm       -0.38320 0.275 25.6  -1.393  0.1755
#  Ambient Warm Hyp - Warm Ambient Norm       -0.75505 0.282 26.4  -2.682  0.0125
#  Ambient Warm Hyp - Ambient Ambient Norm    -0.52828 0.283 27.2  -1.865  0.0730
#  Warm Ambient Hyp - Ambient Ambient Hyp     -0.25987 0.157 19.9  -1.656  0.1134
#  Warm Ambient Hyp - Warm Warm Norm          -0.07705 0.275 25.8  -0.280  0.7818
#  Warm Ambient Hyp - Ambient Warm Norm       -0.25880 0.276 26.0  -0.937  0.3574
#  Warm Ambient Hyp - Warm Ambient Norm       -0.63066 0.282 26.8  -2.235  0.0340
#  Warm Ambient Hyp - Ambient Ambient Norm    -0.40388 0.284 27.5  -1.420  0.1668
#  Ambient Ambient Hyp - Warm Warm Norm        0.18282 0.278 26.5   0.659  0.5158
#  Ambient Ambient Hyp - Ambient Warm Norm     0.00107 0.278 26.7   0.004  0.9970
#  Ambient Ambient Hyp - Warm Ambient Norm    -0.37078 0.284 27.5  -1.304  0.2031
#  Ambient Ambient Hyp - Ambient Ambient Norm -0.14401 0.286 28.2  -0.503  0.6185
#  Warm Warm Norm - Ambient Warm Norm         -0.18175 0.152 18.2  -1.195  0.2473
#  Warm Warm Norm - Warm Ambient Norm         -0.55360 0.281 26.6  -1.967  0.0597
#  Warm Warm Norm - Ambient Ambient Norm      -0.32683 0.284 27.2  -1.152  0.2592
#  Ambient Warm Norm - Warm Ambient Norm      -0.37186 0.282 26.7  -1.318  0.1988
#  Ambient Warm Norm - Ambient Ambient Norm   -0.14508 0.284 27.4  -0.511  0.6134
#  Warm Ambient Norm - Ambient Ambient Norm    0.22677 0.163 18.4   1.391  0.1807
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.

# %% [markdown]
# ## plotting significant interactions

# %%
#format for jupyter
options(repr.plot.width = 12, repr.plot.height = 6)

# plot Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO shell  year 2 
summary_stats_s <- Year2_Growth_clean%>%
  group_by(Phase_1_temp, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(Actual_shell_growth_year2_mg, na.rm = TRUE),
    se_growth = std.error(Actual_shell_growth_year2_mg, na.rm = TRUE))

#reorder Phase_1_treat and Phase_2_treat
summary_stats_s$Phase_1_temp <- factor(summary_stats_s$Phase_1_temp, 
                                       levels = c("Ambient", "Warm"))
summary_stats_s$Phase_2_treat <- factor(summary_stats_s$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp",  "Both"))

#plot with mean and SD
ggplot(summary_stats_s, aes(x = Phase_1_temp, y = mean_growth, color = Phase_1_temp)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 16) +
  guides(color = "none") + # Remove legend for color
  facet_wrap(
    vars(Phase_2_treat),
    labeller = as_labeller(c(
      "Hyp" = "Hypoxic",
      "Cont" = "Control",
      "Warm" = "Warm",
      "Both" = "Both")), scales = "fixed", nrow = 1) +
  scale_color_manual(values = c("Warm" = "#B00149", "Ambient" = "darkblue")) +
  labs(x = "Phase 1 Temperature", y = "Year 2 Shell Growth (mg)") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
#Warm Warm Hyp - Warm Ambient Norm          p = 0.0127
#    warm both - warm control
#Ambient Warm Hyp - Warm Ambient Norm       p = 0.0125
#    ambient both - warm control
            
#            oysters exposed to early life warming and then control conditions 
#            grew more than oysters that experienced both stressors in phase 2

#Warm Ambient Hyp - Warm Ambient Norm       p = 0.0340
#    warm hyp - warm control
#            oysters exposed to early life warming grew more after experiencing phase 2 control conditions than phase 2 hypoxia

#and maaayyyybeeee
# Warm Warm Norm - Warm Ambient Norm         p = 0.0597
#    warm warm - warm control
#        oysters exposed to early life warming grew less after being exposed to warming again

# %% [markdown]
# # 3. Tissue:Shell Growth

# %% [markdown]
# ### Below is all experimental, found no significant results from normal analysis

# %%
low_TS <- Year2_Growth_clean%>%
filter(Ratio_TS_year2 < 7)

# %%
#format for :
options(repr.plot.width = 14, repr.plot.height = 6)

#all, TISSUE:SHELL
summary_stats_s <- low_TS %>%
  group_by(Phase_1_treat, Phase_2_treat) %>%
  mutate(
    mean_growth = mean(Ratio_TS_year2, na.rm = TRUE),
    se_growth = std.error(Ratio_TS_year2, na.rm = TRUE))

  #reorder Phase_1_treat and Phase_2_treat
  summary_stats_s$Phase_1_treat <- factor(summary_stats_s$Phase_1_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
  summary_stats_s$Phase_2_treat <- factor(summary_stats_s$Phase_2_treat, 
                                        levels = c("Cont", "Warm","Hyp", "Both"))
  
  #plot with mean and SD, TISSUE:SHELL
  ggplot(summary_stats_s, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
    geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
    geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                  width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
geom_jitter(data = low_TS,
              aes(x = Phase_1_treat, y = Ratio_TS_year2, color = Phase_1_treat),
              width = 0.1, alpha = 0.5, size = 2) +
    theme_classic(base_size = 20) +
    guides(color = "none") + # Remove legend for color
    facet_wrap(vars(Phase_2_treat), 
               labeller = as_labeller(c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")), 
               scales = "fixed", nrow = 1) + # Facet by Phase_2_treat
    scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
    labs(x = "Phase 1 Treatment", y = "Year 2 Tissue:Shell Growth (mg)") +
    scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
    theme(legend.position = "none") # Remove legend
# Out:
# plot without title

# %%
# need to find  and address this weird point for hypoxic both
    #2024_Hyp06_Both05_B59 has a Tissue:Shell of 7.32

# %%
max(Year2_Growth_clean$Ratio_TS_year2)
# Out:
# [1] 7.320282

# %%
#2024_Hyp06_Both05_B59, no notes attached to this one
#can I exclude it just because its an outlier?

# %% [markdown]
# ## statistical analysis

# %%
#THIS HAS FILTERED DATASET AS DATASET
m3 <- lmer(Ratio_TS_year2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = low_TS, REML=TRUE)

#m4 <- lmer(Ratio_TS_year2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+Actual_shell_pre_mg+
#             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
#             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Year2_Growth_clean, REML=TRUE)

#THIS HAS FILTERED DATASET AS DATASET
m5 <- lmer(Ratio_TS_year2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+Actual_tissue_pre_mg+
             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = low_TS, REML=TRUE)

#m5 is the best covariate

#m6 <- lmer(Ratio_TS_year2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+Actual_shell_post_mg+
#             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
#             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Year2_Growth_clean, REML=TRUE)

#m7 <- lmer(Ratio_TS_year2~ Phase_1_DO*Phase_1_temp*Phase_2.1_temp*Phase_2.1_DO+Actual_tissue_post_mg+
#             (1|Phase_2_rep_R)+(1|Phase_1_rep_R)+
#             (1|Phase_2_rep_R:Phase_1_DO)+(1|Phase_2_rep_R:Phase_1_temp)+(1|Phase_2_rep_R:Phase_1_DO:Phase_1_temp), data = Year2_Growth_clean, REML=TRUE)

# AIC(m3, m4, m5, m6, m7)
# Out:
# boundary (singular) fit: see help('isSingular')
#
# boundary (singular) fit: see help('isSingular')

# %%
aov_tab<-Anova(m3, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                                                     F            Df Df.res
# (Intercept)                                         1.241916e+03 1  17.75861
# Phase_1_DO                                          8.633612e-01 1  10.07705
# Phase_1_temp                                        6.286333e-01 1  12.82096
# Phase_2.1_temp                                      3.348863e-01 1  19.33339
# Phase_2.1_DO                                        5.544912e-01 1  19.34389
# Phase_1_DO:Phase_1_temp                             2.938488e+00 1  10.11219
# Phase_1_DO:Phase_2.1_temp                           2.068597e+00 1  18.73459
# Phase_1_temp:Phase_2.1_temp                         1.228546e-02 1  18.95862
# Phase_1_DO:Phase_2.1_DO                             6.002898e-01 1  18.75911
# Phase_1_temp:Phase_2.1_DO                           2.308271e-01 1  18.97646
# Phase_2.1_temp:Phase_2.1_DO                         2.105408e+00 1  19.34162
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              1.018047e+00 1  18.75715
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                3.423427e+00 1  18.78312
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.281952e+00 1  18.76516
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            2.907441e-01 1  18.97990
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 1.523665e-01 1  18.78796
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.3745
# Phase_1_temp                                        0.4423
# Phase_2.1_temp                                      0.5695
# Phase_2.1_DO                                        0.4654
# Phase_1_DO:Phase_1_temp                             0.1169
# Phase_1_DO:Phase_2.1_temp                           0.1669
# Phase_1_temp:Phase_2.1_temp                         0.9129
# Phase_1_DO:Phase_2.1_DO                             0.4481
# Phase_1_temp:Phase_2.1_DO                           0.6364
# Phase_2.1_temp:Phase_2.1_DO                         0.1628
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.3258
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.0801
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.2718
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.5960
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.7007

# %%
#posthocs
emmeans(m3,specs = pairwise ~ Phase_1_DO*Phase_1_temp*Phase_2.1_DO, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO Phase_1_temp Phase_2.1_DO emmean     SE   df lower.CL upper.CL
#  Hyp        Warm         Hyp           0.503 0.0304 44.9    0.441    0.564
#  Norm       Warm         Hyp           0.504 0.0309 47.1    0.442    0.567
#  Hyp        Ambient      Hyp           0.527 0.0314 48.5    0.464    0.591
#  Norm       Ambient      Hyp           0.532 0.0307 45.3    0.470    0.594
#  Hyp        Warm         Norm          0.488 0.0307 41.8    0.426    0.550
#  Norm       Warm         Norm          0.582 0.0316 48.1    0.519    0.646
#  Hyp        Ambient      Norm          0.559 0.0309 44.4    0.496    0.621
#  Norm       Ambient      Norm          0.525 0.0329 53.3    0.460    0.591
#
# Results are averaged over the levels of: Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast                             estimate     SE   df t.ratio p.value
#  Hyp Warm Hyp - Norm Warm Hyp         -0.00180 0.0351 25.9  -0.051  0.9596
#  Hyp Warm Hyp - Hyp Ambient Hyp       -0.02478 0.0382 28.3  -0.648  0.5220
#  Hyp Warm Hyp - Norm Ambient Hyp      -0.02944 0.0376 27.1  -0.783  0.4404
#  Hyp Warm Hyp - Hyp Warm Norm          0.01431 0.0427 56.0   0.335  0.7388
#  Hyp Warm Hyp - Norm Warm Norm        -0.07970 0.0438 46.5  -1.819  0.0754
#  Hyp Warm Hyp - Hyp Ambient Norm      -0.05600 0.0433 44.6  -1.293  0.2027
#  Hyp Warm Hyp - Norm Ambient Norm     -0.02284 0.0448 49.1  -0.510  0.6122
#  Norm Warm Hyp - Hyp Ambient Hyp      -0.02298 0.0386 29.2  -0.595  0.5566
#  Norm Warm Hyp - Norm Ambient Hyp     -0.02765 0.0381 28.3  -0.726  0.4736
#  Norm Warm Hyp - Hyp Warm Norm         0.01611 0.0436 44.4   0.370  0.7134
#  Norm Warm Hyp - Norm Warm Norm       -0.07791 0.0437 62.9  -1.781  0.0797
#  Norm Warm Hyp - Hyp Ambient Norm     -0.05420 0.0437 45.7  -1.241  0.2211
#  Norm Warm Hyp - Norm Ambient Norm    -0.02104 0.0451 50.2  -0.466  0.6430
#  Hyp Ambient Hyp - Norm Ambient Hyp   -0.00466 0.0357 26.2  -0.131  0.8971
#  Hyp Ambient Hyp - Hyp Warm Norm       0.03909 0.0439 45.1   0.890  0.3784
#  Hyp Ambient Hyp - Norm Warm Norm     -0.05492 0.0446 48.3  -1.233  0.2237
#  Hyp Ambient Hyp - Hyp Ambient Norm   -0.03122 0.0436 61.3  -0.716  0.4766
#  Hyp Ambient Hyp - Norm Ambient Norm   0.00194 0.0455 50.9   0.043  0.9661
#  Norm Ambient Hyp - Hyp Warm Norm      0.04375 0.0434 43.5   1.008  0.3188
#  Norm Ambient Hyp - Norm Warm Norm    -0.05026 0.0440 46.7  -1.142  0.2593
#  Norm Ambient Hyp - Hyp Ambient Norm  -0.02656 0.0435 44.8  -0.610  0.5447
#  Norm Ambient Hyp - Norm Ambient Norm  0.00661 0.0445 64.6   0.148  0.8826
#  Hyp Warm Norm - Norm Warm Norm       -0.09401 0.0353 23.9  -2.665  0.0136
#  Hyp Warm Norm - Hyp Ambient Norm     -0.07031 0.0376 24.9  -1.870  0.0733
#  Hyp Warm Norm - Norm Ambient Norm    -0.03715 0.0391 28.1  -0.949  0.3508
#  Norm Warm Norm - Hyp Ambient Norm     0.02370 0.0384 27.5   0.617  0.5422
#  Norm Warm Norm - Norm Ambient Norm    0.05686 0.0400 31.3   1.423  0.1647
#  Hyp Ambient Norm - Norm Ambient Norm  0.03316 0.0366 27.6   0.906  0.3728
#
# Results are averaged over the levels of: Phase_2.1_temp
# Degrees-of-freedom method: kenward-roger

# %%
aov_tab<-Anova(m4, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                                                     F            Df Df.res
# (Intercept)                                         1.761367e+02 1   90.39213
# Phase_1_DO                                          8.467446e-02 1   13.33746
# Phase_1_temp                                        1.203651e+00 1   13.33936
# Phase_2.1_temp                                      1.058446e+00 1   18.76468
# Phase_2.1_DO                                        1.117008e-02 1   18.79977
# Actual_shell_pre_mg                                 7.700140e-02 1  361.62843
# Phase_1_DO:Phase_1_temp                             2.038839e+00 1   13.29428
# Phase_1_DO:Phase_2.1_temp                           2.384727e-03 1   18.82103
# Phase_1_temp:Phase_2.1_temp                         4.076342e-01 1   19.09178
# Phase_1_DO:Phase_2.1_DO                             1.196172e+00 1   18.88256
# Phase_1_temp:Phase_2.1_DO                           9.967772e-01 1   19.04947
# Phase_2.1_temp:Phase_2.1_DO                         3.013051e+00 1   18.87847
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              8.227284e-02 1   18.88972
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.625550e-02 1   18.92118
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.524770e+00 1   18.94537
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.054008e+00 1   19.27710
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 7.787859e-01 1   19.06013
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.7755
# Phase_1_temp                                        0.2920
# Phase_2.1_temp                                      0.3166
# Phase_2.1_DO                                        0.9169
# Actual_shell_pre_mg                                 0.7816
# Phase_1_DO:Phase_1_temp                             0.1764
# Phase_1_DO:Phase_2.1_temp                           0.9616
# Phase_1_temp:Phase_2.1_temp                         0.5308
# Phase_1_DO:Phase_2.1_DO                             0.2878
# Phase_1_temp:Phase_2.1_DO                           0.3306
# Phase_2.1_temp:Phase_2.1_DO                         0.0989
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.7774
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.8999
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.2320
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.3173
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.3885

# %%
aov_tab<-Anova(m5, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                                                     F            Df Df.res
# (Intercept)                                         478.14989799 1   71.36206
# Phase_1_DO                                            0.54926116 1   10.04989
# Phase_1_temp                                          0.62481698 1   12.06880
# Phase_2.1_temp                                        0.35367891 1   19.02680
# Phase_2.1_DO                                          0.67541113 1   19.03963
# Actual_tissue_pre_mg                                  8.39624198 1  376.74684
# Phase_1_DO:Phase_1_temp                               3.15343563 1   10.03568
# Phase_1_DO:Phase_2.1_temp                             2.32715080 1   18.63058
# Phase_1_temp:Phase_2.1_temp                           0.08734098 1   18.94560
# Phase_1_DO:Phase_2.1_DO                               0.45093365 1   18.66780
# Phase_1_temp:Phase_2.1_DO                             0.10221080 1   19.03261
# Phase_2.1_temp:Phase_2.1_DO                           2.93648970 1   19.07784
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp                1.05763357 1   18.68426
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                  3.22758347 1   18.73944
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO                0.78242173 1   18.84622
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO              0.58594659 1   19.07581
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO   0.02317870 1   18.92269
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.4756
# Phase_1_temp                                        0.4445
# Phase_2.1_temp                                      0.5590
# Phase_2.1_DO                                        0.4213
# Actual_tissue_pre_mg                                0.0040
# Phase_1_DO:Phase_1_temp                             0.1060
# Phase_1_DO:Phase_2.1_temp                           0.1439
# Phase_1_temp:Phase_2.1_temp                         0.7708
# Phase_1_DO:Phase_2.1_DO                             0.5101
# Phase_1_temp:Phase_2.1_DO                           0.7527
# Phase_2.1_temp:Phase_2.1_DO                         0.1028
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.3169
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.0885
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.3875
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.4534
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.8806

# %%
aov_tab<-Anova(m6, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                                                     F            Df Df.res
# (Intercept)                                         1.434592e+02 1   97.03730
# Phase_1_DO                                          1.191296e-01 1   13.73971
# Phase_1_temp                                        1.189050e+00 1   13.53471
# Phase_2.1_temp                                      1.087018e+00 1   18.67064
# Phase_2.1_DO                                        4.379796e-02 1   19.15616
# Actual_shell_post_mg                                7.980121e-01 1  313.29456
# Phase_1_DO:Phase_1_temp                             2.028057e+00 1   13.56922
# Phase_1_DO:Phase_2.1_temp                           3.658445e-03 1   18.82505
# Phase_1_temp:Phase_2.1_temp                         3.306779e-01 1   19.12647
# Phase_1_DO:Phase_2.1_DO                             1.144307e+00 1   18.88634
# Phase_1_temp:Phase_2.1_DO                           8.939248e-01 1   19.10809
# Phase_2.1_temp:Phase_2.1_DO                         3.164512e+00 1   18.73695
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              9.119970e-02 1   18.87301
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.295988e-02 1   18.90709
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.393618e+00 1   19.01335
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.202020e+00 1   19.31494
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 6.822059e-01 1   19.10960
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.7352
# Phase_1_temp                                        0.2946
# Phase_2.1_temp                                      0.3104
# Phase_2.1_DO                                        0.8364
# Actual_shell_post_mg                                0.3724
# Phase_1_DO:Phase_1_temp                             0.1770
# Phase_1_DO:Phase_2.1_temp                           0.9524
# Phase_1_temp:Phase_2.1_temp                         0.5720
# Phase_1_DO:Phase_2.1_DO                             0.2982
# Phase_1_temp:Phase_2.1_DO                           0.3562
# Phase_2.1_temp:Phase_2.1_DO                         0.0915
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.7660
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.9106
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.2524
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.2864
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.4190

# %%
#format for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

leveneTest(Ratio_TS_year2~Phase_1_treat*Phase_2_treat, Year2_Growth_clean) 
m1.e <- residuals(m5) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df  F value   Pr(>F)
# group  15 0.8481645 0.6234428
#       457        NA        NA
# Plot with title “Normal Q-Q Plot”

# %%
aov_tab<-Anova(m6, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                                                     F            Df Df.res
# (Intercept)                                         1.434592e+02 1   97.03730
# Phase_1_DO                                          1.191296e-01 1   13.73971
# Phase_1_temp                                        1.189050e+00 1   13.53471
# Phase_2.1_temp                                      1.087018e+00 1   18.67064
# Phase_2.1_DO                                        4.379796e-02 1   19.15616
# Actual_shell_post_mg                                7.980121e-01 1  313.29456
# Phase_1_DO:Phase_1_temp                             2.028057e+00 1   13.56922
# Phase_1_DO:Phase_2.1_temp                           3.658445e-03 1   18.82505
# Phase_1_temp:Phase_2.1_temp                         3.306779e-01 1   19.12647
# Phase_1_DO:Phase_2.1_DO                             1.144307e+00 1   18.88634
# Phase_1_temp:Phase_2.1_DO                           8.939248e-01 1   19.10809
# Phase_2.1_temp:Phase_2.1_DO                         3.164512e+00 1   18.73695
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              9.119970e-02 1   18.87301
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.295988e-02 1   18.90709
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.393618e+00 1   19.01335
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.202020e+00 1   19.31494
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 6.822059e-01 1   19.10960
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.7352
# Phase_1_temp                                        0.2946
# Phase_2.1_temp                                      0.3104
# Phase_2.1_DO                                        0.8364
# Actual_shell_post_mg                                0.3724
# Phase_1_DO:Phase_1_temp                             0.1770
# Phase_1_DO:Phase_2.1_temp                           0.9524
# Phase_1_temp:Phase_2.1_temp                         0.5720
# Phase_1_DO:Phase_2.1_DO                             0.2982
# Phase_1_temp:Phase_2.1_DO                           0.3562
# Phase_2.1_temp:Phase_2.1_DO                         0.0915
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.7660
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.9106
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.2524
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.2864
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.4190

# %%
aov_tab<-Anova(m7, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                                                     F            Df Df.res
# (Intercept)                                         1.605838e+02 1   92.60608
# Phase_1_DO                                          9.819837e-02 1   13.56466
# Phase_1_temp                                        1.105493e+00 1   13.65720
# Phase_2.1_temp                                      1.038839e+00 1   18.75253
# Phase_2.1_DO                                        3.332730e-02 1   18.97137
# Actual_tissue_post_mg                               1.139966e+00 1  368.78025
# Phase_1_DO:Phase_1_temp                             2.001313e+00 1   13.47445
# Phase_1_DO:Phase_2.1_temp                           1.214735e-03 1   18.81727
# Phase_1_temp:Phase_2.1_temp                         3.739250e-01 1   18.91838
# Phase_1_DO:Phase_2.1_DO                             1.129373e+00 1   18.87731
# Phase_1_temp:Phase_2.1_DO                           8.750022e-01 1   19.09136
# Phase_2.1_temp:Phase_2.1_DO                         3.143562e+00 1   18.78516
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              7.555940e-02 1   18.84308
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                1.340842e-02 1   18.88742
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              1.352903e+00 1   19.01786
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            1.127526e+00 1   19.03764
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 6.710983e-01 1   19.06851
#                                                     Pr(>F)
# (Intercept)                                         0.0000
# Phase_1_DO                                          0.7588
# Phase_1_temp                                        0.3113
# Phase_2.1_temp                                      0.3211
# Phase_2.1_DO                                        0.8571
# Actual_tissue_post_mg                               0.2864
# Phase_1_DO:Phase_1_temp                             0.1799
# Phase_1_DO:Phase_2.1_temp                           0.9726
# Phase_1_temp:Phase_2.1_temp                         0.5482
# Phase_1_DO:Phase_2.1_DO                             0.3013
# Phase_1_temp:Phase_2.1_DO                           0.3613
# Phase_2.1_temp:Phase_2.1_DO                         0.0924
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp              0.7864
# Phase_1_DO:Phase_1_temp:Phase_2.1_DO                0.9090
# Phase_1_DO:Phase_2.1_temp:Phase_2.1_DO              0.2592
# Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO            0.3016
# Phase_1_DO:Phase_1_temp:Phase_2.1_temp:Phase_2.1_DO 0.4228
