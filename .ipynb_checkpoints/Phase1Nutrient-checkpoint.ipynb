# %% [markdown]
# # Phase 1 Nutrient Analysis

# %% [markdown]
# ### load packages, read in data, etc.

# %%
#load packages
library(lme4) #for linear mixed effects model
library(readr) #to read in data
library(tidyr)
library(emmeans) #for post hocs
library(esquisse) #interface for building plots
library(dplyr) #for data wrangling
library(nlme) #for linear mixed effects model
library(car) #for the Levene test
library(ggplot2) #for graphs
library(plotrix) #for standard error
library(performance) #model testing
library(lmtest) #another option than levene test for variance
# Out:
# Loading required package: Matrix
#
#
# Attaching package: ‘tidyr’
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, pack, unpack
#
#
# Warning message:
# “package ‘emmeans’ was built under R version 4.4.3”
# Welcome to emmeans.
# Caution: You lose important information if you filter this package's results.
# See '? untidy'
#
# Warning message:
# “package ‘dplyr’ was built under R version 4.4.3”
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘nlme’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     collapse
#
#
# The following object is masked from ‘package:lme4’:
#
#     lmList
#
#
# Loading required package: carData
#
#
# Attaching package: ‘car’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     recode
#
#
# Warning message:
# “package ‘ggplot2’ was built under R version 4.4.3”
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
#set contrasts
options(contrasts = c("contr.sum","contr.poly")) #could also be contr.treatment for unequal groups sum
getOption("contrasts")
# Out:
# [1] "contr.sum"  "contr.poly"

# %%
#Read in dataset, set column types
getwd()
setwd("/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC/Oyster_Nutrient_Data/Phase1_Nutrient")
# Out:
# [1] "/Users/sophiemontague/Desktop/MontagueORCC_repo/MontagueORCC"

# %%
#read in % data
Tissue_Nutrient_df <- read_csv("Phase1_tissuenutrient_working.csv", 
                        col_types = cols(wt_percent_N = col_number(), 
                                         wt_percent_C = col_number()))
Shell_Nutrient_df <-read_csv("Phase1_shellnutrient_working.csv", 
                        col_types = cols(wt_percent_N = col_number(), 
                                         wt_percent_C = col_number()))

# %%
#filter out data points (errors/replicates)
#tissue
N_T_df <- Tissue_Nutrient_df%>%
  filter(N_exclude != "Y" | is.na(N_exclude))

C_T_df <- Tissue_Nutrient_df%>%
  filter(C_exclude != "Y" | is.na(C_exclude))

#shell
N_S_df <- Shell_Nutrient_df%>%
  filter(N_exclude != "Y" | is.na(N_exclude))

C_S_df <- Shell_Nutrient_df%>%
  filter(C_exclude != "Y" | is.na(C_exclude))

# %% [markdown]
# ## % Nitrogen in Tissue

# %%
#summary stats
summary_stats <- N_T_df %>%
  group_by(Phase_1_treat) %>%
  summarize(
    mean_growth = mean(wt_percent_N, na.rm = TRUE),
    se_growth = std.error(wt_percent_N, na.rm = TRUE))
#reorder Phase_1_treat
summary_stats$Phase_1_treat <- factor(summary_stats$Phase_1_treat, 
                                      levels = c("Cont", "Warm","Hyp", "Both"))
#plot
ggplot(summary_stats, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "% N in Tissue") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  ylim(4,10)+
  theme(legend.position = "none") # Remove legend
#plot with raw data
ggplot(summary_stats, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_jitter(data = N_T_df,
              aes(x = Phase_1_treat, y = wt_percent_N, color = Phase_1_treat),
              width = 0.1, alpha = 0.5, size = 2) +
  geom_point(size = 4, position = position_dodge(0.9)) +
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.1, position = position_dodge(0.9)) +
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) +
  guides(color = "none") +
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred",
                                "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "% N in Tissue") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control",
                              "Warm" = "Warm", "Both" = "Both")) +
  ylim(4, 10) +
  theme(legend.position = "none")
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### Analysis

# %%
Nm1 <- lmer(wt_percent_N ~ Phase_1_DO*Phase_1_temp + 
              (1|Phase_1_rep_R), data = N_T_df, REML=TRUE)

aov_tab <- Anova(Nm1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                         F            Df Df.res   Pr(>F)
# (Intercept)             1926.3720992 1  19.57171 0.0000
# Phase_1_DO                 0.3595182 1  19.57171 0.5557
# Phase_1_temp               1.7435381 1  19.57171 0.2019
# Phase_1_DO:Phase_1_temp    1.0634180 1  19.57171 0.3150

# %% [markdown]
# #### No significant interactions

# %%
#diagnostics
leveneTest(wt_percent_N~Phase_1_DO*Phase_1_temp, N_T_df)
m1.e <- residuals(Nm1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df F value   Pr(>F)
# group  3 0.3181501 0.8121661
#       40        NA        NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## Carbon in Tissue

# %%
#summary stats
summary_stats <- C_T_df %>%
  group_by(Phase_1_treat) %>%
  summarize(
    mean_growth = mean(wt_percent_C, na.rm = TRUE),
    se_growth = std.error(wt_percent_C, na.rm = TRUE))

#reorder Phase_1_treat
summary_stats$Phase_1_treat <- factor(summary_stats$Phase_1_treat, 
                                      levels = c("Cont", "Warm","Hyp", "Both"))
#plot
ggplot(summary_stats, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.2, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 20) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light grey
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred", "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "% C in Tissue") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control", "Warm" = "Warm", "Both" = "Both")) +
  ylim(34,42)+
  theme(legend.position = "none") # Remove legend
#plot with raw data
ggplot(summary_stats, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_jitter(data = C_T_df,
              aes(x = Phase_1_treat, y = wt_percent_C, color = Phase_1_treat),
              width = 0.1, alpha = 0.5, size = 2) +
  geom_point(size = 4, position = position_dodge(0.9)) +
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.1, position = position_dodge(0.9)) +
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) +
  guides(color = "none") +
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred",
                                "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "% C in Tissue") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control",
                              "Warm" = "Warm", "Both" = "Both")) +
ylim(25, 50)+
  theme(legend.position = "none")
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### Analysis

# %%
Cm1 <- lmer(log(wt_percent_C) ~ Phase_1_DO*Phase_1_temp +
              (1|Phase_1_rep_R), data = C_T_df, REML=TRUE)
aov_tab <-Anova(Cm1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                         F            Df Df.res   Pr(>F)
# (Intercept)             3.519110e+04 1  19.72065 0.0000
# Phase_1_DO              3.615743e-04 1  19.72065 0.9850
# Phase_1_temp            7.808316e-01 1  19.72065 0.3875
# Phase_1_DO:Phase_1_temp 5.671695e-01 1  19.72065 0.4603

# %% [markdown]
# #### No significant interactions

# %%
#diagnostics
leveneTest(log(wt_percent_C)~Phase_1_DO*Phase_1_temp, C_T_df)
m1.e <- residuals(Cm1) 
qqnorm(m1.e)
qqline(m1.e)
# Out:
#       Df F value  Pr(>F)
# group  3 1.031584 0.388394
#       42       NA       NA
# Plot with title “Normal Q-Q Plot”

# %% [markdown]
# ## Carbon:Nitrogen in Tissue

# %%
#read in data
Tissue_Nutrient_df <- read_csv("Phase1_tissuenutrient_working.csv", 
                               col_types = cols(wt_percent_N = col_number(), 
                                                wt_percent_C = col_number()))

#filter out exclusions for N and C
CN_T_df <- Tissue_Nutrient_df %>%
  filter( (is.na(N_exclude) | N_exclude != "Y") &
            (is.na(C_exclude) | C_exclude != "Y") )

# %%
#summary stats
summary_stats <- CN_T_df %>%
  group_by(Phase_1_treat) %>%
  summarize(
    mean_growth = mean((wt_percent_C/wt_percent_N), na.rm = TRUE),
    se_growth = std.error((wt_percent_C/wt_percent_N), na.rm = TRUE))
#reorder Phase_1_treat
summary_stats$Phase_1_treat <- factor(summary_stats$Phase_1_treat, 
                                      levels = c("Cont", "Warm","Hyp", "Both"))
#plot
ggplot(summary_stats, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) +
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.1, position = position_dodge(0.9)) +
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) +
  guides(color = "none") +
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred",
                                "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Tissue") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control",
                              "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none")

#plot with raw data
ggplot(summary_stats, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_point(size = 4, position = position_dodge(0.9)) +
  geom_jitter(data = CN_T_df,
              aes(x = Phase_1_treat, y = (wt_percent_C/wt_percent_N), color = Phase_1_treat),
              width = 0.1, alpha = 0.5, size = 2) +
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.1, position = position_dodge(0.9)) +
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) +
  guides(color = "none") +
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred",
                                "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "C:N in Tissue") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control",
                              "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none")
# Out:
# plot without title
# plot without title

# %%
## C:N 
CNm1 <- lmer(log(wt_percent_C/wt_percent_N) ~ Phase_1_DO*Phase_1_temp + 
              (1|Phase_1_rep_R), data = CN_T_df, REML=TRUE)
aov_tab <- Anova(CNm1, test="F", type="III")
        #log transformed model is preferred as compared by AIC

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                         F            Df Df.res   Pr(>F)
# (Intercept)             3.443808e+04 1  19.57171 0.0000
# Phase_1_DO              3.220187e+00 1  19.57171 0.0882
# Phase_1_temp            1.621440e+00 1  19.57171 0.2178
# Phase_1_DO:Phase_1_temp 6.350939e-01 1  19.57171 0.4351

# %%
#not running many interactions and also runs with bonferroni adjustment
emmeans(CNm1,specs = pairwise ~ Phase_1_DO, adjust = "none")
emmeans(CNm1,specs = pairwise ~ Phase_1_DO, adjust = "bonferroni")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO emmean     SE   df lower.CL upper.CL
#  Hypoxic      1.65 0.0131 21.8     1.62     1.67
#  Normoxic     1.61 0.0117 17.2     1.59     1.64
#
# Results are averaged over the levels of: Phase_1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.
# Confidence level used: 0.95
#
# $contrasts
#  contrast           estimate     SE   df t.ratio p.value
#  Hypoxic - Normoxic   0.0315 0.0176 19.6   1.794  0.0882
#
# Results are averaged over the levels of: Phase_1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_DO emmean     SE   df lower.CL upper.CL
#  Hypoxic      1.65 0.0131 21.8     1.62     1.67
#  Normoxic     1.61 0.0117 17.2     1.59     1.64
#
# Results are averaged over the levels of: Phase_1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.
# Confidence level used: 0.95
#
# $contrasts
#  contrast           estimate     SE   df t.ratio p.value
#  Hypoxic - Normoxic   0.0315 0.0176 19.6   1.794  0.0882
#
# Results are averaged over the levels of: Phase_1_temp
# Degrees-of-freedom method: kenward-roger
# Results are given on the log (not the response) scale.

# %% [markdown]
# ### Plotting significant factor

# %%
#summary stats
summary_stats <- CN_T_df %>%
  group_by(Phase_1_DO) %>%
  mutate(
    mean_cn = mean((wt_percent_C/wt_percent_N), na.rm = TRUE),
    se_cn = std.error((wt_percent_C/wt_percent_N), na.rm = TRUE))
#reorder
summary_stats$Phase_1_DO <- factor(summary_stats$Phase_1_DO, levels = c("Normoxic", "Hypoxic"))
#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_1_DO, y = mean_cn, color = Phase_1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
  geom_errorbar(aes(ymin = mean_cn - se_cn, ymax = mean_cn + se_cn), 
                width = 0.05, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hypoxic" = "darkmagenta", "Normoxic" = "seagreen")) +
  labs(x = "Phase 1 DO", y = "C:N in Tissue") +
ylim(4.9, 5.3)+
  theme(legend.position = "none") # Remove legend

#Tissue plot with mean and SD
ggplot(summary_stats, aes(x = Phase_1_DO, y = mean_cn, color = Phase_1_DO)) +
  geom_point(size = 4, position = position_dodge(0.9)) + # Plot means as points
geom_jitter(data = CN_T_df,
              aes(x = Phase_1_DO, y = (wt_percent_C/wt_percent_N), color = Phase_1_DO),
              width = 0.1, alpha = 0.5, size = 2) +
  geom_errorbar(aes(ymin = mean_cn - se_cn, ymax = mean_cn + se_cn), 
                width = 0.05, position = position_dodge(0.9)) + # Error bars for SD
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) + #fill background light blue
  guides(color = "none") + # Remove legend for color
  scale_color_manual(values = c("Hypoxic" = "darkmagenta", "Normoxic" = "seagreen")) +
  labs(x = "Phase 1 DO", y = "C:N in Tissue") +
  theme(legend.position = "none") # Remove legend
# Out:
# plot without title
# plot without title

# %% [markdown]
# #### Oysters in hypoxia tended to store higher C:N than oysters in normoxia (p = 0.08)

# %%
colnames(N_T_df)
# Out:
#  [1] "og_order"        "Sample_Name"     "Phase_1_treat"   "Phase_1_rep_R"
#  [5] "Phase_1_DO"      "Phase_1_temp"    "Linearcorr_d15N" "wt_percent_N"
#  [9] "N_notes"         "Linearcorr_d13C" "wt_percent_C"    "C_notes"
# [13] "N_exclude"       "C_exclude"

# %% [markdown]
# # δ15N in Oyster Tissue

# %%
#summary stats
summary_stats <- N_T_df %>%
  group_by(Phase_1_treat) %>%
  summarize(
    mean_growth = mean(Linearcorr_d15N, na.rm = TRUE),
    se_growth = std.error(Linearcorr_d15N, na.rm = TRUE))
#reorder Phase_1_treat
summary_stats$Phase_1_treat <- factor(summary_stats$Phase_1_treat, 
                                      levels = c("Cont", "Warm","Hyp", "Both"))

#plot including ALL raw data
ggplot(summary_stats, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_jitter(data = N_T_df,
              aes(x = Phase_1_treat, y = Linearcorr_d15N, color = Phase_1_treat),
              width = 0.1, alpha = 0.5, size = 2) +
  geom_point(size = 4, position = position_dodge(0.9)) +
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.1, position = position_dodge(0.9)) +
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) +
  guides(color = "none") +
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred",
                                "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Linearcorr_d15N") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control",
                              "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none")



#summary stats filtering out small peaks / data with higher error
summary_stats <- delta_N %>%
  group_by(Phase_1_treat) %>%
  summarize(
    mean_growth = mean(Linearcorr_d15N, na.rm = TRUE),
    se_growth = std.error(Linearcorr_d15N, na.rm = TRUE))
#reorder Phase_1_treat
summary_stats$Phase_1_treat <- factor(summary_stats$Phase_1_treat, 
                                      levels = c("Cont", "Warm","Hyp", "Both"))

#plot filtering out small peaks / data with higher error
ggplot(summary_stats, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_jitter(data = delta_N,
              aes(x = Phase_1_treat, y = Linearcorr_d15N, color = Phase_1_treat),
              width = 0.1, alpha = 0.5, size = 2) +
  geom_point(size = 4, position = position_dodge(0.9)) +
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.1, position = position_dodge(0.9)) +
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) +
  guides(color = "none") +
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred",
                                "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Linearcorr_d15N") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control",
                              "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none")
# Out:
# plot without title
# plot without title

# %% [markdown]
# ### An increased δ15N in Oyster Tissue could be an indication of starvation. Low DO conditions have been linked to increased δ15N in Oyster Tissue (Patterson & Carmichael 2018).

# %% [markdown]
# ## Analysis

# %%
colnames(N_T_df)
# Out:
#  [1] "og_order"        "Sample_Name"     "Phase_1_treat"   "Phase_1_rep_R"
#  [5] "Phase_1_DO"      "Phase_1_temp"    "Linearcorr_d15N" "wt_percent_N"
#  [9] "N_notes"         "Linearcorr_d13C" "wt_percent_C"    "C_notes"
# [13] "N_exclude"       "C_exclude"

# %%
Nm1 <- lmer(Linearcorr_d15N ~ Phase_1_DO*Phase_1_temp +
              (1|Phase_1_rep_R), data = N_T_df, REML=TRUE)

aov_tab <- Anova(Nm1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                         F            Df Df.res   Pr(>F)
# (Intercept)             3.287093e+03 1  19.59861 0.0000
# Phase_1_DO              3.220591e-03 1  19.59861 0.9553
# Phase_1_temp            4.938750e-01 1  19.59861 0.4905
# Phase_1_DO:Phase_1_temp 5.280021e-01 1  19.59861 0.4760

# %%
View(N_T_df)
# Out:
#    og_order Sample_Name                Phase_1_treat Phase_1_rep_R Phase_1_DO
# 1  10       2024_Both01_Null_O6_T      Both          Both01        Hypoxic
# 2  42       2024_Both01_Null_O98_T     Both          Both01        Hypoxic
# 3  32       2024_Both02_Null_O13_T     Both          Both02        Hypoxic
# 4  52       2024_Both02_Null_O14_T_C   Both          Both02        Hypoxic
# 5  36       2024_Both03_Null_O22_T     Both          Both03        Hypoxic
# 6  12       2024_Both05_Null_O33_T     Both          Both05        Hypoxic
# 7  34       2024_Both05_Null_O38_T     Both          Both05        Hypoxic
# 8  15       2024_Both06_Null_O45_T     Both          Both06        Hypoxic
# 9   2       2024_Cont01_Null_W2_T      Cont          Cont01        Normoxic
# 10  7       2024_Cont01_Null_W6_T      Cont          Cont01        Normoxic
# 11 26       2024_Cont02_Null_W10_T     Cont          Cont02        Normoxic
# 12  4       2024_Cont02_Null_W14_T     Cont          Cont02        Normoxic
# 13 37       2024_Cont03_Null_W17_T     Cont          Cont03        Normoxic
# 14 21       2024_Cont03_Null_W19_T     Cont          Cont03        Normoxic
# 15 24       2024_Cont04_Null_W30_T     Cont          Cont04        Normoxic
# 16 20       2024_Cont04_Null_W31_T     Cont          Cont04        Normoxic
# 17 25       2024_Cont05_Null_W34_T     Cont          Cont05        Normoxic
# 18 27       2024_Cont05_Null_W37_T     Cont          Cont05        Normoxic
# 19 39       2024_Cont06_Null_W47_T     Cont          Cont06        Normoxic
# 20 38       2024_Cont06_Null_W48_T     Cont          Cont06        Normoxic
# 21 19       2024_Hyp01_Null_B1_T       Hyp           Hyp01         Hypoxic
# 22 46       2024_Hyp01_Null_B3_T       Hyp           Hyp01         Hypoxic
# 23 31       2024_Hyp02_Null_B10_T      Hyp           Hyp02         Hypoxic
# 24  6       2024_Hyp02_Null_B9_T       Hyp           Hyp02         Hypoxic
# 25  9       2024_Hyp03_Null_B22_T      Hyp           Hyp03         Hypoxic
# 26  1       2024_Hyp04_Null_B25_T      Hyp           Hyp04         Hypoxic
# 27 47       2024_Hyp04_Null_B30_T      Hyp           Hyp04         Hypoxic
# 28 35       2024_Hyp05_Null_B37_T      Hyp           Hyp05         Hypoxic
# 29 33       2024_Hyp06_Null_B41_T      Hyp           Hyp06         Hypoxic
# 30  5       2024_Hyp06_Null_B46_T      Hyp           Hyp06         Hypoxic
# 31 18       2024_Warm01_Null_G5_T      Warm          Warm01        Normoxic
# 32 17       2024_Warm01_Null_G6_T      Warm          Warm01        Normoxic
# 33 22       2024_Warm02_Null_G13_T     Warm          Warm02        Normoxic
# 34 29       2024_Warm02_Null_G14_T     Warm          Warm02        Normoxic
# 35 40       2024_Warm03_Null_G18_T     Warm          Warm03        Normoxic
# 36 28       2024_Warm03_Null_G22_T     Warm          Warm03        Normoxic
# 37 23       2024_Warm04_Null_G26_T     Warm          Warm04        Normoxic
# 38 30       2024_Warm04_Null_G30_T     Warm          Warm04        Normoxic
# 39 16       2024_Warm05_Null_G37_T     Warm          Warm05        Normoxic
# 40  8       2024_Warm05_Null_G38_T     Warm          Warm05        Normoxic
# 41 13       2024_Warm06_Null_G43_T     Warm          Warm06        Normoxic
# 42 NA       2024_Both04_Null_O30_T_avg Both          Both04        Hypoxic
# 43 NA       2024_Hyp05_Null_B33_T_avg  Hyp           Hyp05         Hypoxic
# 44 NA       2024_Warm06_Null_G46_T_avg Warm          Warm06        Normoxic
#    Phase_1_temp Linearcorr_d15N wt_percent_N
# 1  Warm          9.6            8.3
# 2  Warm          7.7            8.2
# 3  Warm         10.5            7.1
# 4  Warm         10.6            8.0
# 5  Warm          9.9            4.2
# 6  Warm         10.2            7.6
# 7  Warm         10.2            7.9
# 8  Warm         10.2            8.1
# 9  Ambient      11.0            7.7
# 10 Ambient      10.0            7.9
# 11 Ambient      11.0            8.7
# 12 Ambient       9.2            6.4
# 13 Ambient       9.8            8.7
# 14 Ambient       7.4            7.2
# 15 Ambient      11.3            7.7
# 16 Ambient      10.5            7.5
# 17 Ambient      10.8            8.7
# 18 Ambient      10.1            5.7
# 19 Ambient       8.0            8.2
# 20 Ambient      10.8            8.5
# 21 Ambient      10.4            7.0
# 22 Ambient      10.1            8.6
# 23 Ambient       7.9            6.9
# 24 Ambient      11.2            8.4
# 25 Ambient      11.0            6.1
# 26 Ambient      10.8            7.7
# 27 Ambient       7.5            7.8
# 28 Ambient      11.2            9.6
# 29 Ambient      10.4            7.9
# 30 Ambient      11.4            8.1
# 31 Warm         10.6            8.4
# 32 Warm          9.8            6.9
# 33 Warm         10.5            8.1
# 34 Warm         10.9            7.7
# 35 Warm          8.3            8.2
# 36 Warm          9.6            6.7
# 37 Warm         10.4            7.9
# 38 Warm         10.7            8.2
# 39 Warm          9.1            8.9
# 40 Warm          9.0            6.0
# 41 Warm         11.7            8.6
# 42 Warm          9.0            4.3
# 43 Ambient      11.0            8.7
# 44 Warm          9.4            6.1
#    N_notes                                   Linearcorr_d13C wt_percent_C
# 1  NA                                        -23.4           40.8
# 2  small peak - error on δ15N will be higher -24.8           44.4
# 3  NA                                        -23.7           35.8
# 4  NA                                        -23.3           40.6
# 5  small peak - error on δ15N will be higher -19.6           25.3
# 6  NA                                        -22.9           38.1
# 7  NA                                        -23.8           40.2
# 8  NA                                        -24.0           40.3
# 9  NA                                        -23.1           37.3
# 10 NA                                        -23.0           37.6
# 11 NA                                        -23.5           41.0
# 12 small peak - error on δ15N will be higher -23.3           37.6
# 13 small peak - error on δ15N will be higher -23.7           40.5
# 14 small peak - error on δ15N will be higher -23.6           35.7
# 15 NA                                        -23.2           39.6
# 16 NA                                        -23.4           38.9
# 17 NA                                        -23.7           41.6
# 18 NA                                        -21.8           31.3
# 19 small peak - error on δ15N will be higher -23.7           39.0
# 20 NA                                        -23.7           42.3
# 21 NA                                        -23.1           37.9
# 22 NA                                        -23.9           42.1
# 23 small peak - error on δ15N will be higher -23.3           34.9
# 24 NA                                        -23.1           41.5
# 25 NA                                        -21.4           33.8
# 26 NA                                        -23.1           37.9
# 27 small peak - error on δ15N will be higher -23.9           39.8
# 28 NA                                        -23.6           48.7
# 29 NA                                        -22.9           40.0
# 30 NA                                        -23.1           41.0
# 31 NA                                        -24.1           41.4
# 32 NA                                        -22.6           35.2
# 33 NA                                        -23.9           41.3
# 34 NA                                        -23.4           38.5
# 35 small peak - error on δ15N will be higher -24.2           40.9
# 36 small peak - error on δ15N will be higher -22.7           34.8
# 37 NA                                        -24.5           42.2
# 38 NA                                        -23.8           40.0
# 39 small peak - error on δ15N will be higher -24.6           43.7
# 40 small peak - error on δ15N will be higher -21.5           30.8
# 41 NA                                        -24.0           41.9
# 42 NA                                        -19.7           26.2
# 43 NA                                        -23.7           43.0
# 44 NA                                        -23.1           31.0
#    C_notes N_exclude C_exclude
# 1  NA      NA        NA
# 2  NA      NA        NA
# 3  NA      NA        NA
# 4  NA      NA        NA
# 5  NA      NA        NA
# 6  NA      NA        NA
# 7  NA      NA        NA
# 8  NA      NA        NA
# 9  NA      NA        NA
# 10 NA      NA        NA
# 11 NA      NA        NA
# 12 NA      NA        NA
# 13 NA      NA        NA
# 14 NA      NA        NA
# 15 NA      NA        NA
# 16 NA      NA        NA
# 17 NA      NA        NA
# 18 NA      NA        NA
# 19 NA      NA        NA
# 20 NA      NA        NA
# 21 NA      NA        NA
# 22 NA      NA        NA
# 23 NA      NA        NA
# 24 NA      NA        NA
# 25 NA      NA        NA
# 26 NA      NA        NA
# 27 NA      NA        NA
# 28 NA      NA        NA
# 29 NA      NA        NA
# 30 NA      NA        NA
# 31 NA      NA        NA
# 32 NA      NA        NA
# 33 NA      NA        NA
# 34 NA      NA        NA
# 35 NA      NA        NA
# 36 NA      NA        NA
# 37 NA      NA        NA
# 38 NA      NA        NA
# 39 NA      NA        NA
# 40 NA      NA        NA
# 41 NA      NA        NA
# 42 NA      NA        NA
# 43 NA      NA        NA
# 44 NA      NA        NA

# %%
delta_N <- N_T_df%>%
filter(is.na(N_notes))

# %%
delta_N
# Out:
#    og_order Sample_Name                Phase_1_treat Phase_1_rep_R Phase_1_DO
# 1  10       2024_Both01_Null_O6_T      Both          Both01        Hypoxic
# 2  32       2024_Both02_Null_O13_T     Both          Both02        Hypoxic
# 3  52       2024_Both02_Null_O14_T_C   Both          Both02        Hypoxic
# 4  12       2024_Both05_Null_O33_T     Both          Both05        Hypoxic
# 5  34       2024_Both05_Null_O38_T     Both          Both05        Hypoxic
# 6  15       2024_Both06_Null_O45_T     Both          Both06        Hypoxic
# 7   2       2024_Cont01_Null_W2_T      Cont          Cont01        Normoxic
# 8   7       2024_Cont01_Null_W6_T      Cont          Cont01        Normoxic
# 9  26       2024_Cont02_Null_W10_T     Cont          Cont02        Normoxic
# 10 24       2024_Cont04_Null_W30_T     Cont          Cont04        Normoxic
# 11 20       2024_Cont04_Null_W31_T     Cont          Cont04        Normoxic
# 12 25       2024_Cont05_Null_W34_T     Cont          Cont05        Normoxic
# 13 27       2024_Cont05_Null_W37_T     Cont          Cont05        Normoxic
# 14 38       2024_Cont06_Null_W48_T     Cont          Cont06        Normoxic
# 15 19       2024_Hyp01_Null_B1_T       Hyp           Hyp01         Hypoxic
# 16 46       2024_Hyp01_Null_B3_T       Hyp           Hyp01         Hypoxic
# 17  6       2024_Hyp02_Null_B9_T       Hyp           Hyp02         Hypoxic
# 18  9       2024_Hyp03_Null_B22_T      Hyp           Hyp03         Hypoxic
# 19  1       2024_Hyp04_Null_B25_T      Hyp           Hyp04         Hypoxic
# 20 35       2024_Hyp05_Null_B37_T      Hyp           Hyp05         Hypoxic
# 21 33       2024_Hyp06_Null_B41_T      Hyp           Hyp06         Hypoxic
# 22  5       2024_Hyp06_Null_B46_T      Hyp           Hyp06         Hypoxic
# 23 18       2024_Warm01_Null_G5_T      Warm          Warm01        Normoxic
# 24 17       2024_Warm01_Null_G6_T      Warm          Warm01        Normoxic
# 25 22       2024_Warm02_Null_G13_T     Warm          Warm02        Normoxic
# 26 29       2024_Warm02_Null_G14_T     Warm          Warm02        Normoxic
# 27 23       2024_Warm04_Null_G26_T     Warm          Warm04        Normoxic
# 28 30       2024_Warm04_Null_G30_T     Warm          Warm04        Normoxic
# 29 13       2024_Warm06_Null_G43_T     Warm          Warm06        Normoxic
# 30 NA       2024_Both04_Null_O30_T_avg Both          Both04        Hypoxic
# 31 NA       2024_Hyp05_Null_B33_T_avg  Hyp           Hyp05         Hypoxic
# 32 NA       2024_Warm06_Null_G46_T_avg Warm          Warm06        Normoxic
#    Phase_1_temp Linearcorr_d15N wt_percent_N N_notes Linearcorr_d13C
# 1  Warm          9.6            8.3          NA      -23.4
# 2  Warm         10.5            7.1          NA      -23.7
# 3  Warm         10.6            8.0          NA      -23.3
# 4  Warm         10.2            7.6          NA      -22.9
# 5  Warm         10.2            7.9          NA      -23.8
# 6  Warm         10.2            8.1          NA      -24.0
# 7  Ambient      11.0            7.7          NA      -23.1
# 8  Ambient      10.0            7.9          NA      -23.0
# 9  Ambient      11.0            8.7          NA      -23.5
# 10 Ambient      11.3            7.7          NA      -23.2
# 11 Ambient      10.5            7.5          NA      -23.4
# 12 Ambient      10.8            8.7          NA      -23.7
# 13 Ambient      10.1            5.7          NA      -21.8
# 14 Ambient      10.8            8.5          NA      -23.7
# 15 Ambient      10.4            7.0          NA      -23.1
# 16 Ambient      10.1            8.6          NA      -23.9
# 17 Ambient      11.2            8.4          NA      -23.1
# 18 Ambient      11.0            6.1          NA      -21.4
# 19 Ambient      10.8            7.7          NA      -23.1
# 20 Ambient      11.2            9.6          NA      -23.6
# 21 Ambient      10.4            7.9          NA      -22.9
# 22 Ambient      11.4            8.1          NA      -23.1
# 23 Warm         10.6            8.4          NA      -24.1
# 24 Warm          9.8            6.9          NA      -22.6
# 25 Warm         10.5            8.1          NA      -23.9
# 26 Warm         10.9            7.7          NA      -23.4
# 27 Warm         10.4            7.9          NA      -24.5
# 28 Warm         10.7            8.2          NA      -23.8
# 29 Warm         11.7            8.6          NA      -24.0
# 30 Warm          9.0            4.3          NA      -19.7
# 31 Ambient      11.0            8.7          NA      -23.7
# 32 Warm          9.4            6.1          NA      -23.1
#    wt_percent_C C_notes N_exclude C_exclude
# 1  40.8         NA      NA        NA
# 2  35.8         NA      NA        NA
# 3  40.6         NA      NA        NA
# 4  38.1         NA      NA        NA
# 5  40.2         NA      NA        NA
# 6  40.3         NA      NA        NA
# 7  37.3         NA      NA        NA
# 8  37.6         NA      NA        NA
# 9  41.0         NA      NA        NA
# 10 39.6         NA      NA        NA
# 11 38.9         NA      NA        NA
# 12 41.6         NA      NA        NA
# 13 31.3         NA      NA        NA
# 14 42.3         NA      NA        NA
# 15 37.9         NA      NA        NA
# 16 42.1         NA      NA        NA
# 17 41.5         NA      NA        NA
# 18 33.8         NA      NA        NA
# 19 37.9         NA      NA        NA
# 20 48.7         NA      NA        NA
# 21 40.0         NA      NA        NA
# 22 41.0         NA      NA        NA
# 23 41.4         NA      NA        NA
# 24 35.2         NA      NA        NA
# 25 41.3         NA      NA        NA
# 26 38.5         NA      NA        NA
# 27 42.2         NA      NA        NA
# 28 40.0         NA      NA        NA
# 29 41.9         NA      NA        NA
# 30 26.2         NA      NA        NA
# 31 43.0         NA      NA        NA
# 32 31.0         NA      NA        NA

# %%
Nm1 <- lmer(Linearcorr_d15N ~ Phase_1_DO*Phase_1_temp +
              (1|Phase_1_rep_R), data = delta_N, REML=TRUE)

aov_tab <- Anova(Nm1, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
# boundary (singular) fit: see help('isSingular')
#                         F            Df Df.res   Pr(>F)
# (Intercept)             1.154157e+04 1  13.93777 0.0000
# Phase_1_DO              6.321716e-01 1  13.93777 0.4399
# Phase_1_temp            6.238881e+00 1  13.93777 0.0256
# Phase_1_DO:Phase_1_temp 2.371649e+00 1  13.93777 0.1459

# %%
emmeans(Nm1,specs = pairwise ~ Phase_1_temp, adjust = "none")
# Out:
# NOTE: Results may be misleading due to involvement in interactions
# $emmeans
#  Phase_1_temp emmean    SE   df lower.CL upper.CL
#  Ambient        10.8 0.135 14.5    10.47     11.0
#  Warm           10.3 0.142 13.5     9.97     10.6
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger
# Confidence level used: 0.95
#
# $contrasts
#  contrast       estimate    SE   df t.ratio p.value
#  Ambient - Warm    0.489 0.196 13.9   2.498  0.0256
#
# Results are averaged over the levels of: Phase_1_DO
# Degrees-of-freedom method: kenward-roger

# %%
#format display for jupyter
options(repr.plot.width = 6, repr.plot.height = 6)

stats_s <- delta_N %>%
  group_by(Phase_1_temp) %>%
  summarise(
    mean_growth = mean(Linearcorr_d15N, na.rm = TRUE),
    se_growth = std.error(Linearcorr_d15N, na.rm = TRUE),
    .groups = "drop")

ggplot(stats_s, aes(
  x = Phase_1_temp,
  y = mean_growth,
  colour = Phase_1_temp)) +
  geom_jitter(data = delta_N,
    aes(
      x = Phase_1_temp,
      y = Linearcorr_d15N,
      colour = Phase_1_temp),
    inherit.aes = FALSE,
    width = 0.1,
    alpha = 0.5,
    size = 2) +
  geom_point(size = 4) +
  geom_errorbar(
    aes(
      ymin = mean_growth - se_growth,
      ymax = mean_growth + se_growth),
    width = 0.1) +
  scale_colour_manual(
    values = c("Warm" = "#B00149", "Ambient" = "darkblue")) +
  labs(
    x = "Phase 1 Treatment",
    y = "δ15N") +
  theme_classic(base_size = 18) +
  theme(
    panel.background = element_rect(fill = "aliceblue"),
    legend.position = "none")
# Out:
# plot without title

# %% [markdown]
# ### oysters in warm conditions had a lower δ15N than oysters in control conditions

# %% [markdown]
# ### interesting because we expect increased δ15N if oysters are stressed due to catabolism of tissues (Patterson and Carmichael 2018)

# %% [markdown]
# # δ15N in Oyster Shell

# %%
#rename Linearcorr_d15N column
colnames(N_S_df)
N_S_df<-N_S_df%>%
rename(Linearcorr_d15N = 'Linear corr d15N')
# Out:
#  [1] "og_order"         "Sample_Name"      "Phase_1_treat"    "Phase_1_rep_R"
#  [5] "Phase_1_DO"       "Phase_1_temp"     "Linear corr d15N" "wt_percent_N"
#  [9] "Linear corr d13C" "wt_percent_C"     "N_exclude"        "C_exclude"

# %%
#summary stats
summary_stats <- N_S_df %>%
  group_by(Phase_1_treat) %>%
  summarize(
    mean_growth = mean(Linearcorr_d15N, na.rm = TRUE),
    se_growth = std.error(Linearcorr_d15N, na.rm = TRUE))
#reorder Phase_1_treat
summary_stats$Phase_1_treat <- factor(summary_stats$Phase_1_treat, 
                                      levels = c("Cont", "Warm","Hyp", "Both"))

#plot including ALL raw data
ggplot(summary_stats, aes(x = Phase_1_treat, y = mean_growth, color = Phase_1_treat)) +
  geom_jitter(data = N_S_df,
              aes(x = Phase_1_treat, y = Linearcorr_d15N, color = Phase_1_treat),
              width = 0.1, alpha = 0.5, size = 2) +
  geom_point(size = 4, position = position_dodge(0.9)) +
  geom_errorbar(aes(ymin = mean_growth - se_growth, ymax = mean_growth + se_growth), 
                width = 0.1, position = position_dodge(0.9)) +
  theme_classic(base_size = 18) +
  theme(panel.background = element_rect(fill = "aliceblue")) +
  guides(color = "none") +
  scale_color_manual(values = c("Hyp" = "steelblue3", "Warm" = "palevioletred",
                                "Cont" = "burlywood3", "Both" = "plum3")) +
  labs(x = "Phase 1 Treatment", y = "Linearcorr_d15N") +
  scale_x_discrete(labels = c("Hyp" = "Hypoxic", "Cont" = "Control",
                              "Warm" = "Warm", "Both" = "Both")) +
  theme(legend.position = "none")
# Out:
# plot without title

# %%
Nm2 <- lmer(Linearcorr_d15N ~ Phase_1_DO*Phase_1_temp +
              (1|Phase_1_rep_R), data = N_S_df, REML=TRUE)

aov_tab <- Anova(Nm2, test="F", type="III")

#remove scientific notation
aov_tab %>%
  mutate(`Pr(>F)` = round(`Pr(>F)`, 4))
# Out:
#                         F            Df Df.res Pr(>F)
# (Intercept)             8.947241e+03 1  20     0.0000
# Phase_1_DO              1.419044e-03 1  20     0.9703
# Phase_1_temp            3.632752e-01 1  20     0.5535
# Phase_1_DO:Phase_1_temp 5.676174e-03 1  20     0.9407

# %% [markdown]
# ### No differences in δ15N in Oyster Shell
